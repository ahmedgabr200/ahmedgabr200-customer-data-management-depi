# %%
import pandas as pd


csv_file_path = 'fact_sales_data.csv' 
df = pd.read_csv(csv_file_path)

insert_statements = []

for index, row in df.iterrows():
    insert_statement = f"""
    INSERT INTO fact_sales (transaction_id, customer_key, address_key, contact_key, payment_method_key, interaction_key, interaction_type_key, transaction_date_key, amount, created_at)
    VALUES ({row['transaction_id']}, {row['customer_key']}, {row['address_key']}, {row['contact_key']}, 
    {row['payment_method_key']}, {row['interaction_key']}, {row['interaction_type_key']}, 
    {row['transaction_date_key']}, {row['amount']}, '{row['created_at']}');
    """
    insert_statements.append(insert_statement)
with open("insert_statements.sql", "w") as file:
    for statement in insert_statements:
        file.write(statement)

print("Insert statements have been written to 'insert_statements.sql'")
# Out:
# Insert statements have been written to 'insert_statements.sql'

# %%
import pyodbc

csv_file_path = 'fact_sales_data.csvا
df = pd.read_csv(csv_file_path)


conn = pyodbc.connect('DRIVER={SQL Server};'
                      'SERVER=DESKTOP-67E98DV;'
                      'DATABASE=SalesDWH;'
                      'Trusted_Connection=yes;') 
cursor = conn.cursor()


cursor.execute("SELECT payment_method_key FROM dim_payment_method")
available_payment_keys = [row[0] for row in cursor.fetchall()]


invalid_keys = df[~df['payment_method_key'].isin(available_payment_keys)]

if not invalid_keys.empty:
    print("Found invalid payment_method_key values:")
    print(invalid_keys)
else:
    print("All payment_method_key values are valid.")
# Out:
# Found invalid payment_method_key values:
#      transaction_id  customer_key  address_key  contact_key  \
# 0                 1            46           98           78
# 1                 2            34          171          197
# 2                 3           108           80           87
# 3                 4            85           60          160
# 4                 5           138          187           10
# ..              ...           ...          ...          ...
# 995             996           140           71           72
# 996             997            85          178           83
# 997             998            12          103           16
# 998             999            85          119           63
# 999            1000            51            3          130
#
#      payment_method_key  interaction_key  interaction_type_key  \
# 0                     8               92                     1
# 1                     3               57                     4
# 2                     3                3                     2
# 3                     4               70                     1
# 4                     3               78                     2
# ..                  ...              ...                   ...
# 995                   2               92                     2
# 996                   9               17                     3
# 997                   1               45                     5
# 998                   9               95                     1
# 999                   6                7                     1
#
#      transaction_date_key  amount  created_at
# 0                     776  698.90  2023-06-10
# 1                     758  560.01  2023-03-07
# 2                     810  387.26  2022-04-27
# 3                     591  426.86  2020-12-28
# 4                     933  302.52  2020-12-27
# ..                    ...     ...         ...
# 995                   809  194.84  2022-07-27
# 996                   790  722.28  2021-10-14
# 997                  1106  393.94  2020-07-28
# 998                  1117  691.78  2021-09-18
# 999                   335  693.95  2021-01-12
#
# [1000 rows x 10 columns]

# %%
import pyodbc

def connect_to_server(server_name, database_name):
    try:
        connection = pyodbc.connect(f'DRIVER={{SQL Server}};'
                                    f'SERVER={server_name};'
                                    f'DATABASE={database_name};'
                                    'Trusted_Connection=yes;')
        print(f"Connected to {database_name} on {server_name} successfully!")
        return connection
    except Exception as e:
        print(f"Failed to connect to {database_name} on {server_name}: {e}")
        return None


def fetch_data_from_db(connection, query):
    cursor = connection.cursor()
    cursor.execute(query)
    return cursor.fetchall()


def get_date_key(dwh_conn, transaction_date):
    query = f"SELECT date_key FROM dim_date WHERE full_date = '{transaction_date}'"
    cursor = dwh_conn.cursor()
    cursor.execute(query)
    result = cursor.fetchone()
    return result[0] if result else None


def customer_key_exists(dwh_conn, customer_key):
    query = f"SELECT 1 FROM dim_customer WHERE customer_key = ?"
    cursor = dwh_conn.cursor()
    cursor.execute(query, customer_key)
    result = cursor.fetchone()
    return result is not None


def transform_sales_data_with_check(dwh_conn, data):
    transformed_data = []
    for row in data:
        
        date_key = get_date_key(dwh_conn, row[2])  
        
       
        if customer_key_exists(dwh_conn, row[1]):  
            transformed_row = (
                row[0],  
                row[1], 
                None,    
                None,    
                row[4], 
                None, 
                None,  
                date_key,  
                row[3]   
            )
            transformed_data.append(transformed_row)
        else:
            print(f"CustomerID {row[1]} not found in dim_customer. Skipping this record.")
    return transformed_data

def load_data_to_dwh(connection, insert_query, data):
    cursor = connection.cursor()
    cursor.executemany(insert_query, data)
    connection.commit()
    print(f"{len(data)} rows inserted successfully!")


database_conn = connect_to_server('DESKTOP-67E98DV\\SQLEXPRESS', 'CustomerDataManagement') 
dwh_conn = connect_to_server('DESKTOP-67E98DV', 'SalesDWH')  

if database_conn and dwh_conn:

    sales_query = "SELECT TransactionID, CustomerID, TransactionDate, Amount, PaymentMethodID FROM Transactions"
    sales_data = fetch_data_from_db(database_conn, sales_query)

   
    transformed_sales_data = transform_sales_data_with_check(dwh_conn, sales_data)

  
    sales_insert_query = """
 x    INSERT INTO fact_sales (transaction_id, customer_key, address_key, contact_key, payment_method_key, interaction_key, interaction_type_key, transaction_date_key, amount)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    """
    load_data_to_dwh(dwh_conn, sales_insert_query, transformed_sales_data)


    database_conn.close()
    dwh_conn.close()

else:
    print("Error in database connections. Please check your server details.")
# Out:
# Connected to CustomerDataManagement on DESKTOP-67E98DV\SQLEXPRESS successfully!
# Connected to SalesDWH on DESKTOP-67E98DV successfully!
# CustomerID 1 not found in dim_customer. Skipping this record.
# CustomerID 2 not found in dim_customer. Skipping this record.
# CustomerID 3 not found in dim_customer. Skipping this record.
# CustomerID 4 not found in dim_customer. Skipping this record.
# CustomerID 5 not found in dim_customer. Skipping this record.
# CustomerID 6 not found in dim_customer. Skipping this record.
# CustomerID 7 not found in dim_customer. Skipping this record.
# CustomerID 8 not found in dim_customer. Skipping this record.
# CustomerID 9 not found in dim_customer. Skipping this record.
# CustomerID 10 not found in dim_customer. Skipping this record.
# CustomerID 11 not found in dim_customer. Skipping this record.
# CustomerID 12 not found in dim_customer. Skipping this record.
# CustomerID 13 not found in dim_customer. Skipping this record.
# CustomerID 14 not found in dim_customer. Skipping this record.
# CustomerID 15 not found in dim_customer. Skipping this record.
# CustomerID 16 not found in dim_customer. Skipping this record.
# CustomerID 17 not found in dim_customer. Skipping this record.
# CustomerID 18 not found in dim_customer. Skipping this record.
# CustomerID 19 not found in dim_customer. Skipping this record.
# CustomerID 20 not found in dim_customer. Skipping this record.
# CustomerID 21 not found in dim_customer. Skipping this record.
# CustomerID 22 not found in dim_customer. Skipping this record.
# CustomerID 23 not found in dim_customer. Skipping this record.
# CustomerID 24 not found in dim_customer. Skipping this record.
# CustomerID 25 not found in dim_customer. Skipping this record.
# CustomerID 26 not found in dim_customer. Skipping this record.
# CustomerID 27 not found in dim_customer. Skipping this record.
# CustomerID 28 not found in dim_customer. Skipping this record.
# CustomerID 988 not found in dim_customer. Skipping this record.
# CustomerID 989 not found in dim_customer. Skipping this record.
# CustomerID 990 not found in dim_customer. Skipping this record.
# CustomerID 991 not found in dim_customer. Skipping this record.
# CustomerID 992 not found in dim_customer. Skipping this record.
# CustomerID 993 not found in dim_customer. Skipping this record.
# CustomerID 994 not found in dim_customer. Skipping this record.
# CustomerID 995 not found in dim_customer. Skipping this record.
# CustomerID 996 not found in dim_customer. Skipping this record.
# CustomerID 997 not found in dim_customer. Skipping this record.
# CustomerID 998 not found in dim_customer. Skipping this record.
# CustomerID 999 not found in dim_customer. Skipping this record.
# CustomerID 1000 not found in dim_customer. Skipping this record.
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[16], line 89
#      84 # 4. تحميل المبيعات في الـ DWH
#      85 sales_insert_query = """
#      86 INSERT INTO fact_sales (transaction_id, customer_key, address_key, contact_key, payment_method_key, interaction_key, interaction_type_key, transaction_date_key, amount)
#      87 VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
#      88 """
# ---> 89 load_data_to_dwh(dwh_conn, sales_insert_query, transformed_sales_data)
#      91 # 5. إغلاق الاتصالات
#      92 database_conn.close()
#
# Cell In[16], line 66, in load_data_to_dwh(connection, insert_query, data)
#      64 def load_data_to_dwh(connection, insert_query, data):
#      65     cursor = connection.cursor()
# ---> 66     cursor.executemany(insert_query, data)
#      67     connection.commit()
#      68     print(f"{len(data)} rows inserted successfully!")
#
# ProgrammingError: The second parameter to executemany must not be empty.

# %%
import pyodbc
from datetime import datetime, timedelta


def create_connection(server, database):
    connection_string = f"""
    DRIVER={{ODBC Driver 17 for SQL Server}};
    SERVER={server};
    DATABASE={database};
    Trusted_Connection=yes;
    """
    try:
        connection = pyodbc.connect(connection_string)
        print(f"Connected to {database} on {server} successfully!")
        return connection
    except pyodbc.Error as e:
        print(f"Error while connecting to database: {e}")
        return None


def generate_date_data(start_date, end_date):
    date_data = []
    current_date = start_date
    while current_date <= end_date:
        date_key = int(current_date.strftime("%Y%m%d"))  
        date_data.append([
            date_key,
            current_date.strftime("%Y-%m-%d"),  
            current_date.year, 
            (current_date.month - 1) // 3 + 1,  
            current_date.month, 
            current_date.strftime("%B"),  
        ])
        current_date += timedelta(days=1)
    return date_data


def load_date_data_to_dwh(connection, date_data):
    cursor = connection.cursor()
    

    cursor.execute("SET IDENTITY_INSERT dim_date ON")
    
    date_insert_query = """
    INSERT INTO dim_date (date_key, full_date, year, quarter, month_num, month_name)
    VALUES (?, ?, ?, ?, ?, ?)
    """
    
    cursor.executemany(date_insert_query, date_data)
    connection.commit()  
    
    
    cursor.execute("SET IDENTITY_INSERT dim_date OFF")
    connection.commit()  
    
    print(f"{len(date_data)} rows inserted successfully into dim_date!")


def check_data_in_dim_date(connection):
    cursor = connection.cursor()
    cursor.execute("SELECT * FROM dim_date")
    rows = cursor.fetchall()
    for row in rows:
        print(row)


if __name__ == "__main__":
    
    dwh_conn = create_connection('DESKTOP-67E98DV', 'SalesDWH')
    
    start_date = datetime(2020, 1, 1)
    end_date = datetime(2023, 12, 31)
    
    
    date_data = generate_date_data(start_date, end_date)
    
    load_date_data_to_dwh(dwh_conn, date_data)
    
    check_data_in_dim_date(dwh_conn)
    
    
    dwh_conn.close()
# Out:
# (20200211, datetime.date(2020, 2, 11), 2020, 1, 2, 'February')
# (20200212, datetime.date(2020, 2, 12), 2020, 1, 2, 'February')
# (20200213, datetime.date(2020, 2, 13), 2020, 1, 2, 'February')
# (20200214, datetime.date(2020, 2, 14), 2020, 1, 2, 'February')
# (20200215, datetime.date(2020, 2, 15), 2020, 1, 2, 'February')
# (20200216, datetime.date(2020, 2, 16), 2020, 1, 2, 'February')
# (20200217, datetime.date(2020, 2, 17), 2020, 1, 2, 'February')
# (20200218, datetime.date(2020, 2, 18), 2020, 1, 2, 'February')
# (20200219, datetime.date(2020, 2, 19), 2020, 1, 2, 'February')
# (20200220, datetime.date(2020, 2, 20), 2020, 1, 2, 'February')
# (20200221, datetime.date(2020, 2, 21), 2020, 1, 2, 'February')
# (20200222, datetime.date(2020, 2, 22), 2020, 1, 2, 'February')
# (20200223, datetime.date(2020, 2, 23), 2020, 1, 2, 'February')
# (20200224, datetime.date(2020, 2, 24), 2020, 1, 2, 'February')
# (20200225, datetime.date(2020, 2, 25), 2020, 1, 2, 'February')
# (20200226, datetime.date(2020, 2, 26), 2020, 1, 2, 'February')
# (20200227, datetime.date(2020, 2, 27), 2020, 1, 2, 'February')
# (20200228, datetime.date(2020, 2, 28), 2020, 1, 2, 'February')
# (20200229, datetime.date(2020, 2, 29), 2020, 1, 2, 'February')
# (20200301, datetime.date(2020, 3, 1), 2020, 1, 3, 'March')
# (20200302, datetime.date(2020, 3, 2), 2020, 1, 3, 'March')
# (20200303, datetime.date(2020, 3, 3), 2020, 1, 3, 'March')
# (20200304, datetime.date(2020, 3, 4), 2020, 1, 3, 'March')
# (20200305, datetime.date(2020, 3, 5), 2020, 1, 3, 'March')
# (20200306, datetime.date(2020, 3, 6), 2020, 1, 3, 'March')
# (20200307, datetime.date(2020, 3, 7), 2020, 1, 3, 'March')
# (20200308, datetime.date(2020, 3, 8), 2020, 1, 3, 'March')
# (20200309, datetime.date(2020, 3, 9), 2020, 1, 3, 'March')
# (20200310, datetime.date(2020, 3, 10), 2020, 1, 3, 'March')
# (20200311, datetime.date(2020, 3, 11), 2020, 1, 3, 'March')
# (20200312, datetime.date(2020, 3, 12), 2020, 1, 3, 'March')
# (20200313, datetime.date(2020, 3, 13), 2020, 1, 3, 'March')
# (20200314, datetime.date(2020, 3, 14), 2020, 1, 3, 'March')
# (20200315, datetime.date(2020, 3, 15), 2020, 1, 3, 'March')
# (20200316, datetime.date(2020, 3, 16), 2020, 1, 3, 'March')
# (20200317, datetime.date(2020, 3, 17), 2020, 1, 3, 'March')
# (20200318, datetime.date(2020, 3, 18), 2020, 1, 3, 'March')
# (20200319, datetime.date(2020, 3, 19), 2020, 1, 3, 'March')
# (20200320, datetime.date(2020, 3, 20), 2020, 1, 3, 'March')
# (20200321, datetime.date(2020, 3, 21), 2020, 1, 3, 'March')
# (20200322, datetime.date(2020, 3, 22), 2020, 1, 3, 'March')
# (20200323, datetime.date(2020, 3, 23), 2020, 1, 3, 'March')
# (20200324, datetime.date(2020, 3, 24), 2020, 1, 3, 'March')
# (20200325, datetime.date(2020, 3, 25), 2020, 1, 3, 'March')
# (20200326, datetime.date(2020, 3, 26), 2020, 1, 3, 'March')
# (20200327, datetime.date(2020, 3, 27), 2020, 1, 3, 'March')
# (20200328, datetime.date(2020, 3, 28), 2020, 1, 3, 'March')
# (20200329, datetime.date(2020, 3, 29), 2020, 1, 3, 'March')
# (20200330, datetime.date(2020, 3, 30), 2020, 1, 3, 'March')
# (20200331, datetime.date(2020, 3, 31), 2020, 1, 3, 'March')
# (20200401, datetime.date(2020, 4, 1), 2020, 2, 4, 'April')
# (20200402, datetime.date(2020, 4, 2), 2020, 2, 4, 'April')
# (20200403, datetime.date(2020, 4, 3), 2020, 2, 4, 'April')
# (20200404, datetime.date(2020, 4, 4), 2020, 2, 4, 'April')
# (20200405, datetime.date(2020, 4, 5), 2020, 2, 4, 'April')
# (20200406, datetime.date(2020, 4, 6), 2020, 2, 4, 'April')
# (20200407, datetime.date(2020, 4, 7), 2020, 2, 4, 'April')
# (20200408, datetime.date(2020, 4, 8), 2020, 2, 4, 'April')
# (20200409, datetime.date(2020, 4, 9), 2020, 2, 4, 'April')
# (20200410, datetime.date(2020, 4, 10), 2020, 2, 4, 'April')
# (20200411, datetime.date(2020, 4, 11), 2020, 2, 4, 'April')
# (20200412, datetime.date(2020, 4, 12), 2020, 2, 4, 'April')
# (20200413, datetime.date(2020, 4, 13), 2020, 2, 4, 'April')
# (20200414, datetime.date(2020, 4, 14), 2020, 2, 4, 'April')
# (20200415, datetime.date(2020, 4, 15), 2020, 2, 4, 'April')
# (20200416, datetime.date(2020, 4, 16), 2020, 2, 4, 'April')
# (20200417, datetime.date(2020, 4, 17), 2020, 2, 4, 'April')
# (20200418, datetime.date(2020, 4, 18), 2020, 2, 4, 'April')
# (20200419, datetime.date(2020, 4, 19), 2020, 2, 4, 'April')
# (20200420, datetime.date(2020, 4, 20), 2020, 2, 4, 'April')
# (20200421, datetime.date(2020, 4, 21), 2020, 2, 4, 'April')
# (20200422, datetime.date(2020, 4, 22), 2020, 2, 4, 'April')
# (20200423, datetime.date(2020, 4, 23), 2020, 2, 4, 'April')
# (20200424, datetime.date(2020, 4, 24), 2020, 2, 4, 'April')
# (20200425, datetime.date(2020, 4, 25), 2020, 2, 4, 'April')
# (20200426, datetime.date(2020, 4, 26), 2020, 2, 4, 'April')
# (20200427, datetime.date(2020, 4, 27), 2020, 2, 4, 'April')
# (20200428, datetime.date(2020, 4, 28), 2020, 2, 4, 'April')
# (20200429, datetime.date(2020, 4, 29), 2020, 2, 4, 'April')
# (20200430, datetime.date(2020, 4, 30), 2020, 2, 4, 'April')
# (20200501, datetime.date(2020, 5, 1), 2020, 2, 5, 'May')
# (20200502, datetime.date(2020, 5, 2), 2020, 2, 5, 'May')
# (20200503, datetime.date(2020, 5, 3), 2020, 2, 5, 'May')
# (20200504, datetime.date(2020, 5, 4), 2020, 2, 5, 'May')
# (20200505, datetime.date(2020, 5, 5), 2020, 2, 5, 'May')
# (20200506, datetime.date(2020, 5, 6), 2020, 2, 5, 'May')
# (20200507, datetime.date(2020, 5, 7), 2020, 2, 5, 'May')
# (20200508, datetime.date(2020, 5, 8), 2020, 2, 5, 'May')
# (20200509, datetime.date(2020, 5, 9), 2020, 2, 5, 'May')
# (20200510, datetime.date(2020, 5, 10), 2020, 2, 5, 'May')
# (20200511, datetime.date(2020, 5, 11), 2020, 2, 5, 'May')
# (20200512, datetime.date(2020, 5, 12), 2020, 2, 5, 'May')
# (20200513, datetime.date(2020, 5, 13), 2020, 2, 5, 'May')
# (20200514, datetime.date(2020, 5, 14), 2020, 2, 5, 'May')
# (20200515, datetime.date(2020, 5, 15), 2020, 2, 5, 'May')
# (20200516, datetime.date(2020, 5, 16), 2020, 2, 5, 'May')
# (20200517, datetime.date(2020, 5, 17), 2020, 2, 5, 'May')
# (20200518, datetime.date(2020, 5, 18), 2020, 2, 5, 'May')
# (20200519, datetime.date(2020, 5, 19), 2020, 2, 5, 'May')
# (20200520, datetime.date(2020, 5, 20), 2020, 2, 5, 'May')
# (20200521, datetime.date(2020, 5, 21), 2020, 2, 5, 'May')
# (20200522, datetime.date(2020, 5, 22), 2020, 2, 5, 'May')
# (20200523, datetime.date(2020, 5, 23), 2020, 2, 5, 'May')
# (20200524, datetime.date(2020, 5, 24), 2020, 2, 5, 'May')
# (20200525, datetime.date(2020, 5, 25), 2020, 2, 5, 'May')
# (20200526, datetime.date(2020, 5, 26), 2020, 2, 5, 'May')
# (20200527, datetime.date(2020, 5, 27), 2020, 2, 5, 'May')
# (20200528, datetime.date(2020, 5, 28), 2020, 2, 5, 'May')
# (20200529, datetime.date(2020, 5, 29), 2020, 2, 5, 'May')
# (20200530, datetime.date(2020, 5, 30), 2020, 2, 5, 'May')
# (20200531, datetime.date(2020, 5, 31), 2020, 2, 5, 'May')
# (20200601, datetime.date(2020, 6, 1), 2020, 2, 6, 'June')
# (20200602, datetime.date(2020, 6, 2), 2020, 2, 6, 'June')
# (20200603, datetime.date(2020, 6, 3), 2020, 2, 6, 'June')
# (20200604, datetime.date(2020, 6, 4), 2020, 2, 6, 'June')
# (20200605, datetime.date(2020, 6, 5), 2020, 2, 6, 'June')
# (20200606, datetime.date(2020, 6, 6), 2020, 2, 6, 'June')
# (20200607, datetime.date(2020, 6, 7), 2020, 2, 6, 'June')
# (20200608, datetime.date(2020, 6, 8), 2020, 2, 6, 'June')
# (20200609, datetime.date(2020, 6, 9), 2020, 2, 6, 'June')
# (20200610, datetime.date(2020, 6, 10), 2020, 2, 6, 'June')
# (20200611, datetime.date(2020, 6, 11), 2020, 2, 6, 'June')
# (20200612, datetime.date(2020, 6, 12), 2020, 2, 6, 'June')
# (20200613, datetime.date(2020, 6, 13), 2020, 2, 6, 'June')
# (20200614, datetime.date(2020, 6, 14), 2020, 2, 6, 'June')
# (20200615, datetime.date(2020, 6, 15), 2020, 2, 6, 'June')
# (20200616, datetime.date(2020, 6, 16), 2020, 2, 6, 'June')
# (20200617, datetime.date(2020, 6, 17), 2020, 2, 6, 'June')
# (20200618, datetime.date(2020, 6, 18), 2020, 2, 6, 'June')
# (20200619, datetime.date(2020, 6, 19), 2020, 2, 6, 'June')
# (20200620, datetime.date(2020, 6, 20), 2020, 2, 6, 'June')
# (20200621, datetime.date(2020, 6, 21), 2020, 2, 6, 'June')
# (20200622, datetime.date(2020, 6, 22), 2020, 2, 6, 'June')
# (20200623, datetime.date(2020, 6, 23), 2020, 2, 6, 'June')
# (20200624, datetime.date(2020, 6, 24), 2020, 2, 6, 'June')
# (20200625, datetime.date(2020, 6, 25), 2020, 2, 6, 'June')
# (20200626, datetime.date(2020, 6, 26), 2020, 2, 6, 'June')
# (20200627, datetime.date(2020, 6, 27), 2020, 2, 6, 'June')
# (20200628, datetime.date(2020, 6, 28), 2020, 2, 6, 'June')
# (20200629, datetime.date(2020, 6, 29), 2020, 2, 6, 'June')
# (20200630, datetime.date(2020, 6, 30), 2020, 2, 6, 'June')
# (20200701, datetime.date(2020, 7, 1), 2020, 3, 7, 'July')
# (20200702, datetime.date(2020, 7, 2), 2020, 3, 7, 'July')
# (20200703, datetime.date(2020, 7, 3), 2020, 3, 7, 'July')
# (20200704, datetime.date(2020, 7, 4), 2020, 3, 7, 'July')
# (20200705, datetime.date(2020, 7, 5), 2020, 3, 7, 'July')
# (20200706, datetime.date(2020, 7, 6), 2020, 3, 7, 'July')
# (20200707, datetime.date(2020, 7, 7), 2020, 3, 7, 'July')
# (20200708, datetime.date(2020, 7, 8), 2020, 3, 7, 'July')
# (20200709, datetime.date(2020, 7, 9), 2020, 3, 7, 'July')
# (20200710, datetime.date(2020, 7, 10), 2020, 3, 7, 'July')
# (20200711, datetime.date(2020, 7, 11), 2020, 3, 7, 'July')
# (20200712, datetime.date(2020, 7, 12), 2020, 3, 7, 'July')
# (20200713, datetime.date(2020, 7, 13), 2020, 3, 7, 'July')
# (20200714, datetime.date(2020, 7, 14), 2020, 3, 7, 'July')
# (20200715, datetime.date(2020, 7, 15), 2020, 3, 7, 'July')
# (20200716, datetime.date(2020, 7, 16), 2020, 3, 7, 'July')
# (20200717, datetime.date(2020, 7, 17), 2020, 3, 7, 'July')
# (20200718, datetime.date(2020, 7, 18), 2020, 3, 7, 'July')
# (20200719, datetime.date(2020, 7, 19), 2020, 3, 7, 'July')
# (20200720, datetime.date(2020, 7, 20), 2020, 3, 7, 'July')
# (20200721, datetime.date(2020, 7, 21), 2020, 3, 7, 'July')
# (20200722, datetime.date(2020, 7, 22), 2020, 3, 7, 'July')
# (20200723, datetime.date(2020, 7, 23), 2020, 3, 7, 'July')
# (20200724, datetime.date(2020, 7, 24), 2020, 3, 7, 'July')
# (20200725, datetime.date(2020, 7, 25), 2020, 3, 7, 'July')
# (20200726, datetime.date(2020, 7, 26), 2020, 3, 7, 'July')
# (20200727, datetime.date(2020, 7, 27), 2020, 3, 7, 'July')
# (20200728, datetime.date(2020, 7, 28), 2020, 3, 7, 'July')
# (20200729, datetime.date(2020, 7, 29), 2020, 3, 7, 'July')
# (20200730, datetime.date(2020, 7, 30), 2020, 3, 7, 'July')
# (20200731, datetime.date(2020, 7, 31), 2020, 3, 7, 'July')
# (20200801, datetime.date(2020, 8, 1), 2020, 3, 8, 'August')
# (20200802, datetime.date(2020, 8, 2), 2020, 3, 8, 'August')
# (20200803, datetime.date(2020, 8, 3), 2020, 3, 8, 'August')
# (20200804, datetime.date(2020, 8, 4), 2020, 3, 8, 'August')
# (20200805, datetime.date(2020, 8, 5), 2020, 3, 8, 'August')
# (20200806, datetime.date(2020, 8, 6), 2020, 3, 8, 'August')
# (20200807, datetime.date(2020, 8, 7), 2020, 3, 8, 'August')
# (20200808, datetime.date(2020, 8, 8), 2020, 3, 8, 'August')
# (20200809, datetime.date(2020, 8, 9), 2020, 3, 8, 'August')
# (20200810, datetime.date(2020, 8, 10), 2020, 3, 8, 'August')
# (20200811, datetime.date(2020, 8, 11), 2020, 3, 8, 'August')
# (20200812, datetime.date(2020, 8, 12), 2020, 3, 8, 'August')
# (20200813, datetime.date(2020, 8, 13), 2020, 3, 8, 'August')
# (20200814, datetime.date(2020, 8, 14), 2020, 3, 8, 'August')
# (20200815, datetime.date(2020, 8, 15), 2020, 3, 8, 'August')
# (20200816, datetime.date(2020, 8, 16), 2020, 3, 8, 'August')
# (20200817, datetime.date(2020, 8, 17), 2020, 3, 8, 'August')
# (20200818, datetime.date(2020, 8, 18), 2020, 3, 8, 'August')
# (20200819, datetime.date(2020, 8, 19), 2020, 3, 8, 'August')
# (20200820, datetime.date(2020, 8, 20), 2020, 3, 8, 'August')
# (20200821, datetime.date(2020, 8, 21), 2020, 3, 8, 'August')
# (20200822, datetime.date(2020, 8, 22), 2020, 3, 8, 'August')
# (20200823, datetime.date(2020, 8, 23), 2020, 3, 8, 'August')
# (20200824, datetime.date(2020, 8, 24), 2020, 3, 8, 'August')
# (20200825, datetime.date(2020, 8, 25), 2020, 3, 8, 'August')
# (20200826, datetime.date(2020, 8, 26), 2020, 3, 8, 'August')
# (20200827, datetime.date(2020, 8, 27), 2020, 3, 8, 'August')
# (20200828, datetime.date(2020, 8, 28), 2020, 3, 8, 'August')
# (20200829, datetime.date(2020, 8, 29), 2020, 3, 8, 'August')
# (20200830, datetime.date(2020, 8, 30), 2020, 3, 8, 'August')
# (20200831, datetime.date(2020, 8, 31), 2020, 3, 8, 'August')
# (20200901, datetime.date(2020, 9, 1), 2020, 3, 9, 'September')
# (20200902, datetime.date(2020, 9, 2), 2020, 3, 9, 'September')
# (20200903, datetime.date(2020, 9, 3), 2020, 3, 9, 'September')
# (20200904, datetime.date(2020, 9, 4), 2020, 3, 9, 'September')
# (20200905, datetime.date(2020, 9, 5), 2020, 3, 9, 'September')
# (20200906, datetime.date(2020, 9, 6), 2020, 3, 9, 'September')
# (20200907, datetime.date(2020, 9, 7), 2020, 3, 9, 'September')
# (20200908, datetime.date(2020, 9, 8), 2020, 3, 9, 'September')
# (20200909, datetime.date(2020, 9, 9), 2020, 3, 9, 'September')
# (20200910, datetime.date(2020, 9, 10), 2020, 3, 9, 'September')
# (20200911, datetime.date(2020, 9, 11), 2020, 3, 9, 'September')
# (20200912, datetime.date(2020, 9, 12), 2020, 3, 9, 'September')
# (20200913, datetime.date(2020, 9, 13), 2020, 3, 9, 'September')
# (20200914, datetime.date(2020, 9, 14), 2020, 3, 9, 'September')
# (20200915, datetime.date(2020, 9, 15), 2020, 3, 9, 'September')
# (20200916, datetime.date(2020, 9, 16), 2020, 3, 9, 'September')
# (20200917, datetime.date(2020, 9, 17), 2020, 3, 9, 'September')
# (20200918, datetime.date(2020, 9, 18), 2020, 3, 9, 'September')
# (20200919, datetime.date(2020, 9, 19), 2020, 3, 9, 'September')
# (20200920, datetime.date(2020, 9, 20), 2020, 3, 9, 'September')
# (20200921, datetime.date(2020, 9, 21), 2020, 3, 9, 'September')
# (20200922, datetime.date(2020, 9, 22), 2020, 3, 9, 'September')
# (20200923, datetime.date(2020, 9, 23), 2020, 3, 9, 'September')
# (20200924, datetime.date(2020, 9, 24), 2020, 3, 9, 'September')
# (20200925, datetime.date(2020, 9, 25), 2020, 3, 9, 'September')
# (20200926, datetime.date(2020, 9, 26), 2020, 3, 9, 'September')
# (20200927, datetime.date(2020, 9, 27), 2020, 3, 9, 'September')
# (20200928, datetime.date(2020, 9, 28), 2020, 3, 9, 'September')
# (20200929, datetime.date(2020, 9, 29), 2020, 3, 9, 'September')
# (20200930, datetime.date(2020, 9, 30), 2020, 3, 9, 'September')
# (20201001, datetime.date(2020, 10, 1), 2020, 4, 10, 'October')
# (20201002, datetime.date(2020, 10, 2), 2020, 4, 10, 'October')
# (20201003, datetime.date(2020, 10, 3), 2020, 4, 10, 'October')
# (20201004, datetime.date(2020, 10, 4), 2020, 4, 10, 'October')
# (20201005, datetime.date(2020, 10, 5), 2020, 4, 10, 'October')
# (20201006, datetime.date(2020, 10, 6), 2020, 4, 10, 'October')
# (20201007, datetime.date(2020, 10, 7), 2020, 4, 10, 'October')
# (20201008, datetime.date(2020, 10, 8), 2020, 4, 10, 'October')
# (20201009, datetime.date(2020, 10, 9), 2020, 4, 10, 'October')
# (20201010, datetime.date(2020, 10, 10), 2020, 4, 10, 'October')
# (20201011, datetime.date(2020, 10, 11), 2020, 4, 10, 'October')
# (20201012, datetime.date(2020, 10, 12), 2020, 4, 10, 'October')
# (20201013, datetime.date(2020, 10, 13), 2020, 4, 10, 'October')
# (20201014, datetime.date(2020, 10, 14), 2020, 4, 10, 'October')
# (20201015, datetime.date(2020, 10, 15), 2020, 4, 10, 'October')
# (20201016, datetime.date(2020, 10, 16), 2020, 4, 10, 'October')
# (20201017, datetime.date(2020, 10, 17), 2020, 4, 10, 'October')
# (20201018, datetime.date(2020, 10, 18), 2020, 4, 10, 'October')
# (20201019, datetime.date(2020, 10, 19), 2020, 4, 10, 'October')
# (20201020, datetime.date(2020, 10, 20), 2020, 4, 10, 'October')
# (20201021, datetime.date(2020, 10, 21), 2020, 4, 10, 'October')
# (20201022, datetime.date(2020, 10, 22), 2020, 4, 10, 'October')
# (20201023, datetime.date(2020, 10, 23), 2020, 4, 10, 'October')
# (20201024, datetime.date(2020, 10, 24), 2020, 4, 10, 'October')
# (20201025, datetime.date(2020, 10, 25), 2020, 4, 10, 'October')
# (20201026, datetime.date(2020, 10, 26), 2020, 4, 10, 'October')
# (20201027, datetime.date(2020, 10, 27), 2020, 4, 10, 'October')
# (20201028, datetime.date(2020, 10, 28), 2020, 4, 10, 'October')
# (20201029, datetime.date(2020, 10, 29), 2020, 4, 10, 'October')
# (20201030, datetime.date(2020, 10, 30), 2020, 4, 10, 'October')
# (20201031, datetime.date(2020, 10, 31), 2020, 4, 10, 'October')
# (20201101, datetime.date(2020, 11, 1), 2020, 4, 11, 'November')
# (20201102, datetime.date(2020, 11, 2), 2020, 4, 11, 'November')
# (20201103, datetime.date(2020, 11, 3), 2020, 4, 11, 'November')
# (20201104, datetime.date(2020, 11, 4), 2020, 4, 11, 'November')
# (20201105, datetime.date(2020, 11, 5), 2020, 4, 11, 'November')
# (20201106, datetime.date(2020, 11, 6), 2020, 4, 11, 'November')
# (20201107, datetime.date(2020, 11, 7), 2020, 4, 11, 'November')
# (20201108, datetime.date(2020, 11, 8), 2020, 4, 11, 'November')
# (20201109, datetime.date(2020, 11, 9), 2020, 4, 11, 'November')
# (20201110, datetime.date(2020, 11, 10), 2020, 4, 11, 'November')
# (20201111, datetime.date(2020, 11, 11), 2020, 4, 11, 'November')
# (20201112, datetime.date(2020, 11, 12), 2020, 4, 11, 'November')
# (20201113, datetime.date(2020, 11, 13), 2020, 4, 11, 'November')
# (20201114, datetime.date(2020, 11, 14), 2020, 4, 11, 'November')
# (20201115, datetime.date(2020, 11, 15), 2020, 4, 11, 'November')
# (20201116, datetime.date(2020, 11, 16), 2020, 4, 11, 'November')
# (20201117, datetime.date(2020, 11, 17), 2020, 4, 11, 'November')
# (20201118, datetime.date(2020, 11, 18), 2020, 4, 11, 'November')
# (20201119, datetime.date(2020, 11, 19), 2020, 4, 11, 'November')
# (20201120, datetime.date(2020, 11, 20), 2020, 4, 11, 'November')
# (20201121, datetime.date(2020, 11, 21), 2020, 4, 11, 'November')
# (20201122, datetime.date(2020, 11, 22), 2020, 4, 11, 'November')
# (20201123, datetime.date(2020, 11, 23), 2020, 4, 11, 'November')
# (20201124, datetime.date(2020, 11, 24), 2020, 4, 11, 'November')
# (20201125, datetime.date(2020, 11, 25), 2020, 4, 11, 'November')
# (20201126, datetime.date(2020, 11, 26), 2020, 4, 11, 'November')
# (20201127, datetime.date(2020, 11, 27), 2020, 4, 11, 'November')
# (20201128, datetime.date(2020, 11, 28), 2020, 4, 11, 'November')
# (20201129, datetime.date(2020, 11, 29), 2020, 4, 11, 'November')
# (20201130, datetime.date(2020, 11, 30), 2020, 4, 11, 'November')
# (20201201, datetime.date(2020, 12, 1), 2020, 4, 12, 'December')
# (20201202, datetime.date(2020, 12, 2), 2020, 4, 12, 'December')
# (20201203, datetime.date(2020, 12, 3), 2020, 4, 12, 'December')
# (20201204, datetime.date(2020, 12, 4), 2020, 4, 12, 'December')
# (20201205, datetime.date(2020, 12, 5), 2020, 4, 12, 'December')
# (20201206, datetime.date(2020, 12, 6), 2020, 4, 12, 'December')
# (20201207, datetime.date(2020, 12, 7), 2020, 4, 12, 'December')
# (20201208, datetime.date(2020, 12, 8), 2020, 4, 12, 'December')
# (20201209, datetime.date(2020, 12, 9), 2020, 4, 12, 'December')
# (20201210, datetime.date(2020, 12, 10), 2020, 4, 12, 'December')
# (20201211, datetime.date(2020, 12, 11), 2020, 4, 12, 'December')
# (20201212, datetime.date(2020, 12, 12), 2020, 4, 12, 'December')
# (20201213, datetime.date(2020, 12, 13), 2020, 4, 12, 'December')
# (20201214, datetime.date(2020, 12, 14), 2020, 4, 12, 'December')
# (20201215, datetime.date(2020, 12, 15), 2020, 4, 12, 'December')
# (20201216, datetime.date(2020, 12, 16), 2020, 4, 12, 'December')
# (20201217, datetime.date(2020, 12, 17), 2020, 4, 12, 'December')
# (20201218, datetime.date(2020, 12, 18), 2020, 4, 12, 'December')
# (20201219, datetime.date(2020, 12, 19), 2020, 4, 12, 'December')
# (20201220, datetime.date(2020, 12, 20), 2020, 4, 12, 'December')
# (20201221, datetime.date(2020, 12, 21), 2020, 4, 12, 'December')
# (20201222, datetime.date(2020, 12, 22), 2020, 4, 12, 'December')
# (20201223, datetime.date(2020, 12, 23), 2020, 4, 12, 'December')
# (20201224, datetime.date(2020, 12, 24), 2020, 4, 12, 'December')
# (20201225, datetime.date(2020, 12, 25), 2020, 4, 12, 'December')
# (20201226, datetime.date(2020, 12, 26), 2020, 4, 12, 'December')
# (20201227, datetime.date(2020, 12, 27), 2020, 4, 12, 'December')
# (20201228, datetime.date(2020, 12, 28), 2020, 4, 12, 'December')
# (20201229, datetime.date(2020, 12, 29), 2020, 4, 12, 'December')
# (20201230, datetime.date(2020, 12, 30), 2020, 4, 12, 'December')
# (20201231, datetime.date(2020, 12, 31), 2020, 4, 12, 'December')
# (20210101, datetime.date(2021, 1, 1), 2021, 1, 1, 'January')
# (20210102, datetime.date(2021, 1, 2), 2021, 1, 1, 'January')
# (20210103, datetime.date(2021, 1, 3), 2021, 1, 1, 'January')
# (20210104, datetime.date(2021, 1, 4), 2021, 1, 1, 'January')
# (20210105, datetime.date(2021, 1, 5), 2021, 1, 1, 'January')
# (20210106, datetime.date(2021, 1, 6), 2021, 1, 1, 'January')
# (20210107, datetime.date(2021, 1, 7), 2021, 1, 1, 'January')
# (20210108, datetime.date(2021, 1, 8), 2021, 1, 1, 'January')
# (20210109, datetime.date(2021, 1, 9), 2021, 1, 1, 'January')
# (20210110, datetime.date(2021, 1, 10), 2021, 1, 1, 'January')
# (20210111, datetime.date(2021, 1, 11), 2021, 1, 1, 'January')
# (20210112, datetime.date(2021, 1, 12), 2021, 1, 1, 'January')
# (20210113, datetime.date(2021, 1, 13), 2021, 1, 1, 'January')
# (20210114, datetime.date(2021, 1, 14), 2021, 1, 1, 'January')
# (20210115, datetime.date(2021, 1, 15), 2021, 1, 1, 'January')
# (20210116, datetime.date(2021, 1, 16), 2021, 1, 1, 'January')
# (20210117, datetime.date(2021, 1, 17), 2021, 1, 1, 'January')
# (20210118, datetime.date(2021, 1, 18), 2021, 1, 1, 'January')
# (20210119, datetime.date(2021, 1, 19), 2021, 1, 1, 'January')
# (20210120, datetime.date(2021, 1, 20), 2021, 1, 1, 'January')
# (20210121, datetime.date(2021, 1, 21), 2021, 1, 1, 'January')
# (20210122, datetime.date(2021, 1, 22), 2021, 1, 1, 'January')
# (20210123, datetime.date(2021, 1, 23), 2021, 1, 1, 'January')
# (20210124, datetime.date(2021, 1, 24), 2021, 1, 1, 'January')
# (20210125, datetime.date(2021, 1, 25), 2021, 1, 1, 'January')
# (20210126, datetime.date(2021, 1, 26), 2021, 1, 1, 'January')
# (20210127, datetime.date(2021, 1, 27), 2021, 1, 1, 'January')
# (20210128, datetime.date(2021, 1, 28), 2021, 1, 1, 'January')
# (20210129, datetime.date(2021, 1, 29), 2021, 1, 1, 'January')
# (20210130, datetime.date(2021, 1, 30), 2021, 1, 1, 'January')
# (20210131, datetime.date(2021, 1, 31), 2021, 1, 1, 'January')
# (20210201, datetime.date(2021, 2, 1), 2021, 1, 2, 'February')
# (20210202, datetime.date(2021, 2, 2), 2021, 1, 2, 'February')
# (20210203, datetime.date(2021, 2, 3), 2021, 1, 2, 'February')
# (20210204, datetime.date(2021, 2, 4), 2021, 1, 2, 'February')
# (20210205, datetime.date(2021, 2, 5), 2021, 1, 2, 'February')
# (20210206, datetime.date(2021, 2, 6), 2021, 1, 2, 'February')
# (20210207, datetime.date(2021, 2, 7), 2021, 1, 2, 'February')
# (20210208, datetime.date(2021, 2, 8), 2021, 1, 2, 'February')
# (20210209, datetime.date(2021, 2, 9), 2021, 1, 2, 'February')
# (20210210, datetime.date(2021, 2, 10), 2021, 1, 2, 'February')
# (20210211, datetime.date(2021, 2, 11), 2021, 1, 2, 'February')
# (20210212, datetime.date(2021, 2, 12), 2021, 1, 2, 'February')
# (20210213, datetime.date(2021, 2, 13), 2021, 1, 2, 'February')
# (20210214, datetime.date(2021, 2, 14), 2021, 1, 2, 'February')
# (20210215, datetime.date(2021, 2, 15), 2021, 1, 2, 'February')
# (20210216, datetime.date(2021, 2, 16), 2021, 1, 2, 'February')
# (20210217, datetime.date(2021, 2, 17), 2021, 1, 2, 'February')
# (20210218, datetime.date(2021, 2, 18), 2021, 1, 2, 'February')
# (20210219, datetime.date(2021, 2, 19), 2021, 1, 2, 'February')
# (20210220, datetime.date(2021, 2, 20), 2021, 1, 2, 'February')
# (20210221, datetime.date(2021, 2, 21), 2021, 1, 2, 'February')
# (20210222, datetime.date(2021, 2, 22), 2021, 1, 2, 'February')
# (20210223, datetime.date(2021, 2, 23), 2021, 1, 2, 'February')
# (20210224, datetime.date(2021, 2, 24), 2021, 1, 2, 'February')
# (20210225, datetime.date(2021, 2, 25), 2021, 1, 2, 'February')
# (20210226, datetime.date(2021, 2, 26), 2021, 1, 2, 'February')
# (20210227, datetime.date(2021, 2, 27), 2021, 1, 2, 'February')
# (20210228, datetime.date(2021, 2, 28), 2021, 1, 2, 'February')
# (20210301, datetime.date(2021, 3, 1), 2021, 1, 3, 'March')
# (20210302, datetime.date(2021, 3, 2), 2021, 1, 3, 'March')
# (20210303, datetime.date(2021, 3, 3), 2021, 1, 3, 'March')
# (20210304, datetime.date(2021, 3, 4), 2021, 1, 3, 'March')
# (20210305, datetime.date(2021, 3, 5), 2021, 1, 3, 'March')
# (20210306, datetime.date(2021, 3, 6), 2021, 1, 3, 'March')
# (20210307, datetime.date(2021, 3, 7), 2021, 1, 3, 'March')
# (20210308, datetime.date(2021, 3, 8), 2021, 1, 3, 'March')
# (20210309, datetime.date(2021, 3, 9), 2021, 1, 3, 'March')
# (20210310, datetime.date(2021, 3, 10), 2021, 1, 3, 'March')
# (20210311, datetime.date(2021, 3, 11), 2021, 1, 3, 'March')
# (20210312, datetime.date(2021, 3, 12), 2021, 1, 3, 'March')
# (20210313, datetime.date(2021, 3, 13), 2021, 1, 3, 'March')
# (20210314, datetime.date(2021, 3, 14), 2021, 1, 3, 'March')
# (20210315, datetime.date(2021, 3, 15), 2021, 1, 3, 'March')
# (20210316, datetime.date(2021, 3, 16), 2021, 1, 3, 'March')
# (20210317, datetime.date(2021, 3, 17), 2021, 1, 3, 'March')
# (20210318, datetime.date(2021, 3, 18), 2021, 1, 3, 'March')
# (20210319, datetime.date(2021, 3, 19), 2021, 1, 3, 'March')
# (20210320, datetime.date(2021, 3, 20), 2021, 1, 3, 'March')
# (20210321, datetime.date(2021, 3, 21), 2021, 1, 3, 'March')
# (20210322, datetime.date(2021, 3, 22), 2021, 1, 3, 'March')
# (20210323, datetime.date(2021, 3, 23), 2021, 1, 3, 'March')
# (20210324, datetime.date(2021, 3, 24), 2021, 1, 3, 'March')
# (20210325, datetime.date(2021, 3, 25), 2021, 1, 3, 'March')
# (20210326, datetime.date(2021, 3, 26), 2021, 1, 3, 'March')
# (20210327, datetime.date(2021, 3, 27), 2021, 1, 3, 'March')
# (20210328, datetime.date(2021, 3, 28), 2021, 1, 3, 'March')
# (20210329, datetime.date(2021, 3, 29), 2021, 1, 3, 'March')
# (20210330, datetime.date(2021, 3, 30), 2021, 1, 3, 'March')
# (20210331, datetime.date(2021, 3, 31), 2021, 1, 3, 'March')
# (20210401, datetime.date(2021, 4, 1), 2021, 2, 4, 'April')
# (20210402, datetime.date(2021, 4, 2), 2021, 2, 4, 'April')
# (20210403, datetime.date(2021, 4, 3), 2021, 2, 4, 'April')
# (20210404, datetime.date(2021, 4, 4), 2021, 2, 4, 'April')
# (20210405, datetime.date(2021, 4, 5), 2021, 2, 4, 'April')
# (20210406, datetime.date(2021, 4, 6), 2021, 2, 4, 'April')
# (20210407, datetime.date(2021, 4, 7), 2021, 2, 4, 'April')
# (20210408, datetime.date(2021, 4, 8), 2021, 2, 4, 'April')
# (20210409, datetime.date(2021, 4, 9), 2021, 2, 4, 'April')
# (20210410, datetime.date(2021, 4, 10), 2021, 2, 4, 'April')
# (20210411, datetime.date(2021, 4, 11), 2021, 2, 4, 'April')
# (20210412, datetime.date(2021, 4, 12), 2021, 2, 4, 'April')
# (20210413, datetime.date(2021, 4, 13), 2021, 2, 4, 'April')
# (20210414, datetime.date(2021, 4, 14), 2021, 2, 4, 'April')
# (20210415, datetime.date(2021, 4, 15), 2021, 2, 4, 'April')
# (20210416, datetime.date(2021, 4, 16), 2021, 2, 4, 'April')
# (20210417, datetime.date(2021, 4, 17), 2021, 2, 4, 'April')
# (20210418, datetime.date(2021, 4, 18), 2021, 2, 4, 'April')
# (20210419, datetime.date(2021, 4, 19), 2021, 2, 4, 'April')
# (20210420, datetime.date(2021, 4, 20), 2021, 2, 4, 'April')
# (20210421, datetime.date(2021, 4, 21), 2021, 2, 4, 'April')
# (20210422, datetime.date(2021, 4, 22), 2021, 2, 4, 'April')
# (20210423, datetime.date(2021, 4, 23), 2021, 2, 4, 'April')
# (20210424, datetime.date(2021, 4, 24), 2021, 2, 4, 'April')
# (20210425, datetime.date(2021, 4, 25), 2021, 2, 4, 'April')
# (20210426, datetime.date(2021, 4, 26), 2021, 2, 4, 'April')
# (20210427, datetime.date(2021, 4, 27), 2021, 2, 4, 'April')
# (20210428, datetime.date(2021, 4, 28), 2021, 2, 4, 'April')
# (20210429, datetime.date(2021, 4, 29), 2021, 2, 4, 'April')
# (20210430, datetime.date(2021, 4, 30), 2021, 2, 4, 'April')
# (20210501, datetime.date(2021, 5, 1), 2021, 2, 5, 'May')
# (20210502, datetime.date(2021, 5, 2), 2021, 2, 5, 'May')
# (20210503, datetime.date(2021, 5, 3), 2021, 2, 5, 'May')
# (20210504, datetime.date(2021, 5, 4), 2021, 2, 5, 'May')
# (20210505, datetime.date(2021, 5, 5), 2021, 2, 5, 'May')
# (20210506, datetime.date(2021, 5, 6), 2021, 2, 5, 'May')
# (20210507, datetime.date(2021, 5, 7), 2021, 2, 5, 'May')
# (20210508, datetime.date(2021, 5, 8), 2021, 2, 5, 'May')
# (20210509, datetime.date(2021, 5, 9), 2021, 2, 5, 'May')
# (20210510, datetime.date(2021, 5, 10), 2021, 2, 5, 'May')
# (20210511, datetime.date(2021, 5, 11), 2021, 2, 5, 'May')
# (20210512, datetime.date(2021, 5, 12), 2021, 2, 5, 'May')
# (20210513, datetime.date(2021, 5, 13), 2021, 2, 5, 'May')
# (20210514, datetime.date(2021, 5, 14), 2021, 2, 5, 'May')
# (20210515, datetime.date(2021, 5, 15), 2021, 2, 5, 'May')
# (20210516, datetime.date(2021, 5, 16), 2021, 2, 5, 'May')
# (20210517, datetime.date(2021, 5, 17), 2021, 2, 5, 'May')
# (20210518, datetime.date(2021, 5, 18), 2021, 2, 5, 'May')
# (20210519, datetime.date(2021, 5, 19), 2021, 2, 5, 'May')
# (20210520, datetime.date(2021, 5, 20), 2021, 2, 5, 'May')
# (20210521, datetime.date(2021, 5, 21), 2021, 2, 5, 'May')
# (20210522, datetime.date(2021, 5, 22), 2021, 2, 5, 'May')
# (20210523, datetime.date(2021, 5, 23), 2021, 2, 5, 'May')
# (20210524, datetime.date(2021, 5, 24), 2021, 2, 5, 'May')
# (20210525, datetime.date(2021, 5, 25), 2021, 2, 5, 'May')
# (20210526, datetime.date(2021, 5, 26), 2021, 2, 5, 'May')
# (20210527, datetime.date(2021, 5, 27), 2021, 2, 5, 'May')
# (20210528, datetime.date(2021, 5, 28), 2021, 2, 5, 'May')
# (20210529, datetime.date(2021, 5, 29), 2021, 2, 5, 'May')
# (20210530, datetime.date(2021, 5, 30), 2021, 2, 5, 'May')
# (20210531, datetime.date(2021, 5, 31), 2021, 2, 5, 'May')
# (20210601, datetime.date(2021, 6, 1), 2021, 2, 6, 'June')
# (20210602, datetime.date(2021, 6, 2), 2021, 2, 6, 'June')
# (20210603, datetime.date(2021, 6, 3), 2021, 2, 6, 'June')
# (20210604, datetime.date(2021, 6, 4), 2021, 2, 6, 'June')
# (20210605, datetime.date(2021, 6, 5), 2021, 2, 6, 'June')
# (20210606, datetime.date(2021, 6, 6), 2021, 2, 6, 'June')
# (20210607, datetime.date(2021, 6, 7), 2021, 2, 6, 'June')
# (20210608, datetime.date(2021, 6, 8), 2021, 2, 6, 'June')
# (20210609, datetime.date(2021, 6, 9), 2021, 2, 6, 'June')
# (20210610, datetime.date(2021, 6, 10), 2021, 2, 6, 'June')
# (20210611, datetime.date(2021, 6, 11), 2021, 2, 6, 'June')
# (20210612, datetime.date(2021, 6, 12), 2021, 2, 6, 'June')
# (20210613, datetime.date(2021, 6, 13), 2021, 2, 6, 'June')
# (20210614, datetime.date(2021, 6, 14), 2021, 2, 6, 'June')
# (20210615, datetime.date(2021, 6, 15), 2021, 2, 6, 'June')
# (20210616, datetime.date(2021, 6, 16), 2021, 2, 6, 'June')
# (20210617, datetime.date(2021, 6, 17), 2021, 2, 6, 'June')
# (20210618, datetime.date(2021, 6, 18), 2021, 2, 6, 'June')
# (20210619, datetime.date(2021, 6, 19), 2021, 2, 6, 'June')
# (20210620, datetime.date(2021, 6, 20), 2021, 2, 6, 'June')
# (20210621, datetime.date(2021, 6, 21), 2021, 2, 6, 'June')
# (20210622, datetime.date(2021, 6, 22), 2021, 2, 6, 'June')
# (20210623, datetime.date(2021, 6, 23), 2021, 2, 6, 'June')
# (20210624, datetime.date(2021, 6, 24), 2021, 2, 6, 'June')
# (20210625, datetime.date(2021, 6, 25), 2021, 2, 6, 'June')
# (20210626, datetime.date(2021, 6, 26), 2021, 2, 6, 'June')
# (20210627, datetime.date(2021, 6, 27), 2021, 2, 6, 'June')
# (20210628, datetime.date(2021, 6, 28), 2021, 2, 6, 'June')
# (20210629, datetime.date(2021, 6, 29), 2021, 2, 6, 'June')
# (20210630, datetime.date(2021, 6, 30), 2021, 2, 6, 'June')
# (20210701, datetime.date(2021, 7, 1), 2021, 3, 7, 'July')
# (20210702, datetime.date(2021, 7, 2), 2021, 3, 7, 'July')
# (20210703, datetime.date(2021, 7, 3), 2021, 3, 7, 'July')
# (20210704, datetime.date(2021, 7, 4), 2021, 3, 7, 'July')
# (20210705, datetime.date(2021, 7, 5), 2021, 3, 7, 'July')
# (20210706, datetime.date(2021, 7, 6), 2021, 3, 7, 'July')
# (20210707, datetime.date(2021, 7, 7), 2021, 3, 7, 'July')
# (20210708, datetime.date(2021, 7, 8), 2021, 3, 7, 'July')
# (20210709, datetime.date(2021, 7, 9), 2021, 3, 7, 'July')
# (20210710, datetime.date(2021, 7, 10), 2021, 3, 7, 'July')
# (20210711, datetime.date(2021, 7, 11), 2021, 3, 7, 'July')
# (20210712, datetime.date(2021, 7, 12), 2021, 3, 7, 'July')
# (20210713, datetime.date(2021, 7, 13), 2021, 3, 7, 'July')
# (20210714, datetime.date(2021, 7, 14), 2021, 3, 7, 'July')
# (20210715, datetime.date(2021, 7, 15), 2021, 3, 7, 'July')
# (20210716, datetime.date(2021, 7, 16), 2021, 3, 7, 'July')
# (20210717, datetime.date(2021, 7, 17), 2021, 3, 7, 'July')
# (20210718, datetime.date(2021, 7, 18), 2021, 3, 7, 'July')
# (20210719, datetime.date(2021, 7, 19), 2021, 3, 7, 'July')
# (20210720, datetime.date(2021, 7, 20), 2021, 3, 7, 'July')
# (20210721, datetime.date(2021, 7, 21), 2021, 3, 7, 'July')
# (20210722, datetime.date(2021, 7, 22), 2021, 3, 7, 'July')
# (20210723, datetime.date(2021, 7, 23), 2021, 3, 7, 'July')
# (20210724, datetime.date(2021, 7, 24), 2021, 3, 7, 'July')
# (20210725, datetime.date(2021, 7, 25), 2021, 3, 7, 'July')
# (20210726, datetime.date(2021, 7, 26), 2021, 3, 7, 'July')
# (20210727, datetime.date(2021, 7, 27), 2021, 3, 7, 'July')
# (20210728, datetime.date(2021, 7, 28), 2021, 3, 7, 'July')
# (20210729, datetime.date(2021, 7, 29), 2021, 3, 7, 'July')
# (20210730, datetime.date(2021, 7, 30), 2021, 3, 7, 'July')
# (20210731, datetime.date(2021, 7, 31), 2021, 3, 7, 'July')
# (20210801, datetime.date(2021, 8, 1), 2021, 3, 8, 'August')
# (20210802, datetime.date(2021, 8, 2), 2021, 3, 8, 'August')
# (20210803, datetime.date(2021, 8, 3), 2021, 3, 8, 'August')
# (20210804, datetime.date(2021, 8, 4), 2021, 3, 8, 'August')
# (20210805, datetime.date(2021, 8, 5), 2021, 3, 8, 'August')
# (20210806, datetime.date(2021, 8, 6), 2021, 3, 8, 'August')
# (20210807, datetime.date(2021, 8, 7), 2021, 3, 8, 'August')
# (20210808, datetime.date(2021, 8, 8), 2021, 3, 8, 'August')
# (20210809, datetime.date(2021, 8, 9), 2021, 3, 8, 'August')
# (20210810, datetime.date(2021, 8, 10), 2021, 3, 8, 'August')
# (20210811, datetime.date(2021, 8, 11), 2021, 3, 8, 'August')
# (20210812, datetime.date(2021, 8, 12), 2021, 3, 8, 'August')
# (20210813, datetime.date(2021, 8, 13), 2021, 3, 8, 'August')
# (20210814, datetime.date(2021, 8, 14), 2021, 3, 8, 'August')
# (20210815, datetime.date(2021, 8, 15), 2021, 3, 8, 'August')
# (20210816, datetime.date(2021, 8, 16), 2021, 3, 8, 'August')
# (20210817, datetime.date(2021, 8, 17), 2021, 3, 8, 'August')
# (20210818, datetime.date(2021, 8, 18), 2021, 3, 8, 'August')
# (20210819, datetime.date(2021, 8, 19), 2021, 3, 8, 'August')
# (20210820, datetime.date(2021, 8, 20), 2021, 3, 8, 'August')
# (20210821, datetime.date(2021, 8, 21), 2021, 3, 8, 'August')
# (20210822, datetime.date(2021, 8, 22), 2021, 3, 8, 'August')
# (20210823, datetime.date(2021, 8, 23), 2021, 3, 8, 'August')
# (20210824, datetime.date(2021, 8, 24), 2021, 3, 8, 'August')
# (20210825, datetime.date(2021, 8, 25), 2021, 3, 8, 'August')
# (20210826, datetime.date(2021, 8, 26), 2021, 3, 8, 'August')
# (20210827, datetime.date(2021, 8, 27), 2021, 3, 8, 'August')
# (20210828, datetime.date(2021, 8, 28), 2021, 3, 8, 'August')
# (20210829, datetime.date(2021, 8, 29), 2021, 3, 8, 'August')
# (20210830, datetime.date(2021, 8, 30), 2021, 3, 8, 'August')
# (20210831, datetime.date(2021, 8, 31), 2021, 3, 8, 'August')
# (20210901, datetime.date(2021, 9, 1), 2021, 3, 9, 'September')
# (20210902, datetime.date(2021, 9, 2), 2021, 3, 9, 'September')
# (20210903, datetime.date(2021, 9, 3), 2021, 3, 9, 'September')
# (20210904, datetime.date(2021, 9, 4), 2021, 3, 9, 'September')
# (20210905, datetime.date(2021, 9, 5), 2021, 3, 9, 'September')
# (20210906, datetime.date(2021, 9, 6), 2021, 3, 9, 'September')
# (20210907, datetime.date(2021, 9, 7), 2021, 3, 9, 'September')
# (20210908, datetime.date(2021, 9, 8), 2021, 3, 9, 'September')
# (20210909, datetime.date(2021, 9, 9), 2021, 3, 9, 'September')
# (20210910, datetime.date(2021, 9, 10), 2021, 3, 9, 'September')
# (20210911, datetime.date(2021, 9, 11), 2021, 3, 9, 'September')
# (20210912, datetime.date(2021, 9, 12), 2021, 3, 9, 'September')
# (20210913, datetime.date(2021, 9, 13), 2021, 3, 9, 'September')
# (20210914, datetime.date(2021, 9, 14), 2021, 3, 9, 'September')
# (20210915, datetime.date(2021, 9, 15), 2021, 3, 9, 'September')
# (20210916, datetime.date(2021, 9, 16), 2021, 3, 9, 'September')
# (20210917, datetime.date(2021, 9, 17), 2021, 3, 9, 'September')
# (20210918, datetime.date(2021, 9, 18), 2021, 3, 9, 'September')
# (20210919, datetime.date(2021, 9, 19), 2021, 3, 9, 'September')
# (20210920, datetime.date(2021, 9, 20), 2021, 3, 9, 'September')
# (20210921, datetime.date(2021, 9, 21), 2021, 3, 9, 'September')
# (20210922, datetime.date(2021, 9, 22), 2021, 3, 9, 'September')
# (20210923, datetime.date(2021, 9, 23), 2021, 3, 9, 'September')
# (20210924, datetime.date(2021, 9, 24), 2021, 3, 9, 'September')
# (20210925, datetime.date(2021, 9, 25), 2021, 3, 9, 'September')
# (20210926, datetime.date(2021, 9, 26), 2021, 3, 9, 'September')
# (20210927, datetime.date(2021, 9, 27), 2021, 3, 9, 'September')
# (20210928, datetime.date(2021, 9, 28), 2021, 3, 9, 'September')
# (20210929, datetime.date(2021, 9, 29), 2021, 3, 9, 'September')
# (20210930, datetime.date(2021, 9, 30), 2021, 3, 9, 'September')
# (20211001, datetime.date(2021, 10, 1), 2021, 4, 10, 'October')
# (20211002, datetime.date(2021, 10, 2), 2021, 4, 10, 'October')
# (20211003, datetime.date(2021, 10, 3), 2021, 4, 10, 'October')
# (20211004, datetime.date(2021, 10, 4), 2021, 4, 10, 'October')
# (20211005, datetime.date(2021, 10, 5), 2021, 4, 10, 'October')
# (20211006, datetime.date(2021, 10, 6), 2021, 4, 10, 'October')
# (20211007, datetime.date(2021, 10, 7), 2021, 4, 10, 'October')
# (20211008, datetime.date(2021, 10, 8), 2021, 4, 10, 'October')
# (20211009, datetime.date(2021, 10, 9), 2021, 4, 10, 'October')
# (20211010, datetime.date(2021, 10, 10), 2021, 4, 10, 'October')
# (20211011, datetime.date(2021, 10, 11), 2021, 4, 10, 'October')
# (20211012, datetime.date(2021, 10, 12), 2021, 4, 10, 'October')
# (20211013, datetime.date(2021, 10, 13), 2021, 4, 10, 'October')
# (20211014, datetime.date(2021, 10, 14), 2021, 4, 10, 'October')
# (20211015, datetime.date(2021, 10, 15), 2021, 4, 10, 'October')
# (20211016, datetime.date(2021, 10, 16), 2021, 4, 10, 'October')
# (20211017, datetime.date(2021, 10, 17), 2021, 4, 10, 'October')
# (20211018, datetime.date(2021, 10, 18), 2021, 4, 10, 'October')
# (20211019, datetime.date(2021, 10, 19), 2021, 4, 10, 'October')
# (20211020, datetime.date(2021, 10, 20), 2021, 4, 10, 'October')
# (20211021, datetime.date(2021, 10, 21), 2021, 4, 10, 'October')
# (20211022, datetime.date(2021, 10, 22), 2021, 4, 10, 'October')
# (20211023, datetime.date(2021, 10, 23), 2021, 4, 10, 'October')
# (20211024, datetime.date(2021, 10, 24), 2021, 4, 10, 'October')
# (20211025, datetime.date(2021, 10, 25), 2021, 4, 10, 'October')
# (20211026, datetime.date(2021, 10, 26), 2021, 4, 10, 'October')
# (20211027, datetime.date(2021, 10, 27), 2021, 4, 10, 'October')
# (20211028, datetime.date(2021, 10, 28), 2021, 4, 10, 'October')
# (20211029, datetime.date(2021, 10, 29), 2021, 4, 10, 'October')
# (20211030, datetime.date(2021, 10, 30), 2021, 4, 10, 'October')
# (20211031, datetime.date(2021, 10, 31), 2021, 4, 10, 'October')
# (20211101, datetime.date(2021, 11, 1), 2021, 4, 11, 'November')
# (20211102, datetime.date(2021, 11, 2), 2021, 4, 11, 'November')
# (20211103, datetime.date(2021, 11, 3), 2021, 4, 11, 'November')
# (20211104, datetime.date(2021, 11, 4), 2021, 4, 11, 'November')
# (20211105, datetime.date(2021, 11, 5), 2021, 4, 11, 'November')
# (20211106, datetime.date(2021, 11, 6), 2021, 4, 11, 'November')
# (20211107, datetime.date(2021, 11, 7), 2021, 4, 11, 'November')
# (20211108, datetime.date(2021, 11, 8), 2021, 4, 11, 'November')
# (20211109, datetime.date(2021, 11, 9), 2021, 4, 11, 'November')
# (20211110, datetime.date(2021, 11, 10), 2021, 4, 11, 'November')
# (20211111, datetime.date(2021, 11, 11), 2021, 4, 11, 'November')
# (20211112, datetime.date(2021, 11, 12), 2021, 4, 11, 'November')
# (20211113, datetime.date(2021, 11, 13), 2021, 4, 11, 'November')
# (20211114, datetime.date(2021, 11, 14), 2021, 4, 11, 'November')
# (20211115, datetime.date(2021, 11, 15), 2021, 4, 11, 'November')
# (20211116, datetime.date(2021, 11, 16), 2021, 4, 11, 'November')
# (20211117, datetime.date(2021, 11, 17), 2021, 4, 11, 'November')
# (20211118, datetime.date(2021, 11, 18), 2021, 4, 11, 'November')
# (20211119, datetime.date(2021, 11, 19), 2021, 4, 11, 'November')
# (20211120, datetime.date(2021, 11, 20), 2021, 4, 11, 'November')
# (20211121, datetime.date(2021, 11, 21), 2021, 4, 11, 'November')
# (20211122, datetime.date(2021, 11, 22), 2021, 4, 11, 'November')
# (20211123, datetime.date(2021, 11, 23), 2021, 4, 11, 'November')
# (20211124, datetime.date(2021, 11, 24), 2021, 4, 11, 'November')
# (20211125, datetime.date(2021, 11, 25), 2021, 4, 11, 'November')
# (20211126, datetime.date(2021, 11, 26), 2021, 4, 11, 'November')
# (20211127, datetime.date(2021, 11, 27), 2021, 4, 11, 'November')
# (20211128, datetime.date(2021, 11, 28), 2021, 4, 11, 'November')
# (20211129, datetime.date(2021, 11, 29), 2021, 4, 11, 'November')
# (20211130, datetime.date(2021, 11, 30), 2021, 4, 11, 'November')
# (20211201, datetime.date(2021, 12, 1), 2021, 4, 12, 'December')
# (20211202, datetime.date(2021, 12, 2), 2021, 4, 12, 'December')
# (20211203, datetime.date(2021, 12, 3), 2021, 4, 12, 'December')
# (20211204, datetime.date(2021, 12, 4), 2021, 4, 12, 'December')
# (20211205, datetime.date(2021, 12, 5), 2021, 4, 12, 'December')
# (20211206, datetime.date(2021, 12, 6), 2021, 4, 12, 'December')
# (20211207, datetime.date(2021, 12, 7), 2021, 4, 12, 'December')
# (20211208, datetime.date(2021, 12, 8), 2021, 4, 12, 'December')
# (20211209, datetime.date(2021, 12, 9), 2021, 4, 12, 'December')
# (20211210, datetime.date(2021, 12, 10), 2021, 4, 12, 'December')
# (20211211, datetime.date(2021, 12, 11), 2021, 4, 12, 'December')
# (20211212, datetime.date(2021, 12, 12), 2021, 4, 12, 'December')
# (20211213, datetime.date(2021, 12, 13), 2021, 4, 12, 'December')
# (20211214, datetime.date(2021, 12, 14), 2021, 4, 12, 'December')
# (20211215, datetime.date(2021, 12, 15), 2021, 4, 12, 'December')
# (20211216, datetime.date(2021, 12, 16), 2021, 4, 12, 'December')
# (20211217, datetime.date(2021, 12, 17), 2021, 4, 12, 'December')
# (20211218, datetime.date(2021, 12, 18), 2021, 4, 12, 'December')
# (20211219, datetime.date(2021, 12, 19), 2021, 4, 12, 'December')
# (20211220, datetime.date(2021, 12, 20), 2021, 4, 12, 'December')
# (20211221, datetime.date(2021, 12, 21), 2021, 4, 12, 'December')
# (20220203, datetime.date(2022, 2, 3), 2022, 1, 2, 'February')
# (20220204, datetime.date(2022, 2, 4), 2022, 1, 2, 'February')
# (20220205, datetime.date(2022, 2, 5), 2022, 1, 2, 'February')
# (20220206, datetime.date(2022, 2, 6), 2022, 1, 2, 'February')
# (20220207, datetime.date(2022, 2, 7), 2022, 1, 2, 'February')
# (20220208, datetime.date(2022, 2, 8), 2022, 1, 2, 'February')
# (20220209, datetime.date(2022, 2, 9), 2022, 1, 2, 'February')
# (20220210, datetime.date(2022, 2, 10), 2022, 1, 2, 'February')
# (20220211, datetime.date(2022, 2, 11), 2022, 1, 2, 'February')
# (20220212, datetime.date(2022, 2, 12), 2022, 1, 2, 'February')
# (20220213, datetime.date(2022, 2, 13), 2022, 1, 2, 'February')
# (20220214, datetime.date(2022, 2, 14), 2022, 1, 2, 'February')
# (20220215, datetime.date(2022, 2, 15), 2022, 1, 2, 'February')
# (20220216, datetime.date(2022, 2, 16), 2022, 1, 2, 'February')
# (20220217, datetime.date(2022, 2, 17), 2022, 1, 2, 'February')
# (20220218, datetime.date(2022, 2, 18), 2022, 1, 2, 'February')
# ...
# (20230416, datetime.date(2023, 4, 16), 2023, 2, 4, 'April')
# (20230417, datetime.date(2023, 4, 17), 2023, 2, 4, 'April')
# (20230418, datetime.date(2023, 4, 18), 2023, 2, 4, 'April')
# (20230419, datetime.date(2023, 4, 19), 2023, 2, 4, 'April')
# (20230420, datetime.date(2023, 4, 20), 2023, 2, 4, 'April')
# (20230421, datetime.date(2023, 4, 21), 2023, 2, 4, 'April')
# (20230422, datetime.date(2023, 4, 22), 2023, 2, 4, 'April')
# (20230423, datetime.date(2023, 4, 23), 2023, 2, 4, 'April')
# (20230424, datetime.date(2023, 4, 24), 2023, 2, 4, 'April')
# (20230425, datetime.date(2023, 4, 25), 2023, 2, 4, 'April')
# (20230426, datetime.date(2023, 4, 26), 2023, 2, 4, 'April')
# (20230427, datetime.date(2023, 4, 27), 2023, 2, 4, 'April')
# (20230428, datetime.date(2023, 4, 28), 2023, 2, 4, 'April')
# (20230429, datetime.date(2023, 4, 29), 2023, 2, 4, 'April')
# (20230430, datetime.date(2023, 4, 30), 2023, 2, 4, 'April')
# (20230501, datetime.date(2023, 5, 1), 2023, 2, 5, 'May')
# (20230502, datetime.date(2023, 5, 2), 2023, 2, 5, 'May')
# (20230503, datetime.date(2023, 5, 3), 2023, 2, 5, 'May')
# (20230504, datetime.date(2023, 5, 4), 2023, 2, 5, 'May')
# (20230505, datetime.date(2023, 5, 5), 2023, 2, 5, 'May')
# (20230506, datetime.date(2023, 5, 6), 2023, 2, 5, 'May')
# (20230507, datetime.date(2023, 5, 7), 2023, 2, 5, 'May')
# (20230508, datetime.date(2023, 5, 8), 2023, 2, 5, 'May')
# (20230509, datetime.date(2023, 5, 9), 2023, 2, 5, 'May')
# (20230510, datetime.date(2023, 5, 10), 2023, 2, 5, 'May')
# (20230511, datetime.date(2023, 5, 11), 2023, 2, 5, 'May')
# (20230512, datetime.date(2023, 5, 12), 2023, 2, 5, 'May')
# (20230513, datetime.date(2023, 5, 13), 2023, 2, 5, 'May')
# (20230514, datetime.date(2023, 5, 14), 2023, 2, 5, 'May')
# (20230515, datetime.date(2023, 5, 15), 2023, 2, 5, 'May')
# (20230516, datetime.date(2023, 5, 16), 2023, 2, 5, 'May')
# (20230517, datetime.date(2023, 5, 17), 2023, 2, 5, 'May')
# (20230518, datetime.date(2023, 5, 18), 2023, 2, 5, 'May')
# (20230519, datetime.date(2023, 5, 19), 2023, 2, 5, 'May')
# (20230520, datetime.date(2023, 5, 20), 2023, 2, 5, 'May')
# (20230521, datetime.date(2023, 5, 21), 2023, 2, 5, 'May')
# (20230522, datetime.date(2023, 5, 22), 2023, 2, 5, 'May')
# (20230523, datetime.date(2023, 5, 23), 2023, 2, 5, 'May')
# (20230524, datetime.date(2023, 5, 24), 2023, 2, 5, 'May')
# (20230525, datetime.date(2023, 5, 25), 2023, 2, 5, 'May')
# (20230526, datetime.date(2023, 5, 26), 2023, 2, 5, 'May')
# (20230527, datetime.date(2023, 5, 27), 2023, 2, 5, 'May')
# (20230528, datetime.date(2023, 5, 28), 2023, 2, 5, 'May')
# (20230529, datetime.date(2023, 5, 29), 2023, 2, 5, 'May')
# (20230530, datetime.date(2023, 5, 30), 2023, 2, 5, 'May')
# (20230531, datetime.date(2023, 5, 31), 2023, 2, 5, 'May')
# (20230601, datetime.date(2023, 6, 1), 2023, 2, 6, 'June')
# (20230602, datetime.date(2023, 6, 2), 2023, 2, 6, 'June')
# (20230603, datetime.date(2023, 6, 3), 2023, 2, 6, 'June')
# (20230604, datetime.date(2023, 6, 4), 2023, 2, 6, 'June')
# (20230605, datetime.date(2023, 6, 5), 2023, 2, 6, 'June')
# (20230606, datetime.date(2023, 6, 6), 2023, 2, 6, 'June')
# (20230607, datetime.date(2023, 6, 7), 2023, 2, 6, 'June')
# (20230608, datetime.date(2023, 6, 8), 2023, 2, 6, 'June')
# (20230609, datetime.date(2023, 6, 9), 2023, 2, 6, 'June')
# (20230610, datetime.date(2023, 6, 10), 2023, 2, 6, 'June')
# (20230611, datetime.date(2023, 6, 11), 2023, 2, 6, 'June')
# (20230612, datetime.date(2023, 6, 12), 2023, 2, 6, 'June')
# (20230613, datetime.date(2023, 6, 13), 2023, 2, 6, 'June')
# (20230614, datetime.date(2023, 6, 14), 2023, 2, 6, 'June')
# (20230615, datetime.date(2023, 6, 15), 2023, 2, 6, 'June')
# (20230616, datetime.date(2023, 6, 16), 2023, 2, 6, 'June')
# (20230617, datetime.date(2023, 6, 17), 2023, 2, 6, 'June')
# (20230618, datetime.date(2023, 6, 18), 2023, 2, 6, 'June')
# (20230619, datetime.date(2023, 6, 19), 2023, 2, 6, 'June')
# (20230620, datetime.date(2023, 6, 20), 2023, 2, 6, 'June')
# (20230621, datetime.date(2023, 6, 21), 2023, 2, 6, 'June')
# (20230622, datetime.date(2023, 6, 22), 2023, 2, 6, 'June')
# (20230623, datetime.date(2023, 6, 23), 2023, 2, 6, 'June')
# (20230624, datetime.date(2023, 6, 24), 2023, 2, 6, 'June')
# (20230625, datetime.date(2023, 6, 25), 2023, 2, 6, 'June')
# (20230626, datetime.date(2023, 6, 26), 2023, 2, 6, 'June')
# (20230627, datetime.date(2023, 6, 27), 2023, 2, 6, 'June')
# (20230628, datetime.date(2023, 6, 28), 2023, 2, 6, 'June')
# (20230629, datetime.date(2023, 6, 29), 2023, 2, 6, 'June')
# (20230630, datetime.date(2023, 6, 30), 2023, 2, 6, 'June')
# (20230701, datetime.date(2023, 7, 1), 2023, 3, 7, 'July')
# (20230702, datetime.date(2023, 7, 2), 2023, 3, 7, 'July')
# (20230703, datetime.date(2023, 7, 3), 2023, 3, 7, 'July')
# (20230704, datetime.date(2023, 7, 4), 2023, 3, 7, 'July')
# (20230705, datetime.date(2023, 7, 5), 2023, 3, 7, 'July')
# (20230706, datetime.date(2023, 7, 6), 2023, 3, 7, 'July')
# (20230707, datetime.date(2023, 7, 7), 2023, 3, 7, 'July')
# (20230708, datetime.date(2023, 7, 8), 2023, 3, 7, 'July')
# (20230709, datetime.date(2023, 7, 9), 2023, 3, 7, 'July')
# (20230710, datetime.date(2023, 7, 10), 2023, 3, 7, 'July')
# (20230711, datetime.date(2023, 7, 11), 2023, 3, 7, 'July')
# (20230712, datetime.date(2023, 7, 12), 2023, 3, 7, 'July')
# (20230713, datetime.date(2023, 7, 13), 2023, 3, 7, 'July')
# (20230714, datetime.date(2023, 7, 14), 2023, 3, 7, 'July')
# (20230715, datetime.date(2023, 7, 15), 2023, 3, 7, 'July')
# (20230716, datetime.date(2023, 7, 16), 2023, 3, 7, 'July')
# (20230717, datetime.date(2023, 7, 17), 2023, 3, 7, 'July')
# (20230718, datetime.date(2023, 7, 18), 2023, 3, 7, 'July')
# (20230719, datetime.date(2023, 7, 19), 2023, 3, 7, 'July')
# (20230720, datetime.date(2023, 7, 20), 2023, 3, 7, 'July')
# (20230721, datetime.date(2023, 7, 21), 2023, 3, 7, 'July')
# (20230722, datetime.date(2023, 7, 22), 2023, 3, 7, 'July')
# (20230723, datetime.date(2023, 7, 23), 2023, 3, 7, 'July')
# (20230724, datetime.date(2023, 7, 24), 2023, 3, 7, 'July')
# (20230725, datetime.date(2023, 7, 25), 2023, 3, 7, 'July')
# (20230726, datetime.date(2023, 7, 26), 2023, 3, 7, 'July')
# (20230727, datetime.date(2023, 7, 27), 2023, 3, 7, 'July')
# (20230728, datetime.date(2023, 7, 28), 2023, 3, 7, 'July')
# (20230729, datetime.date(2023, 7, 29), 2023, 3, 7, 'July')
# (20230730, datetime.date(2023, 7, 30), 2023, 3, 7, 'July')
# (20230731, datetime.date(2023, 7, 31), 2023, 3, 7, 'July')
# (20230801, datetime.date(2023, 8, 1), 2023, 3, 8, 'August')
# (20230802, datetime.date(2023, 8, 2), 2023, 3, 8, 'August')
# (20230803, datetime.date(2023, 8, 3), 2023, 3, 8, 'August')
# (20230804, datetime.date(2023, 8, 4), 2023, 3, 8, 'August')
# (20230805, datetime.date(2023, 8, 5), 2023, 3, 8, 'August')
# (20230806, datetime.date(2023, 8, 6), 2023, 3, 8, 'August')
# (20230807, datetime.date(2023, 8, 7), 2023, 3, 8, 'August')
# (20230808, datetime.date(2023, 8, 8), 2023, 3, 8, 'August')
# (20230809, datetime.date(2023, 8, 9), 2023, 3, 8, 'August')
# (20230810, datetime.date(2023, 8, 10), 2023, 3, 8, 'August')
# (20230811, datetime.date(2023, 8, 11), 2023, 3, 8, 'August')
# (20230812, datetime.date(2023, 8, 12), 2023, 3, 8, 'August')
# (20230813, datetime.date(2023, 8, 13), 2023, 3, 8, 'August')
# (20230814, datetime.date(2023, 8, 14), 2023, 3, 8, 'August')
# (20230815, datetime.date(2023, 8, 15), 2023, 3, 8, 'August')
# (20230816, datetime.date(2023, 8, 16), 2023, 3, 8, 'August')
# (20230817, datetime.date(2023, 8, 17), 2023, 3, 8, 'August')
# (20230818, datetime.date(2023, 8, 18), 2023, 3, 8, 'August')
# (20230819, datetime.date(2023, 8, 19), 2023, 3, 8, 'August')
# (20230820, datetime.date(2023, 8, 20), 2023, 3, 8, 'August')
# (20230821, datetime.date(2023, 8, 21), 2023, 3, 8, 'August')
# (20230822, datetime.date(2023, 8, 22), 2023, 3, 8, 'August')
# (20230823, datetime.date(2023, 8, 23), 2023, 3, 8, 'August')
# (20230824, datetime.date(2023, 8, 24), 2023, 3, 8, 'August')
# (20230825, datetime.date(2023, 8, 25), 2023, 3, 8, 'August')
# (20230826, datetime.date(2023, 8, 26), 2023, 3, 8, 'August')
# (20230827, datetime.date(2023, 8, 27), 2023, 3, 8, 'August')
# (20230828, datetime.date(2023, 8, 28), 2023, 3, 8, 'August')
# (20230829, datetime.date(2023, 8, 29), 2023, 3, 8, 'August')
# (20230830, datetime.date(2023, 8, 30), 2023, 3, 8, 'August')
# (20230831, datetime.date(2023, 8, 31), 2023, 3, 8, 'August')
# (20230901, datetime.date(2023, 9, 1), 2023, 3, 9, 'September')
# (20230902, datetime.date(2023, 9, 2), 2023, 3, 9, 'September')
# (20230903, datetime.date(2023, 9, 3), 2023, 3, 9, 'September')
# (20230904, datetime.date(2023, 9, 4), 2023, 3, 9, 'September')
# (20230905, datetime.date(2023, 9, 5), 2023, 3, 9, 'September')
# (20230906, datetime.date(2023, 9, 6), 2023, 3, 9, 'September')
# (20230907, datetime.date(2023, 9, 7), 2023, 3, 9, 'September')
# (20230908, datetime.date(2023, 9, 8), 2023, 3, 9, 'September')
# (20230909, datetime.date(2023, 9, 9), 2023, 3, 9, 'September')
# (20230910, datetime.date(2023, 9, 10), 2023, 3, 9, 'September')
# (20230911, datetime.date(2023, 9, 11), 2023, 3, 9, 'September')
# (20230912, datetime.date(2023, 9, 12), 2023, 3, 9, 'September')
# (20230913, datetime.date(2023, 9, 13), 2023, 3, 9, 'September')
# (20230914, datetime.date(2023, 9, 14), 2023, 3, 9, 'September')
# (20230915, datetime.date(2023, 9, 15), 2023, 3, 9, 'September')
# (20230916, datetime.date(2023, 9, 16), 2023, 3, 9, 'September')
# (20230917, datetime.date(2023, 9, 17), 2023, 3, 9, 'September')
# (20230918, datetime.date(2023, 9, 18), 2023, 3, 9, 'September')
# (20230919, datetime.date(2023, 9, 19), 2023, 3, 9, 'September')
# (20230920, datetime.date(2023, 9, 20), 2023, 3, 9, 'September')
# (20230921, datetime.date(2023, 9, 21), 2023, 3, 9, 'September')
# (20230922, datetime.date(2023, 9, 22), 2023, 3, 9, 'September')
# (20230923, datetime.date(2023, 9, 23), 2023, 3, 9, 'September')
# (20230924, datetime.date(2023, 9, 24), 2023, 3, 9, 'September')
# (20230925, datetime.date(2023, 9, 25), 2023, 3, 9, 'September')
# (20230926, datetime.date(2023, 9, 26), 2023, 3, 9, 'September')
# (20230927, datetime.date(2023, 9, 27), 2023, 3, 9, 'September')
# (20230928, datetime.date(2023, 9, 28), 2023, 3, 9, 'September')
# (20230929, datetime.date(2023, 9, 29), 2023, 3, 9, 'September')
# (20230930, datetime.date(2023, 9, 30), 2023, 3, 9, 'September')
# (20231001, datetime.date(2023, 10, 1), 2023, 4, 10, 'October')
# (20231002, datetime.date(2023, 10, 2), 2023, 4, 10, 'October')
# (20231003, datetime.date(2023, 10, 3), 2023, 4, 10, 'October')
# (20231004, datetime.date(2023, 10, 4), 2023, 4, 10, 'October')
# (20231005, datetime.date(2023, 10, 5), 2023, 4, 10, 'October')
# (20231006, datetime.date(2023, 10, 6), 2023, 4, 10, 'October')
# (20231007, datetime.date(2023, 10, 7), 2023, 4, 10, 'October')
# (20231008, datetime.date(2023, 10, 8), 2023, 4, 10, 'October')
# (20231009, datetime.date(2023, 10, 9), 2023, 4, 10, 'October')
# (20231010, datetime.date(2023, 10, 10), 2023, 4, 10, 'October')
# (20231011, datetime.date(2023, 10, 11), 2023, 4, 10, 'October')
# (20231012, datetime.date(2023, 10, 12), 2023, 4, 10, 'October')
# (20231013, datetime.date(2023, 10, 13), 2023, 4, 10, 'October')
# (20231014, datetime.date(2023, 10, 14), 2023, 4, 10, 'October')
# (20231015, datetime.date(2023, 10, 15), 2023, 4, 10, 'October')
# (20231016, datetime.date(2023, 10, 16), 2023, 4, 10, 'October')
# (20231017, datetime.date(2023, 10, 17), 2023, 4, 10, 'October')
# (20231018, datetime.date(2023, 10, 18), 2023, 4, 10, 'October')
# (20231019, datetime.date(2023, 10, 19), 2023, 4, 10, 'October')
# (20231020, datetime.date(2023, 10, 20), 2023, 4, 10, 'October')
# (20231021, datetime.date(2023, 10, 21), 2023, 4, 10, 'October')
# (20231022, datetime.date(2023, 10, 22), 2023, 4, 10, 'October')
# (20231023, datetime.date(2023, 10, 23), 2023, 4, 10, 'October')
# (20231024, datetime.date(2023, 10, 24), 2023, 4, 10, 'October')
# (20231025, datetime.date(2023, 10, 25), 2023, 4, 10, 'October')
# (20231026, datetime.date(2023, 10, 26), 2023, 4, 10, 'October')
# (20231027, datetime.date(2023, 10, 27), 2023, 4, 10, 'October')
# (20231028, datetime.date(2023, 10, 28), 2023, 4, 10, 'October')
# (20231029, datetime.date(2023, 10, 29), 2023, 4, 10, 'October')
# (20231030, datetime.date(2023, 10, 30), 2023, 4, 10, 'October')
# (20231031, datetime.date(2023, 10, 31), 2023, 4, 10, 'October')
# (20231101, datetime.date(2023, 11, 1), 2023, 4, 11, 'November')
# (20231102, datetime.date(2023, 11, 2), 2023, 4, 11, 'November')
# (20231103, datetime.date(2023, 11, 3), 2023, 4, 11, 'November')
# (20231104, datetime.date(2023, 11, 4), 2023, 4, 11, 'November')
# (20231105, datetime.date(2023, 11, 5), 2023, 4, 11, 'November')
# (20231106, datetime.date(2023, 11, 6), 2023, 4, 11, 'November')
# (20231107, datetime.date(2023, 11, 7), 2023, 4, 11, 'November')
# (20231108, datetime.date(2023, 11, 8), 2023, 4, 11, 'November')
# (20231109, datetime.date(2023, 11, 9), 2023, 4, 11, 'November')
# (20231110, datetime.date(2023, 11, 10), 2023, 4, 11, 'November')
# (20231111, datetime.date(2023, 11, 11), 2023, 4, 11, 'November')
# (20231112, datetime.date(2023, 11, 12), 2023, 4, 11, 'November')
# (20231113, datetime.date(2023, 11, 13), 2023, 4, 11, 'November')
# (20231114, datetime.date(2023, 11, 14), 2023, 4, 11, 'November')
# (20231115, datetime.date(2023, 11, 15), 2023, 4, 11, 'November')
# (20231116, datetime.date(2023, 11, 16), 2023, 4, 11, 'November')
# (20231117, datetime.date(2023, 11, 17), 2023, 4, 11, 'November')
# (20231118, datetime.date(2023, 11, 18), 2023, 4, 11, 'November')
# (20231119, datetime.date(2023, 11, 19), 2023, 4, 11, 'November')
# (20231120, datetime.date(2023, 11, 20), 2023, 4, 11, 'November')
# (20231121, datetime.date(2023, 11, 21), 2023, 4, 11, 'November')
# (20231122, datetime.date(2023, 11, 22), 2023, 4, 11, 'November')
# (20231123, datetime.date(2023, 11, 23), 2023, 4, 11, 'November')
# (20231124, datetime.date(2023, 11, 24), 2023, 4, 11, 'November')
# (20231125, datetime.date(2023, 11, 25), 2023, 4, 11, 'November')
# (20231126, datetime.date(2023, 11, 26), 2023, 4, 11, 'November')
# (20231127, datetime.date(2023, 11, 27), 2023, 4, 11, 'November')
# (20231128, datetime.date(2023, 11, 28), 2023, 4, 11, 'November')
# (20231129, datetime.date(2023, 11, 29), 2023, 4, 11, 'November')
# (20231130, datetime.date(2023, 11, 30), 2023, 4, 11, 'November')
# (20231201, datetime.date(2023, 12, 1), 2023, 4, 12, 'December')
# (20231202, datetime.date(2023, 12, 2), 2023, 4, 12, 'December')
# (20231203, datetime.date(2023, 12, 3), 2023, 4, 12, 'December')
# (20231204, datetime.date(2023, 12, 4), 2023, 4, 12, 'December')
# (20231205, datetime.date(2023, 12, 5), 2023, 4, 12, 'December')
# (20231206, datetime.date(2023, 12, 6), 2023, 4, 12, 'December')
# (20231207, datetime.date(2023, 12, 7), 2023, 4, 12, 'December')
# (20231208, datetime.date(2023, 12, 8), 2023, 4, 12, 'December')
# (20231209, datetime.date(2023, 12, 9), 2023, 4, 12, 'December')
# (20231210, datetime.date(2023, 12, 10), 2023, 4, 12, 'December')
# (20231211, datetime.date(2023, 12, 11), 2023, 4, 12, 'December')
# (20231212, datetime.date(2023, 12, 12), 2023, 4, 12, 'December')
# (20231213, datetime.date(2023, 12, 13), 2023, 4, 12, 'December')
# (20231214, datetime.date(2023, 12, 14), 2023, 4, 12, 'December')
# (20231215, datetime.date(2023, 12, 15), 2023, 4, 12, 'December')
# (20231216, datetime.date(2023, 12, 16), 2023, 4, 12, 'December')
# (20231217, datetime.date(2023, 12, 17), 2023, 4, 12, 'December')
# (20231218, datetime.date(2023, 12, 18), 2023, 4, 12, 'December')
# (20231219, datetime.date(2023, 12, 19), 2023, 4, 12, 'December')
# (20231220, datetime.date(2023, 12, 20), 2023, 4, 12, 'December')
# (20231221, datetime.date(2023, 12, 21), 2023, 4, 12, 'December')
# (20231222, datetime.date(2023, 12, 22), 2023, 4, 12, 'December')
# (20231223, datetime.date(2023, 12, 23), 2023, 4, 12, 'December')
# (20231224, datetime.date(2023, 12, 24), 2023, 4, 12, 'December')
# (20231225, datetime.date(2023, 12, 25), 2023, 4, 12, 'December')
# (20231226, datetime.date(2023, 12, 26), 2023, 4, 12, 'December')
# (20231227, datetime.date(2023, 12, 27), 2023, 4, 12, 'December')
# (20231228, datetime.date(2023, 12, 28), 2023, 4, 12, 'December')
# (20231229, datetime.date(2023, 12, 29), 2023, 4, 12, 'December')
# (20231230, datetime.date(2023, 12, 30), 2023, 4, 12, 'December')
# (20231231, datetime.date(2023, 12, 31), 2023, 4, 12, 'December')

# %%
import pyodbc
from datetime import datetime, timedelta
import random

# إنشاء اتصال بقاعدة البيانات
def create_connection(server, database):
    connection_string = f"""
    DRIVER={{ODBC Driver 17 for SQL Server}};
    SERVER={server};
    DATABASE={database};
    Trusted_Connection=yes;
    """
    try:
        connection = pyodbc.connect(connection_string)
        print(f"Connected to {database} on {server} successfully!")
        return connection
    except pyodbc.Error as e:
        print(f"Error while connecting to database: {e}")
        return None


def generate_interaction_data(num_records):
    interaction_data = []
    start_date = datetime(2020, 1, 1)
    
    for i in range(1, num_records + 1):
        interaction_key = i
        interaction_id = i  
        interaction_date = start_date + timedelta(days=i)  
        
       
        customer_id = random.randint(1, 100)  
        
        interaction_type_id = random.randint(1, 5) 
        notes = f"Interaction note {i}"
        
        interaction_data.append([
            interaction_key,
            interaction_id,  
            customer_id,
            interaction_date.strftime("%Y-%m-%d"),
            interaction_type_id,
            notes
        ])
    
    return interaction_data


def load_interaction_data_to_dwh(connection, interaction_data):
    cursor = connection.cursor()
    
   
    cursor.execute("SET IDENTITY_INSERT dim_interaction ON")
    
    interaction_insert_query = """
    INSERT INTO dim_interaction (interaction_key, interaction_id, customer_id, interaction_date, interaction_type_id, notes)
    VALUES (?, ?, ?, ?, ?, ?)
    """
    
    cursor.executemany(interaction_insert_query, interaction_data)
    connection.commit()  
    
  
    cursor.execute("SET IDENTITY_INSERT dim_interaction OFF")
    connection.commit()  
    
    print(f"{len(interaction_data)} rows inserted successfully into dim_interaction!")

# التحقق من البيانات في جدول dim_interaction
def check_data_in_dim_interaction(connection):
    cursor = connection.cursor()
    cursor.execute("SELECT * FROM dim_interaction")
    rows = cursor.fetchall()
    for row in rows:
        print(row)

# تنفيذ العملية
if __name__ == "__main__":
    # اتصال بقاعدة البيانات
    dwh_conn = create_connection('DESKTOP-67E98DV', 'SalesDWH')
    
    # توليد بيانات التفاعل
    interaction_data = generate_interaction_data(1000)  # على سبيل المثال، إنشاء 1000 سجل
    
    # تحميل البيانات إلى جدول dim_interaction
    load_interaction_data_to_dwh(dwh_conn, interaction_data)
    
    # التحقق من البيانات في الجدول
    check_data_in_dim_interaction(dwh_conn)
    
    # إغلاق الاتصال
    dwh_conn.close()
# Out:
# Connected to SalesDWH on DESKTOP-67E98DV successfully!
# 1000 rows inserted successfully into dim_interaction!
# (1, 1, 9, datetime.date(2020, 1, 2), 4, 'Interaction note 1')
# (2, 2, 66, datetime.date(2020, 1, 3), 2, 'Interaction note 2')
# (3, 3, 52, datetime.date(2020, 1, 4), 3, 'Interaction note 3')
# (4, 4, 49, datetime.date(2020, 1, 5), 2, 'Interaction note 4')
# (5, 5, 25, datetime.date(2020, 1, 6), 1, 'Interaction note 5')
# (6, 6, 39, datetime.date(2020, 1, 7), 3, 'Interaction note 6')
# (7, 7, 22, datetime.date(2020, 1, 8), 3, 'Interaction note 7')
# (8, 8, 89, datetime.date(2020, 1, 9), 3, 'Interaction note 8')
# (9, 9, 65, datetime.date(2020, 1, 10), 4, 'Interaction note 9')
# (10, 10, 70, datetime.date(2020, 1, 11), 4, 'Interaction note 10')
# (11, 11, 81, datetime.date(2020, 1, 12), 2, 'Interaction note 11')
# (12, 12, 3, datetime.date(2020, 1, 13), 1, 'Interaction note 12')
# (13, 13, 75, datetime.date(2020, 1, 14), 3, 'Interaction note 13')
# (14, 14, 70, datetime.date(2020, 1, 15), 4, 'Interaction note 14')
# (15, 15, 31, datetime.date(2020, 1, 16), 5, 'Interaction note 15')
# (16, 16, 48, datetime.date(2020, 1, 17), 3, 'Interaction note 16')
# (17, 17, 22, datetime.date(2020, 1, 18), 2, 'Interaction note 17')
# (18, 18, 21, datetime.date(2020, 1, 19), 2, 'Interaction note 18')
# (19, 19, 82, datetime.date(2020, 1, 20), 2, 'Interaction note 19')
# (20, 20, 88, datetime.date(2020, 1, 21), 5, 'Interaction note 20')
# (21, 21, 94, datetime.date(2020, 1, 22), 4, 'Interaction note 21')
# (22, 22, 35, datetime.date(2020, 1, 23), 4, 'Interaction note 22')
# (23, 23, 16, datetime.date(2020, 1, 24), 3, 'Interaction note 23')
# (24, 24, 39, datetime.date(2020, 1, 25), 4, 'Interaction note 24')
# (25, 25, 56, datetime.date(2020, 1, 26), 3, 'Interaction note 25')
# (26, 26, 40, datetime.date(2020, 1, 27), 4, 'Interaction note 26')
# (27, 27, 68, datetime.date(2020, 1, 28), 5, 'Interaction note 27')
# (28, 28, 58, datetime.date(2020, 1, 29), 5, 'Interaction note 28')
# (29, 29, 99, datetime.date(2020, 1, 30), 2, 'Interaction note 29')
# (30, 30, 64, datetime.date(2020, 1, 31), 4, 'Interaction note 30')
# (31, 31, 38, datetime.date(2020, 2, 1), 4, 'Interaction note 31')
# (32, 32, 62, datetime.date(2020, 2, 2), 5, 'Interaction note 32')
# (33, 33, 78, datetime.date(2020, 2, 3), 4, 'Interaction note 33')
# (34, 34, 90, datetime.date(2020, 2, 4), 2, 'Interaction note 34')
# (35, 35, 20, datetime.date(2020, 2, 5), 5, 'Interaction note 35')
# (36, 36, 36, datetime.date(2020, 2, 6), 1, 'Interaction note 36')
# (37, 37, 73, datetime.date(2020, 2, 7), 3, 'Interaction note 37')
# (38, 38, 60, datetime.date(2020, 2, 8), 1, 'Interaction note 38')
# (39, 39, 52, datetime.date(2020, 2, 9), 1, 'Interaction note 39')
# (40, 40, 31, datetime.date(2020, 2, 10), 4, 'Interaction note 40')
# (41, 41, 88, datetime.date(2020, 2, 11), 3, 'Interaction note 41')
# (42, 42, 49, datetime.date(2020, 2, 12), 2, 'Interaction note 42')
# (43, 43, 79, datetime.date(2020, 2, 13), 2, 'Interaction note 43')
# (44, 44, 42, datetime.date(2020, 2, 14), 2, 'Interaction note 44')
# (45, 45, 37, datetime.date(2020, 2, 15), 4, 'Interaction note 45')
# (46, 46, 74, datetime.date(2020, 2, 16), 5, 'Interaction note 46')
# (47, 47, 35, datetime.date(2020, 2, 17), 1, 'Interaction note 47')
# (48, 48, 6, datetime.date(2020, 2, 18), 3, 'Interaction note 48')
# (49, 49, 62, datetime.date(2020, 2, 19), 2, 'Interaction note 49')
# (50, 50, 5, datetime.date(2020, 2, 20), 5, 'Interaction note 50')
# (51, 51, 55, datetime.date(2020, 2, 21), 5, 'Interaction note 51')
# (52, 52, 54, datetime.date(2020, 2, 22), 1, 'Interaction note 52')
# (53, 53, 7, datetime.date(2020, 2, 23), 5, 'Interaction note 53')
# (54, 54, 41, datetime.date(2020, 2, 24), 1, 'Interaction note 54')
# (55, 55, 63, datetime.date(2020, 2, 25), 4, 'Interaction note 55')
# (56, 56, 1, datetime.date(2020, 2, 26), 2, 'Interaction note 56')
# (57, 57, 38, datetime.date(2020, 2, 27), 3, 'Interaction note 57')
# (58, 58, 96, datetime.date(2020, 2, 28), 3, 'Interaction note 58')
# (59, 59, 86, datetime.date(2020, 2, 29), 2, 'Interaction note 59')
# (60, 60, 68, datetime.date(2020, 3, 1), 3, 'Interaction note 60')
# (61, 61, 13, datetime.date(2020, 3, 2), 3, 'Interaction note 61')
# (62, 62, 24, datetime.date(2020, 3, 3), 4, 'Interaction note 62')
# (63, 63, 39, datetime.date(2020, 3, 4), 1, 'Interaction note 63')
# (64, 64, 94, datetime.date(2020, 3, 5), 5, 'Interaction note 64')
# (65, 65, 39, datetime.date(2020, 3, 6), 2, 'Interaction note 65')
# (66, 66, 56, datetime.date(2020, 3, 7), 2, 'Interaction note 66')
# (67, 67, 26, datetime.date(2020, 3, 8), 4, 'Interaction note 67')
# (68, 68, 83, datetime.date(2020, 3, 9), 4, 'Interaction note 68')
# (69, 69, 24, datetime.date(2020, 3, 10), 1, 'Interaction note 69')
# (70, 70, 40, datetime.date(2020, 3, 11), 3, 'Interaction note 70')
# (71, 71, 37, datetime.date(2020, 3, 12), 1, 'Interaction note 71')
# (72, 72, 32, datetime.date(2020, 3, 13), 2, 'Interaction note 72')
# (73, 73, 46, datetime.date(2020, 3, 14), 2, 'Interaction note 73')
# (74, 74, 27, datetime.date(2020, 3, 15), 3, 'Interaction note 74')
# (75, 75, 74, datetime.date(2020, 3, 16), 4, 'Interaction note 75')
# (76, 76, 65, datetime.date(2020, 3, 17), 5, 'Interaction note 76')
# (77, 77, 91, datetime.date(2020, 3, 18), 3, 'Interaction note 77')
# (78, 78, 76, datetime.date(2020, 3, 19), 5, 'Interaction note 78')
# (79, 79, 83, datetime.date(2020, 3, 20), 5, 'Interaction note 79')
# (80, 80, 25, datetime.date(2020, 3, 21), 3, 'Interaction note 80')
# (81, 81, 22, datetime.date(2020, 3, 22), 5, 'Interaction note 81')
# (82, 82, 25, datetime.date(2020, 3, 23), 4, 'Interaction note 82')
# (83, 83, 7, datetime.date(2020, 3, 24), 1, 'Interaction note 83')
# (84, 84, 66, datetime.date(2020, 3, 25), 5, 'Interaction note 84')
# (85, 85, 66, datetime.date(2020, 3, 26), 5, 'Interaction note 85')
# (86, 86, 58, datetime.date(2020, 3, 27), 4, 'Interaction note 86')
# (87, 87, 56, datetime.date(2020, 3, 28), 3, 'Interaction note 87')
# (88, 88, 77, datetime.date(2020, 3, 29), 3, 'Interaction note 88')
# (89, 89, 42, datetime.date(2020, 3, 30), 5, 'Interaction note 89')
# (90, 90, 11, datetime.date(2020, 3, 31), 1, 'Interaction note 90')
# (91, 91, 11, datetime.date(2020, 4, 1), 1, 'Interaction note 91')
# (92, 92, 95, datetime.date(2020, 4, 2), 2, 'Interaction note 92')
# (93, 93, 95, datetime.date(2020, 4, 3), 4, 'Interaction note 93')
# (94, 94, 92, datetime.date(2020, 4, 4), 5, 'Interaction note 94')
# (95, 95, 94, datetime.date(2020, 4, 5), 2, 'Interaction note 95')
# (96, 96, 43, datetime.date(2020, 4, 6), 5, 'Interaction note 96')
# (97, 97, 88, datetime.date(2020, 4, 7), 2, 'Interaction note 97')
# (98, 98, 53, datetime.date(2020, 4, 8), 2, 'Interaction note 98')
# (99, 99, 55, datetime.date(2020, 4, 9), 4, 'Interaction note 99')
# (100, 100, 38, datetime.date(2020, 4, 10), 1, 'Interaction note 100')
# (101, 101, 1, datetime.date(2020, 4, 11), 5, 'Interaction note 101')
# (102, 102, 19, datetime.date(2020, 4, 12), 1, 'Interaction note 102')
# (103, 103, 69, datetime.date(2020, 4, 13), 5, 'Interaction note 103')
# (104, 104, 56, datetime.date(2020, 4, 14), 3, 'Interaction note 104')
# (105, 105, 4, datetime.date(2020, 4, 15), 4, 'Interaction note 105')
# (106, 106, 89, datetime.date(2020, 4, 16), 1, 'Interaction note 106')
# (107, 107, 20, datetime.date(2020, 4, 17), 3, 'Interaction note 107')
# (108, 108, 75, datetime.date(2020, 4, 18), 2, 'Interaction note 108')
# (109, 109, 28, datetime.date(2020, 4, 19), 1, 'Interaction note 109')
# (110, 110, 82, datetime.date(2020, 4, 20), 2, 'Interaction note 110')
# (111, 111, 64, datetime.date(2020, 4, 21), 1, 'Interaction note 111')
# (112, 112, 12, datetime.date(2020, 4, 22), 3, 'Interaction note 112')
# (113, 113, 77, datetime.date(2020, 4, 23), 2, 'Interaction note 113')
# (114, 114, 6, datetime.date(2020, 4, 24), 2, 'Interaction note 114')
# (115, 115, 95, datetime.date(2020, 4, 25), 5, 'Interaction note 115')
# (116, 116, 41, datetime.date(2020, 4, 26), 4, 'Interaction note 116')
# (117, 117, 54, datetime.date(2020, 4, 27), 3, 'Interaction note 117')
# (118, 118, 92, datetime.date(2020, 4, 28), 2, 'Interaction note 118')
# (119, 119, 52, datetime.date(2020, 4, 29), 4, 'Interaction note 119')
# (120, 120, 5, datetime.date(2020, 4, 30), 2, 'Interaction note 120')
# (121, 121, 98, datetime.date(2020, 5, 1), 4, 'Interaction note 121')
# (122, 122, 39, datetime.date(2020, 5, 2), 5, 'Interaction note 122')
# (123, 123, 93, datetime.date(2020, 5, 3), 3, 'Interaction note 123')
# (124, 124, 19, datetime.date(2020, 5, 4), 4, 'Interaction note 124')
# (125, 125, 15, datetime.date(2020, 5, 5), 4, 'Interaction note 125')
# (126, 126, 24, datetime.date(2020, 5, 6), 4, 'Interaction note 126')
# (127, 127, 23, datetime.date(2020, 5, 7), 3, 'Interaction note 127')
# (128, 128, 38, datetime.date(2020, 5, 8), 4, 'Interaction note 128')
# (129, 129, 67, datetime.date(2020, 5, 9), 3, 'Interaction note 129')
# (130, 130, 29, datetime.date(2020, 5, 10), 4, 'Interaction note 130')
# (131, 131, 28, datetime.date(2020, 5, 11), 5, 'Interaction note 131')
# (132, 132, 61, datetime.date(2020, 5, 12), 4, 'Interaction note 132')
# (133, 133, 22, datetime.date(2020, 5, 13), 2, 'Interaction note 133')
# (134, 134, 43, datetime.date(2020, 5, 14), 5, 'Interaction note 134')
# (135, 135, 89, datetime.date(2020, 5, 15), 2, 'Interaction note 135')
# (136, 136, 41, datetime.date(2020, 5, 16), 4, 'Interaction note 136')
# (137, 137, 85, datetime.date(2020, 5, 17), 4, 'Interaction note 137')
# (138, 138, 38, datetime.date(2020, 5, 18), 5, 'Interaction note 138')
# (139, 139, 58, datetime.date(2020, 5, 19), 1, 'Interaction note 139')
# (140, 140, 53, datetime.date(2020, 5, 20), 3, 'Interaction note 140')
# (141, 141, 40, datetime.date(2020, 5, 21), 4, 'Interaction note 141')
# (142, 142, 6, datetime.date(2020, 5, 22), 5, 'Interaction note 142')
# (143, 143, 28, datetime.date(2020, 5, 23), 1, 'Interaction note 143')
# (144, 144, 33, datetime.date(2020, 5, 24), 2, 'Interaction note 144')
# (145, 145, 70, datetime.date(2020, 5, 25), 5, 'Interaction note 145')
# (146, 146, 25, datetime.date(2020, 5, 26), 1, 'Interaction note 146')
# (147, 147, 59, datetime.date(2020, 5, 27), 5, 'Interaction note 147')
# (148, 148, 53, datetime.date(2020, 5, 28), 1, 'Interaction note 148')
# (149, 149, 34, datetime.date(2020, 5, 29), 2, 'Interaction note 149')
# (150, 150, 15, datetime.date(2020, 5, 30), 1, 'Interaction note 150')
# (151, 151, 44, datetime.date(2020, 5, 31), 2, 'Interaction note 151')
# (152, 152, 19, datetime.date(2020, 6, 1), 4, 'Interaction note 152')
# (153, 153, 73, datetime.date(2020, 6, 2), 3, 'Interaction note 153')
# (154, 154, 59, datetime.date(2020, 6, 3), 5, 'Interaction note 154')
# (155, 155, 30, datetime.date(2020, 6, 4), 4, 'Interaction note 155')
# (156, 156, 60, datetime.date(2020, 6, 5), 5, 'Interaction note 156')
# (157, 157, 66, datetime.date(2020, 6, 6), 1, 'Interaction note 157')
# (158, 158, 65, datetime.date(2020, 6, 7), 3, 'Interaction note 158')
# (159, 159, 69, datetime.date(2020, 6, 8), 2, 'Interaction note 159')
# (160, 160, 68, datetime.date(2020, 6, 9), 3, 'Interaction note 160')
# (161, 161, 59, datetime.date(2020, 6, 10), 2, 'Interaction note 161')
# (162, 162, 76, datetime.date(2020, 6, 11), 3, 'Interaction note 162')
# (163, 163, 98, datetime.date(2020, 6, 12), 5, 'Interaction note 163')
# (164, 164, 69, datetime.date(2020, 6, 13), 5, 'Interaction note 164')
# (165, 165, 51, datetime.date(2020, 6, 14), 4, 'Interaction note 165')
# (166, 166, 6, datetime.date(2020, 6, 15), 5, 'Interaction note 166')
# (167, 167, 28, datetime.date(2020, 6, 16), 1, 'Interaction note 167')
# (168, 168, 11, datetime.date(2020, 6, 17), 2, 'Interaction note 168')
# (169, 169, 35, datetime.date(2020, 6, 18), 2, 'Interaction note 169')
# (170, 170, 48, datetime.date(2020, 6, 19), 1, 'Interaction note 170')
# (171, 171, 9, datetime.date(2020, 6, 20), 3, 'Interaction note 171')
# (172, 172, 98, datetime.date(2020, 6, 21), 1, 'Interaction note 172')
# (173, 173, 51, datetime.date(2020, 6, 22), 3, 'Interaction note 173')
# (174, 174, 54, datetime.date(2020, 6, 23), 2, 'Interaction note 174')
# (175, 175, 3, datetime.date(2020, 6, 24), 4, 'Interaction note 175')
# (176, 176, 46, datetime.date(2020, 6, 25), 5, 'Interaction note 176')
# (177, 177, 5, datetime.date(2020, 6, 26), 4, 'Interaction note 177')
# (178, 178, 99, datetime.date(2020, 6, 27), 5, 'Interaction note 178')
# (179, 179, 91, datetime.date(2020, 6, 28), 5, 'Interaction note 179')
# (180, 180, 88, datetime.date(2020, 6, 29), 5, 'Interaction note 180')
# (181, 181, 33, datetime.date(2020, 6, 30), 2, 'Interaction note 181')
# (182, 182, 1, datetime.date(2020, 7, 1), 2, 'Interaction note 182')
# (183, 183, 17, datetime.date(2020, 7, 2), 4, 'Interaction note 183')
# (184, 184, 48, datetime.date(2020, 7, 3), 1, 'Interaction note 184')
# (185, 185, 41, datetime.date(2020, 7, 4), 3, 'Interaction note 185')
# (186, 186, 13, datetime.date(2020, 7, 5), 4, 'Interaction note 186')
# (187, 187, 94, datetime.date(2020, 7, 6), 2, 'Interaction note 187')
# (188, 188, 30, datetime.date(2020, 7, 7), 3, 'Interaction note 188')
# (189, 189, 33, datetime.date(2020, 7, 8), 5, 'Interaction note 189')
# (190, 190, 62, datetime.date(2020, 7, 9), 1, 'Interaction note 190')
# (191, 191, 76, datetime.date(2020, 7, 10), 2, 'Interaction note 191')
# (192, 192, 15, datetime.date(2020, 7, 11), 2, 'Interaction note 192')
# (193, 193, 29, datetime.date(2020, 7, 12), 5, 'Interaction note 193')
# (194, 194, 47, datetime.date(2020, 7, 13), 1, 'Interaction note 194')
# (195, 195, 99, datetime.date(2020, 7, 14), 5, 'Interaction note 195')
# (196, 196, 88, datetime.date(2020, 7, 15), 1, 'Interaction note 196')
# (197, 197, 91, datetime.date(2020, 7, 16), 2, 'Interaction note 197')
# (198, 198, 54, datetime.date(2020, 7, 17), 5, 'Interaction note 198')
# (199, 199, 62, datetime.date(2020, 7, 18), 2, 'Interaction note 199')
# (200, 200, 65, datetime.date(2020, 7, 19), 3, 'Interaction note 200')
# (201, 201, 56, datetime.date(2020, 7, 20), 2, 'Interaction note 201')
# (202, 202, 22, datetime.date(2020, 7, 21), 4, 'Interaction note 202')
# (203, 203, 10, datetime.date(2020, 7, 22), 3, 'Interaction note 203')
# (204, 204, 82, datetime.date(2020, 7, 23), 2, 'Interaction note 204')
# (205, 205, 16, datetime.date(2020, 7, 24), 4, 'Interaction note 205')
# (206, 206, 20, datetime.date(2020, 7, 25), 2, 'Interaction note 206')
# (207, 207, 58, datetime.date(2020, 7, 26), 2, 'Interaction note 207')
# (208, 208, 35, datetime.date(2020, 7, 27), 5, 'Interaction note 208')
# (209, 209, 59, datetime.date(2020, 7, 28), 5, 'Interaction note 209')
# (210, 210, 67, datetime.date(2020, 7, 29), 4, 'Interaction note 210')
# (211, 211, 53, datetime.date(2020, 7, 30), 5, 'Interaction note 211')
# (212, 212, 24, datetime.date(2020, 7, 31), 2, 'Interaction note 212')
# (213, 213, 38, datetime.date(2020, 8, 1), 4, 'Interaction note 213')
# (214, 214, 38, datetime.date(2020, 8, 2), 4, 'Interaction note 214')
# (215, 215, 79, datetime.date(2020, 8, 3), 1, 'Interaction note 215')
# (216, 216, 13, datetime.date(2020, 8, 4), 1, 'Interaction note 216')
# (217, 217, 19, datetime.date(2020, 8, 5), 5, 'Interaction note 217')
# (218, 218, 24, datetime.date(2020, 8, 6), 2, 'Interaction note 218')
# (219, 219, 60, datetime.date(2020, 8, 7), 5, 'Interaction note 219')
# (220, 220, 76, datetime.date(2020, 8, 8), 3, 'Interaction note 220')
# (221, 221, 95, datetime.date(2020, 8, 9), 4, 'Interaction note 221')
# (222, 222, 22, datetime.date(2020, 8, 10), 3, 'Interaction note 222')
# (223, 223, 46, datetime.date(2020, 8, 11), 1, 'Interaction note 223')
# (224, 224, 68, datetime.date(2020, 8, 12), 1, 'Interaction note 224')
# (225, 225, 91, datetime.date(2020, 8, 13), 5, 'Interaction note 225')
# (226, 226, 67, datetime.date(2020, 8, 14), 1, 'Interaction note 226')
# (227, 227, 86, datetime.date(2020, 8, 15), 2, 'Interaction note 227')
# (228, 228, 4, datetime.date(2020, 8, 16), 3, 'Interaction note 228')
# (229, 229, 36, datetime.date(2020, 8, 17), 1, 'Interaction note 229')
# (230, 230, 95, datetime.date(2020, 8, 18), 2, 'Interaction note 230')
# (231, 231, 68, datetime.date(2020, 8, 19), 1, 'Interaction note 231')
# (232, 232, 39, datetime.date(2020, 8, 20), 4, 'Interaction note 232')
# (233, 233, 26, datetime.date(2020, 8, 21), 5, 'Interaction note 233')
# (234, 234, 59, datetime.date(2020, 8, 22), 2, 'Interaction note 234')
# (235, 235, 86, datetime.date(2020, 8, 23), 3, 'Interaction note 235')
# (236, 236, 59, datetime.date(2020, 8, 24), 2, 'Interaction note 236')
# (237, 237, 60, datetime.date(2020, 8, 25), 2, 'Interaction note 237')
# (238, 238, 43, datetime.date(2020, 8, 26), 1, 'Interaction note 238')
# (239, 239, 73, datetime.date(2020, 8, 27), 1, 'Interaction note 239')
# (240, 240, 41, datetime.date(2020, 8, 28), 2, 'Interaction note 240')
# (241, 241, 61, datetime.date(2020, 8, 29), 3, 'Interaction note 241')
# (242, 242, 10, datetime.date(2020, 8, 30), 2, 'Interaction note 242')
# (243, 243, 78, datetime.date(2020, 8, 31), 1, 'Interaction note 243')
# (244, 244, 77, datetime.date(2020, 9, 1), 5, 'Interaction note 244')
# (245, 245, 16, datetime.date(2020, 9, 2), 4, 'Interaction note 245')
# (246, 246, 47, datetime.date(2020, 9, 3), 4, 'Interaction note 246')
# (247, 247, 30, datetime.date(2020, 9, 4), 4, 'Interaction note 247')
# (248, 248, 3, datetime.date(2020, 9, 5), 3, 'Interaction note 248')
# (249, 249, 77, datetime.date(2020, 9, 6), 1, 'Interaction note 249')
# (250, 250, 92, datetime.date(2020, 9, 7), 2, 'Interaction note 250')
# (251, 251, 82, datetime.date(2020, 9, 8), 2, 'Interaction note 251')
# (252, 252, 20, datetime.date(2020, 9, 9), 4, 'Interaction note 252')
# (253, 253, 35, datetime.date(2020, 9, 10), 5, 'Interaction note 253')
# (254, 254, 84, datetime.date(2020, 9, 11), 1, 'Interaction note 254')
# (255, 255, 93, datetime.date(2020, 9, 12), 5, 'Interaction note 255')
# (256, 256, 47, datetime.date(2020, 9, 13), 2, 'Interaction note 256')
# (257, 257, 92, datetime.date(2020, 9, 14), 4, 'Interaction note 257')
# (258, 258, 71, datetime.date(2020, 9, 15), 4, 'Interaction note 258')
# (259, 259, 52, datetime.date(2020, 9, 16), 4, 'Interaction note 259')
# (260, 260, 30, datetime.date(2020, 9, 17), 4, 'Interaction note 260')
# (261, 261, 44, datetime.date(2020, 9, 18), 3, 'Interaction note 261')
# (262, 262, 81, datetime.date(2020, 9, 19), 2, 'Interaction note 262')
# (263, 263, 98, datetime.date(2020, 9, 20), 3, 'Interaction note 263')
# (264, 264, 19, datetime.date(2020, 9, 21), 3, 'Interaction note 264')
# (265, 265, 11, datetime.date(2020, 9, 22), 1, 'Interaction note 265')
# (266, 266, 91, datetime.date(2020, 9, 23), 5, 'Interaction note 266')
# (267, 267, 99, datetime.date(2020, 9, 24), 2, 'Interaction note 267')
# (268, 268, 91, datetime.date(2020, 9, 25), 2, 'Interaction note 268')
# (269, 269, 34, datetime.date(2020, 9, 26), 5, 'Interaction note 269')
# (270, 270, 41, datetime.date(2020, 9, 27), 3, 'Interaction note 270')
# (271, 271, 26, datetime.date(2020, 9, 28), 1, 'Interaction note 271')
# (272, 272, 4, datetime.date(2020, 9, 29), 4, 'Interaction note 272')
# (273, 273, 44, datetime.date(2020, 9, 30), 3, 'Interaction note 273')
# (274, 274, 91, datetime.date(2020, 10, 1), 3, 'Interaction note 274')
# (275, 275, 98, datetime.date(2020, 10, 2), 1, 'Interaction note 275')
# (276, 276, 9, datetime.date(2020, 10, 3), 1, 'Interaction note 276')
# (277, 277, 80, datetime.date(2020, 10, 4), 5, 'Interaction note 277')
# (278, 278, 91, datetime.date(2020, 10, 5), 5, 'Interaction note 278')
# (279, 279, 35, datetime.date(2020, 10, 6), 5, 'Interaction note 279')
# (280, 280, 42, datetime.date(2020, 10, 7), 1, 'Interaction note 280')
# (281, 281, 45, datetime.date(2020, 10, 8), 2, 'Interaction note 281')
# (282, 282, 76, datetime.date(2020, 10, 9), 1, 'Interaction note 282')
# (283, 283, 92, datetime.date(2020, 10, 10), 2, 'Interaction note 283')
# (284, 284, 29, datetime.date(2020, 10, 11), 2, 'Interaction note 284')
# (285, 285, 75, datetime.date(2020, 10, 12), 5, 'Interaction note 285')
# (286, 286, 38, datetime.date(2020, 10, 13), 2, 'Interaction note 286')
# (287, 287, 24, datetime.date(2020, 10, 14), 3, 'Interaction note 287')
# (288, 288, 96, datetime.date(2020, 10, 15), 1, 'Interaction note 288')
# (289, 289, 78, datetime.date(2020, 10, 16), 5, 'Interaction note 289')
# (290, 290, 57, datetime.date(2020, 10, 17), 2, 'Interaction note 290')
# (291, 291, 30, datetime.date(2020, 10, 18), 1, 'Interaction note 291')
# (292, 292, 42, datetime.date(2020, 10, 19), 5, 'Interaction note 292')
# (293, 293, 21, datetime.date(2020, 10, 20), 2, 'Interaction note 293')
# (294, 294, 37, datetime.date(2020, 10, 21), 5, 'Interaction note 294')
# (295, 295, 28, datetime.date(2020, 10, 22), 4, 'Interaction note 295')
# (296, 296, 16, datetime.date(2020, 10, 23), 3, 'Interaction note 296')
# (297, 297, 66, datetime.date(2020, 10, 24), 2, 'Interaction note 297')
# (298, 298, 29, datetime.date(2020, 10, 25), 4, 'Interaction note 298')
# (299, 299, 27, datetime.date(2020, 10, 26), 3, 'Interaction note 299')
# (300, 300, 4, datetime.date(2020, 10, 27), 4, 'Interaction note 300')
# (301, 301, 91, datetime.date(2020, 10, 28), 3, 'Interaction note 301')
# (302, 302, 48, datetime.date(2020, 10, 29), 2, 'Interaction note 302')
# (303, 303, 75, datetime.date(2020, 10, 30), 2, 'Interaction note 303')
# (304, 304, 47, datetime.date(2020, 10, 31), 4, 'Interaction note 304')
# (305, 305, 23, datetime.date(2020, 11, 1), 2, 'Interaction note 305')
# (306, 306, 20, datetime.date(2020, 11, 2), 2, 'Interaction note 306')
# (307, 307, 21, datetime.date(2020, 11, 3), 1, 'Interaction note 307')
# (308, 308, 91, datetime.date(2020, 11, 4), 5, 'Interaction note 308')
# (309, 309, 28, datetime.date(2020, 11, 5), 2, 'Interaction note 309')
# (310, 310, 40, datetime.date(2020, 11, 6), 5, 'Interaction note 310')
# (311, 311, 93, datetime.date(2020, 11, 7), 5, 'Interaction note 311')
# (312, 312, 28, datetime.date(2020, 11, 8), 1, 'Interaction note 312')
# (313, 313, 66, datetime.date(2020, 11, 9), 2, 'Interaction note 313')
# (314, 314, 32, datetime.date(2020, 11, 10), 5, 'Interaction note 314')
# (315, 315, 18, datetime.date(2020, 11, 11), 3, 'Interaction note 315')
# (316, 316, 98, datetime.date(2020, 11, 12), 1, 'Interaction note 316')
# (317, 317, 75, datetime.date(2020, 11, 13), 5, 'Interaction note 317')
# (318, 318, 46, datetime.date(2020, 11, 14), 3, 'Interaction note 318')
# (319, 319, 44, datetime.date(2020, 11, 15), 4, 'Interaction note 319')
# (320, 320, 99, datetime.date(2020, 11, 16), 2, 'Interaction note 320')
# (321, 321, 70, datetime.date(2020, 11, 17), 1, 'Interaction note 321')
# (322, 322, 25, datetime.date(2020, 11, 18), 2, 'Interaction note 322')
# (323, 323, 13, datetime.date(2020, 11, 19), 2, 'Interaction note 323')
# (324, 324, 98, datetime.date(2020, 11, 20), 1, 'Interaction note 324')
# (325, 325, 53, datetime.date(2020, 11, 21), 3, 'Interaction note 325')
# (326, 326, 13, datetime.date(2020, 11, 22), 2, 'Interaction note 326')
# (327, 327, 49, datetime.date(2020, 11, 23), 3, 'Interaction note 327')
# (328, 328, 57, datetime.date(2020, 11, 24), 4, 'Interaction note 328')
# (329, 329, 96, datetime.date(2020, 11, 25), 2, 'Interaction note 329')
# (330, 330, 54, datetime.date(2020, 11, 26), 5, 'Interaction note 330')
# (331, 331, 23, datetime.date(2020, 11, 27), 3, 'Interaction note 331')
# (332, 332, 88, datetime.date(2020, 11, 28), 4, 'Interaction note 332')
# (333, 333, 30, datetime.date(2020, 11, 29), 1, 'Interaction note 333')
# (334, 334, 2, datetime.date(2020, 11, 30), 3, 'Interaction note 334')
# (335, 335, 60, datetime.date(2020, 12, 1), 1, 'Interaction note 335')
# (336, 336, 76, datetime.date(2020, 12, 2), 2, 'Interaction note 336')
# (337, 337, 23, datetime.date(2020, 12, 3), 1, 'Interaction note 337')
# (338, 338, 29, datetime.date(2020, 12, 4), 1, 'Interaction note 338')
# (339, 339, 40, datetime.date(2020, 12, 5), 4, 'Interaction note 339')
# (340, 340, 29, datetime.date(2020, 12, 6), 2, 'Interaction note 340')
# (341, 341, 99, datetime.date(2020, 12, 7), 4, 'Interaction note 341')
# (342, 342, 25, datetime.date(2020, 12, 8), 4, 'Interaction note 342')
# (343, 343, 85, datetime.date(2020, 12, 9), 1, 'Interaction note 343')
# (344, 344, 77, datetime.date(2020, 12, 10), 5, 'Interaction note 344')
# (345, 345, 12, datetime.date(2020, 12, 11), 2, 'Interaction note 345')
# (346, 346, 32, datetime.date(2020, 12, 12), 2, 'Interaction note 346')
# (347, 347, 42, datetime.date(2020, 12, 13), 3, 'Interaction note 347')
# (348, 348, 91, datetime.date(2020, 12, 14), 2, 'Interaction note 348')
# (349, 349, 2, datetime.date(2020, 12, 15), 4, 'Interaction note 349')
# (350, 350, 55, datetime.date(2020, 12, 16), 5, 'Interaction note 350')
# (351, 351, 29, datetime.date(2020, 12, 17), 2, 'Interaction note 351')
# (352, 352, 68, datetime.date(2020, 12, 18), 4, 'Interaction note 352')
# (353, 353, 54, datetime.date(2020, 12, 19), 5, 'Interaction note 353')
# (354, 354, 52, datetime.date(2020, 12, 20), 5, 'Interaction note 354')
# (355, 355, 91, datetime.date(2020, 12, 21), 5, 'Interaction note 355')
# (356, 356, 36, datetime.date(2020, 12, 22), 2, 'Interaction note 356')
# (357, 357, 93, datetime.date(2020, 12, 23), 5, 'Interaction note 357')
# (358, 358, 61, datetime.date(2020, 12, 24), 4, 'Interaction note 358')
# (359, 359, 67, datetime.date(2020, 12, 25), 5, 'Interaction note 359')
# (360, 360, 11, datetime.date(2020, 12, 26), 1, 'Interaction note 360')
# (361, 361, 41, datetime.date(2020, 12, 27), 2, 'Interaction note 361')
# (362, 362, 23, datetime.date(2020, 12, 28), 4, 'Interaction note 362')
# (363, 363, 76, datetime.date(2020, 12, 29), 1, 'Interaction note 363')
# (364, 364, 84, datetime.date(2020, 12, 30), 1, 'Interaction note 364')
# (365, 365, 12, datetime.date(2020, 12, 31), 1, 'Interaction note 365')
# (366, 366, 23, datetime.date(2021, 1, 1), 5, 'Interaction note 366')
# (367, 367, 92, datetime.date(2021, 1, 2), 4, 'Interaction note 367')
# (368, 368, 87, datetime.date(2021, 1, 3), 5, 'Interaction note 368')
# (369, 369, 45, datetime.date(2021, 1, 4), 1, 'Interaction note 369')
# (370, 370, 68, datetime.date(2021, 1, 5), 5, 'Interaction note 370')
# (371, 371, 24, datetime.date(2021, 1, 6), 5, 'Interaction note 371')
# (372, 372, 54, datetime.date(2021, 1, 7), 1, 'Interaction note 372')
# (373, 373, 64, datetime.date(2021, 1, 8), 1, 'Interaction note 373')
# (374, 374, 23, datetime.date(2021, 1, 9), 5, 'Interaction note 374')
# (375, 375, 66, datetime.date(2021, 1, 10), 1, 'Interaction note 375')
# (376, 376, 70, datetime.date(2021, 1, 11), 4, 'Interaction note 376')
# (377, 377, 92, datetime.date(2021, 1, 12), 1, 'Interaction note 377')
# (378, 378, 73, datetime.date(2021, 1, 13), 5, 'Interaction note 378')
# (379, 379, 32, datetime.date(2021, 1, 14), 2, 'Interaction note 379')
# (380, 380, 8, datetime.date(2021, 1, 15), 2, 'Interaction note 380')
# (381, 381, 82, datetime.date(2021, 1, 16), 5, 'Interaction note 381')
# (382, 382, 3, datetime.date(2021, 1, 17), 3, 'Interaction note 382')
# (383, 383, 99, datetime.date(2021, 1, 18), 2, 'Interaction note 383')
# (384, 384, 16, datetime.date(2021, 1, 19), 3, 'Interaction note 384')
# (385, 385, 35, datetime.date(2021, 1, 20), 5, 'Interaction note 385')
# (386, 386, 39, datetime.date(2021, 1, 21), 4, 'Interaction note 386')
# (387, 387, 13, datetime.date(2021, 1, 22), 1, 'Interaction note 387')
# (388, 388, 97, datetime.date(2021, 1, 23), 3, 'Interaction note 388')
# (389, 389, 20, datetime.date(2021, 1, 24), 3, 'Interaction note 389')
# (390, 390, 37, datetime.date(2021, 1, 25), 2, 'Interaction note 390')
# (391, 391, 42, datetime.date(2021, 1, 26), 2, 'Interaction note 391')
# (392, 392, 32, datetime.date(2021, 1, 27), 5, 'Interaction note 392')
# (393, 393, 52, datetime.date(2021, 1, 28), 3, 'Interaction note 393')
# (394, 394, 61, datetime.date(2021, 1, 29), 2, 'Interaction note 394')
# (395, 395, 61, datetime.date(2021, 1, 30), 5, 'Interaction note 395')
# (396, 396, 92, datetime.date(2021, 1, 31), 2, 'Interaction note 396')
# (397, 397, 99, datetime.date(2021, 2, 1), 4, 'Interaction note 397')
# (398, 398, 82, datetime.date(2021, 2, 2), 5, 'Interaction note 398')
# (399, 399, 91, datetime.date(2021, 2, 3), 4, 'Interaction note 399')
# (400, 400, 43, datetime.date(2021, 2, 4), 1, 'Interaction note 400')
# (401, 401, 9, datetime.date(2021, 2, 5), 5, 'Interaction note 401')
# (402, 402, 13, datetime.date(2021, 2, 6), 5, 'Interaction note 402')
# (403, 403, 71, datetime.date(2021, 2, 7), 4, 'Interaction note 403')
# (404, 404, 90, datetime.date(2021, 2, 8), 1, 'Interaction note 404')
# (405, 405, 58, datetime.date(2021, 2, 9), 1, 'Interaction note 405')
# (406, 406, 21, datetime.date(2021, 2, 10), 5, 'Interaction note 406')
# (407, 407, 12, datetime.date(2021, 2, 11), 5, 'Interaction note 407')
# (408, 408, 2, datetime.date(2021, 2, 12), 3, 'Interaction note 408')
# (409, 409, 87, datetime.date(2021, 2, 13), 3, 'Interaction note 409')
# (410, 410, 63, datetime.date(2021, 2, 14), 5, 'Interaction note 410')
# (411, 411, 56, datetime.date(2021, 2, 15), 2, 'Interaction note 411')
# (412, 412, 17, datetime.date(2021, 2, 16), 3, 'Interaction note 412')
# (413, 413, 93, datetime.date(2021, 2, 17), 1, 'Interaction note 413')
# (414, 414, 69, datetime.date(2021, 2, 18), 4, 'Interaction note 414')
# (415, 415, 87, datetime.date(2021, 2, 19), 1, 'Interaction note 415')
# (416, 416, 95, datetime.date(2021, 2, 20), 1, 'Interaction note 416')
# (417, 417, 99, datetime.date(2021, 2, 21), 3, 'Interaction note 417')
# (418, 418, 24, datetime.date(2021, 2, 22), 2, 'Interaction note 418')
# (419, 419, 85, datetime.date(2021, 2, 23), 5, 'Interaction note 419')
# (420, 420, 34, datetime.date(2021, 2, 24), 5, 'Interaction note 420')
# (421, 421, 38, datetime.date(2021, 2, 25), 2, 'Interaction note 421')
# (422, 422, 58, datetime.date(2021, 2, 26), 4, 'Interaction note 422')
# (423, 423, 31, datetime.date(2021, 2, 27), 2, 'Interaction note 423')
# (424, 424, 95, datetime.date(2021, 2, 28), 5, 'Interaction note 424')
# (425, 425, 35, datetime.date(2021, 3, 1), 4, 'Interaction note 425')
# (426, 426, 68, datetime.date(2021, 3, 2), 3, 'Interaction note 426')
# (427, 427, 34, datetime.date(2021, 3, 3), 4, 'Interaction note 427')
# (428, 428, 62, datetime.date(2021, 3, 4), 5, 'Interaction note 428')
# (429, 429, 21, datetime.date(2021, 3, 5), 4, 'Interaction note 429')
# (430, 430, 87, datetime.date(2021, 3, 6), 5, 'Interaction note 430')
# (431, 431, 3, datetime.date(2021, 3, 7), 3, 'Interaction note 431')
# (432, 432, 51, datetime.date(2021, 3, 8), 5, 'Interaction note 432')
# (433, 433, 24, datetime.date(2021, 3, 9), 2, 'Interaction note 433')
# (434, 434, 72, datetime.date(2021, 3, 10), 2, 'Interaction note 434')
# (435, 435, 92, datetime.date(2021, 3, 11), 4, 'Interaction note 435')
# (436, 436, 60, datetime.date(2021, 3, 12), 5, 'Interaction note 436')
# (437, 437, 7, datetime.date(2021, 3, 13), 1, 'Interaction note 437')
# (438, 438, 19, datetime.date(2021, 3, 14), 2, 'Interaction note 438')
# (439, 439, 37, datetime.date(2021, 3, 15), 2, 'Interaction note 439')
# (440, 440, 90, datetime.date(2021, 3, 16), 2, 'Interaction note 440')
# (441, 441, 87, datetime.date(2021, 3, 17), 5, 'Interaction note 441')
# (442, 442, 27, datetime.date(2021, 3, 18), 3, 'Interaction note 442')
# (443, 443, 23, datetime.date(2021, 3, 19), 4, 'Interaction note 443')
# (444, 444, 12, datetime.date(2021, 3, 20), 3, 'Interaction note 444')
# (445, 445, 57, datetime.date(2021, 3, 21), 1, 'Interaction note 445')
# (446, 446, 86, datetime.date(2021, 3, 22), 3, 'Interaction note 446')
# (447, 447, 15, datetime.date(2021, 3, 23), 3, 'Interaction note 447')
# (448, 448, 74, datetime.date(2021, 3, 24), 3, 'Interaction note 448')
# (449, 449, 77, datetime.date(2021, 3, 25), 4, 'Interaction note 449')
# (450, 450, 2, datetime.date(2021, 3, 26), 1, 'Interaction note 450')
# (451, 451, 49, datetime.date(2021, 3, 27), 1, 'Interaction note 451')
# (452, 452, 30, datetime.date(2021, 3, 28), 4, 'Interaction note 452')
# (453, 453, 58, datetime.date(2021, 3, 29), 4, 'Interaction note 453')
# (454, 454, 74, datetime.date(2021, 3, 30), 3, 'Interaction note 454')
# (455, 455, 80, datetime.date(2021, 3, 31), 1, 'Interaction note 455')
# (456, 456, 46, datetime.date(2021, 4, 1), 2, 'Interaction note 456')
# (457, 457, 100, datetime.date(2021, 4, 2), 5, 'Interaction note 457')
# (458, 458, 39, datetime.date(2021, 4, 3), 3, 'Interaction note 458')
# (459, 459, 61, datetime.date(2021, 4, 4), 2, 'Interaction note 459')
# (460, 460, 19, datetime.date(2021, 4, 5), 1, 'Interaction note 460')
# (461, 461, 74, datetime.date(2021, 4, 6), 2, 'Interaction note 461')
# (462, 462, 49, datetime.date(2021, 4, 7), 4, 'Interaction note 462')
# (463, 463, 30, datetime.date(2021, 4, 8), 4, 'Interaction note 463')
# (464, 464, 65, datetime.date(2021, 4, 9), 4, 'Interaction note 464')
# (465, 465, 13, datetime.date(2021, 4, 10), 4, 'Interaction note 465')
# (466, 466, 20, datetime.date(2021, 4, 11), 4, 'Interaction note 466')
# (467, 467, 45, datetime.date(2021, 4, 12), 1, 'Interaction note 467')
# (468, 468, 68, datetime.date(2021, 4, 13), 5, 'Interaction note 468')
# (469, 469, 53, datetime.date(2021, 4, 14), 2, 'Interaction note 469')
# (470, 470, 5, datetime.date(2021, 4, 15), 5, 'Interaction note 470')
# (471, 471, 43, datetime.date(2021, 4, 16), 4, 'Interaction note 471')
# (472, 472, 10, datetime.date(2021, 4, 17), 3, 'Interaction note 472')
# (473, 473, 19, datetime.date(2021, 4, 18), 3, 'Interaction note 473')
# (474, 474, 25, datetime.date(2021, 4, 19), 1, 'Interaction note 474')
# (475, 475, 51, datetime.date(2021, 4, 20), 5, 'Interaction note 475')
# (476, 476, 5, datetime.date(2021, 4, 21), 3, 'Interaction note 476')
# (477, 477, 52, datetime.date(2021, 4, 22), 2, 'Interaction note 477')
# (478, 478, 97, datetime.date(2021, 4, 23), 5, 'Interaction note 478')
# (479, 479, 73, datetime.date(2021, 4, 24), 2, 'Interaction note 479')
# (480, 480, 45, datetime.date(2021, 4, 25), 5, 'Interaction note 480')
# (481, 481, 21, datetime.date(2021, 4, 26), 2, 'Interaction note 481')
# (482, 482, 63, datetime.date(2021, 4, 27), 1, 'Interaction note 482')
# (483, 483, 57, datetime.date(2021, 4, 28), 1, 'Interaction note 483')
# (484, 484, 33, datetime.date(2021, 4, 29), 3, 'Interaction note 484')
# (485, 485, 10, datetime.date(2021, 4, 30), 4, 'Interaction note 485')
# (486, 486, 52, datetime.date(2021, 5, 1), 2, 'Interaction note 486')
# (487, 487, 7, datetime.date(2021, 5, 2), 2, 'Interaction note 487')
# (488, 488, 21, datetime.date(2021, 5, 3), 5, 'Interaction note 488')
# (489, 489, 55, datetime.date(2021, 5, 4), 3, 'Interaction note 489')
# (490, 490, 99, datetime.date(2021, 5, 5), 4, 'Interaction note 490')
# (491, 491, 95, datetime.date(2021, 5, 6), 3, 'Interaction note 491')
# (492, 492, 91, datetime.date(2021, 5, 7), 1, 'Interaction note 492')
# (493, 493, 13, datetime.date(2021, 5, 8), 3, 'Interaction note 493')
# (494, 494, 42, datetime.date(2021, 5, 9), 5, 'Interaction note 494')
# (495, 495, 46, datetime.date(2021, 5, 10), 4, 'Interaction note 495')
# (496, 496, 46, datetime.date(2021, 5, 11), 2, 'Interaction note 496')
# (497, 497, 12, datetime.date(2021, 5, 12), 1, 'Interaction note 497')
# (498, 498, 29, datetime.date(2021, 5, 13), 3, 'Interaction note 498')
# (499, 499, 98, datetime.date(2021, 5, 14), 2, 'Interaction note 499')
# (500, 500, 86, datetime.date(2021, 5, 15), 3, 'Interaction note 500')
# (501, 501, 16, datetime.date(2021, 5, 16), 4, 'Interaction note 501')
# (502, 502, 17, datetime.date(2021, 5, 17), 3, 'Interaction note 502')
# (503, 503, 86, datetime.date(2021, 5, 18), 3, 'Interaction note 503')
# (504, 504, 85, datetime.date(2021, 5, 19), 3, 'Interaction note 504')
# (505, 505, 76, datetime.date(2021, 5, 20), 3, 'Interaction note 505')
# (506, 506, 26, datetime.date(2021, 5, 21), 3, 'Interaction note 506')
# (507, 507, 84, datetime.date(2021, 5, 22), 4, 'Interaction note 507')
# (508, 508, 78, datetime.date(2021, 5, 23), 4, 'Interaction note 508')
# (509, 509, 25, datetime.date(2021, 5, 24), 5, 'Interaction note 509')
# (510, 510, 26, datetime.date(2021, 5, 25), 1, 'Interaction note 510')
# (511, 511, 36, datetime.date(2021, 5, 26), 3, 'Interaction note 511')
# (512, 512, 22, datetime.date(2021, 5, 27), 3, 'Interaction note 512')
# (513, 513, 99, datetime.date(2021, 5, 28), 5, 'Interaction note 513')
# (514, 514, 31, datetime.date(2021, 5, 29), 5, 'Interaction note 514')
# (515, 515, 32, datetime.date(2021, 5, 30), 5, 'Interaction note 515')
# (516, 516, 98, datetime.date(2021, 5, 31), 5, 'Interaction note 516')
# (517, 517, 2, datetime.date(2021, 6, 1), 3, 'Interaction note 517')
# (518, 518, 6, datetime.date(2021, 6, 2), 1, 'Interaction note 518')
# (519, 519, 76, datetime.date(2021, 6, 3), 5, 'Interaction note 519')
# (520, 520, 66, datetime.date(2021, 6, 4), 1, 'Interaction note 520')
# (521, 521, 91, datetime.date(2021, 6, 5), 4, 'Interaction note 521')
# (522, 522, 14, datetime.date(2021, 6, 6), 4, 'Interaction note 522')
# (523, 523, 56, datetime.date(2021, 6, 7), 5, 'Interaction note 523')
# (524, 524, 26, datetime.date(2021, 6, 8), 1, 'Interaction note 524')
# (525, 525, 37, datetime.date(2021, 6, 9), 4, 'Interaction note 525')
# (526, 526, 22, datetime.date(2021, 6, 10), 2, 'Interaction note 526')
# (527, 527, 66, datetime.date(2021, 6, 11), 4, 'Interaction note 527')
# (528, 528, 34, datetime.date(2021, 6, 12), 3, 'Interaction note 528')
# (529, 529, 68, datetime.date(2021, 6, 13), 2, 'Interaction note 529')
# (530, 530, 19, datetime.date(2021, 6, 14), 2, 'Interaction note 530')
# (531, 531, 14, datetime.date(2021, 6, 15), 4, 'Interaction note 531')
# (532, 532, 92, datetime.date(2021, 6, 16), 2, 'Interaction note 532')
# (533, 533, 41, datetime.date(2021, 6, 17), 1, 'Interaction note 533')
# (534, 534, 34, datetime.date(2021, 6, 18), 5, 'Interaction note 534')
# (535, 535, 71, datetime.date(2021, 6, 19), 3, 'Interaction note 535')
# (536, 536, 24, datetime.date(2021, 6, 20), 4, 'Interaction note 536')
# (537, 537, 5, datetime.date(2021, 6, 21), 4, 'Interaction note 537')
# (538, 538, 34, datetime.date(2021, 6, 22), 1, 'Interaction note 538')
# (539, 539, 44, datetime.date(2021, 6, 23), 5, 'Interaction note 539')
# (540, 540, 27, datetime.date(2021, 6, 24), 4, 'Interaction note 540')
# (541, 541, 14, datetime.date(2021, 6, 25), 1, 'Interaction note 541')
# (542, 542, 26, datetime.date(2021, 6, 26), 5, 'Interaction note 542')
# (543, 543, 59, datetime.date(2021, 6, 27), 4, 'Interaction note 543')
# (544, 544, 31, datetime.date(2021, 6, 28), 2, 'Interaction note 544')
# (545, 545, 33, datetime.date(2021, 6, 29), 1, 'Interaction note 545')
# (546, 546, 24, datetime.date(2021, 6, 30), 4, 'Interaction note 546')
# (547, 547, 7, datetime.date(2021, 7, 1), 5, 'Interaction note 547')
# (548, 548, 20, datetime.date(2021, 7, 2), 3, 'Interaction note 548')
# (549, 549, 76, datetime.date(2021, 7, 3), 1, 'Interaction note 549')
# (550, 550, 19, datetime.date(2021, 7, 4), 2, 'Interaction note 550')
# (551, 551, 62, datetime.date(2021, 7, 5), 2, 'Interaction note 551')
# (552, 552, 44, datetime.date(2021, 7, 6), 5, 'Interaction note 552')
# (553, 553, 73, datetime.date(2021, 7, 7), 2, 'Interaction note 553')
# (554, 554, 2, datetime.date(2021, 7, 8), 2, 'Interaction note 554')
# (555, 555, 39, datetime.date(2021, 7, 9), 1, 'Interaction note 555')
# (556, 556, 32, datetime.date(2021, 7, 10), 5, 'Interaction note 556')
# (557, 557, 42, datetime.date(2021, 7, 11), 3, 'Interaction note 557')
# (558, 558, 64, datetime.date(2021, 7, 12), 3, 'Interaction note 558')
# (559, 559, 50, datetime.date(2021, 7, 13), 3, 'Interaction note 559')
# (560, 560, 18, datetime.date(2021, 7, 14), 3, 'Interaction note 560')
# (561, 561, 89, datetime.date(2021, 7, 15), 3, 'Interaction note 561')
# (562, 562, 50, datetime.date(2021, 7, 16), 5, 'Interaction note 562')
# (563, 563, 24, datetime.date(2021, 7, 17), 3, 'Interaction note 563')
# (564, 564, 43, datetime.date(2021, 7, 18), 4, 'Interaction note 564')
# (565, 565, 53, datetime.date(2021, 7, 19), 4, 'Interaction note 565')
# (566, 566, 74, datetime.date(2021, 7, 20), 2, 'Interaction note 566')
# (567, 567, 91, datetime.date(2021, 7, 21), 2, 'Interaction note 567')
# (568, 568, 11, datetime.date(2021, 7, 22), 2, 'Interaction note 568')
# (569, 569, 37, datetime.date(2021, 7, 23), 1, 'Interaction note 569')
# (570, 570, 72, datetime.date(2021, 7, 24), 2, 'Interaction note 570')
# (571, 571, 17, datetime.date(2021, 7, 25), 3, 'Interaction note 571')
# (572, 572, 59, datetime.date(2021, 7, 26), 4, 'Interaction note 572')
# (573, 573, 81, datetime.date(2021, 7, 27), 5, 'Interaction note 573')
# (574, 574, 99, datetime.date(2021, 7, 28), 5, 'Interaction note 574')
# (575, 575, 16, datetime.date(2021, 7, 29), 1, 'Interaction note 575')
# (576, 576, 63, datetime.date(2021, 7, 30), 2, 'Interaction note 576')
# (577, 577, 99, datetime.date(2021, 7, 31), 3, 'Interaction note 577')
# (578, 578, 54, datetime.date(2021, 8, 1), 1, 'Interaction note 578')
# (579, 579, 38, datetime.date(2021, 8, 2), 1, 'Interaction note 579')
# (580, 580, 77, datetime.date(2021, 8, 3), 1, 'Interaction note 580')
# (581, 581, 33, datetime.date(2021, 8, 4), 2, 'Interaction note 581')
# (582, 582, 18, datetime.date(2021, 8, 5), 2, 'Interaction note 582')
# (583, 583, 93, datetime.date(2021, 8, 6), 3, 'Interaction note 583')
# (584, 584, 70, datetime.date(2021, 8, 7), 1, 'Interaction note 584')
# (585, 585, 63, datetime.date(2021, 8, 8), 1, 'Interaction note 585')
# (586, 586, 78, datetime.date(2021, 8, 9), 2, 'Interaction note 586')
# (587, 587, 18, datetime.date(2021, 8, 10), 1, 'Interaction note 587')
# (588, 588, 36, datetime.date(2021, 8, 11), 3, 'Interaction note 588')
# (589, 589, 39, datetime.date(2021, 8, 12), 4, 'Interaction note 589')
# (590, 590, 28, datetime.date(2021, 8, 13), 1, 'Interaction note 590')
# (591, 591, 43, datetime.date(2021, 8, 14), 1, 'Interaction note 591')
# (592, 592, 38, datetime.date(2021, 8, 15), 5, 'Interaction note 592')
# (593, 593, 60, datetime.date(2021, 8, 16), 4, 'Interaction note 593')
# (594, 594, 71, datetime.date(2021, 8, 17), 4, 'Interaction note 594')
# (595, 595, 54, datetime.date(2021, 8, 18), 5, 'Interaction note 595')
# (596, 596, 71, datetime.date(2021, 8, 19), 5, 'Interaction note 596')
# (597, 597, 71, datetime.date(2021, 8, 20), 4, 'Interaction note 597')
# (598, 598, 85, datetime.date(2021, 8, 21), 4, 'Interaction note 598')
# (599, 599, 76, datetime.date(2021, 8, 22), 4, 'Interaction note 599')
# (600, 600, 70, datetime.date(2021, 8, 23), 4, 'Interaction note 600')
# (601, 601, 26, datetime.date(2021, 8, 24), 4, 'Interaction note 601')
# (602, 602, 98, datetime.date(2021, 8, 25), 5, 'Interaction note 602')
# (603, 603, 29, datetime.date(2021, 8, 26), 1, 'Interaction note 603')
# (604, 604, 60, datetime.date(2021, 8, 27), 4, 'Interaction note 604')
# (605, 605, 77, datetime.date(2021, 8, 28), 3, 'Interaction note 605')
# (606, 606, 64, datetime.date(2021, 8, 29), 5, 'Interaction note 606')
# (607, 607, 58, datetime.date(2021, 8, 30), 3, 'Interaction note 607')
# (608, 608, 17, datetime.date(2021, 8, 31), 1, 'Interaction note 608')
# (609, 609, 19, datetime.date(2021, 9, 1), 5, 'Interaction note 609')
# (610, 610, 61, datetime.date(2021, 9, 2), 3, 'Interaction note 610')
# (611, 611, 3, datetime.date(2021, 9, 3), 4, 'Interaction note 611')
# (612, 612, 9, datetime.date(2021, 9, 4), 4, 'Interaction note 612')
# (613, 613, 48, datetime.date(2021, 9, 5), 2, 'Interaction note 613')
# (614, 614, 91, datetime.date(2021, 9, 6), 5, 'Interaction note 614')
# (615, 615, 95, datetime.date(2021, 9, 7), 2, 'Interaction note 615')
# (616, 616, 98, datetime.date(2021, 9, 8), 3, 'Interaction note 616')
# (617, 617, 82, datetime.date(2021, 9, 9), 4, 'Interaction note 617')
# (618, 618, 84, datetime.date(2021, 9, 10), 5, 'Interaction note 618')
# (619, 619, 60, datetime.date(2021, 9, 11), 3, 'Interaction note 619')
# (620, 620, 46, datetime.date(2021, 9, 12), 3, 'Interaction note 620')
# (621, 621, 42, datetime.date(2021, 9, 13), 2, 'Interaction note 621')
# (622, 622, 1, datetime.date(2021, 9, 14), 5, 'Interaction note 622')
# (623, 623, 54, datetime.date(2021, 9, 15), 5, 'Interaction note 623')
# (624, 624, 19, datetime.date(2021, 9, 16), 4, 'Interaction note 624')
# (625, 625, 75, datetime.date(2021, 9, 17), 4, 'Interaction note 625')
# (626, 626, 52, datetime.date(2021, 9, 18), 2, 'Interaction note 626')
# (627, 627, 3, datetime.date(2021, 9, 19), 1, 'Interaction note 627')
# (628, 628, 8, datetime.date(2021, 9, 20), 5, 'Interaction note 628')
# (629, 629, 52, datetime.date(2021, 9, 21), 4, 'Interaction note 629')
# (630, 630, 87, datetime.date(2021, 9, 22), 2, 'Interaction note 630')
# (631, 631, 46, datetime.date(2021, 9, 23), 1, 'Interaction note 631')
# (632, 632, 18, datetime.date(2021, 9, 24), 5, 'Interaction note 632')
# (633, 633, 14, datetime.date(2021, 9, 25), 5, 'Interaction note 633')
# (634, 634, 58, datetime.date(2021, 9, 26), 4, 'Interaction note 634')
# (635, 635, 55, datetime.date(2021, 9, 27), 5, 'Interaction note 635')
# (636, 636, 66, datetime.date(2021, 9, 28), 5, 'Interaction note 636')
# (637, 637, 37, datetime.date(2021, 9, 29), 5, 'Interaction note 637')
# (638, 638, 18, datetime.date(2021, 9, 30), 3, 'Interaction note 638')
# (639, 639, 17, datetime.date(2021, 10, 1), 3, 'Interaction note 639')
# (640, 640, 71, datetime.date(2021, 10, 2), 3, 'Interaction note 640')
# (641, 641, 13, datetime.date(2021, 10, 3), 1, 'Interaction note 641')
# (642, 642, 59, datetime.date(2021, 10, 4), 3, 'Interaction note 642')
# (643, 643, 37, datetime.date(2021, 10, 5), 5, 'Interaction note 643')
# (644, 644, 47, datetime.date(2021, 10, 6), 3, 'Interaction note 644')
# (645, 645, 15, datetime.date(2021, 10, 7), 2, 'Interaction note 645')
# (646, 646, 74, datetime.date(2021, 10, 8), 4, 'Interaction note 646')
# (647, 647, 17, datetime.date(2021, 10, 9), 5, 'Interaction note 647')
# (648, 648, 72, datetime.date(2021, 10, 10), 4, 'Interaction note 648')
# (649, 649, 78, datetime.date(2021, 10, 11), 1, 'Interaction note 649')
# (650, 650, 57, datetime.date(2021, 10, 12), 4, 'Interaction note 650')
# (651, 651, 84, datetime.date(2021, 10, 13), 4, 'Interaction note 651')
# (652, 652, 52, datetime.date(2021, 10, 14), 3, 'Interaction note 652')
# (653, 653, 1, datetime.date(2021, 10, 15), 3, 'Interaction note 653')
# (654, 654, 48, datetime.date(2021, 10, 16), 1, 'Interaction note 654')
# (655, 655, 75, datetime.date(2021, 10, 17), 4, 'Interaction note 655')
# (656, 656, 49, datetime.date(2021, 10, 18), 3, 'Interaction note 656')
# (657, 657, 38, datetime.date(2021, 10, 19), 1, 'Interaction note 657')
# (658, 658, 2, datetime.date(2021, 10, 20), 4, 'Interaction note 658')
# (659, 659, 35, datetime.date(2021, 10, 21), 2, 'Interaction note 659')
# (660, 660, 14, datetime.date(2021, 10, 22), 4, 'Interaction note 660')
# (661, 661, 67, datetime.date(2021, 10, 23), 3, 'Interaction note 661')
# (662, 662, 14, datetime.date(2021, 10, 24), 4, 'Interaction note 662')
# (663, 663, 46, datetime.date(2021, 10, 25), 4, 'Interaction note 663')
# (664, 664, 35, datetime.date(2021, 10, 26), 4, 'Interaction note 664')
# (665, 665, 16, datetime.date(2021, 10, 27), 3, 'Interaction note 665')
# (666, 666, 57, datetime.date(2021, 10, 28), 3, 'Interaction note 666')
# (667, 667, 18, datetime.date(2021, 10, 29), 2, 'Interaction note 667')
# (668, 668, 45, datetime.date(2021, 10, 30), 4, 'Interaction note 668')
# (669, 669, 50, datetime.date(2021, 10, 31), 3, 'Interaction note 669')
# (670, 670, 65, datetime.date(2021, 11, 1), 5, 'Interaction note 670')
# (671, 671, 83, datetime.date(2021, 11, 2), 1, 'Interaction note 671')
# (672, 672, 63, datetime.date(2021, 11, 3), 4, 'Interaction note 672')
# (673, 673, 60, datetime.date(2021, 11, 4), 1, 'Interaction note 673')
# (674, 674, 62, datetime.date(2021, 11, 5), 5, 'Interaction note 674')
# (675, 675, 93, datetime.date(2021, 11, 6), 4, 'Interaction note 675')
# (676, 676, 87, datetime.date(2021, 11, 7), 3, 'Interaction note 676')
# (677, 677, 51, datetime.date(2021, 11, 8), 4, 'Interaction note 677')
# (678, 678, 100, datetime.date(2021, 11, 9), 5, 'Interaction note 678')
# (679, 679, 94, datetime.date(2021, 11, 10), 4, 'Interaction note 679')
# (680, 680, 11, datetime.date(2021, 11, 11), 2, 'Interaction note 680')
# (681, 681, 68, datetime.date(2021, 11, 12), 3, 'Interaction note 681')
# (682, 682, 28, datetime.date(2021, 11, 13), 2, 'Interaction note 682')
# (683, 683, 48, datetime.date(2021, 11, 14), 3, 'Interaction note 683')
# (684, 684, 59, datetime.date(2021, 11, 15), 3, 'Interaction note 684')
# (685, 685, 81, datetime.date(2021, 11, 16), 3, 'Interaction note 685')
# (686, 686, 18, datetime.date(2021, 11, 17), 4, 'Interaction note 686')
# (687, 687, 73, datetime.date(2021, 11, 18), 1, 'Interaction note 687')
# (688, 688, 94, datetime.date(2021, 11, 19), 2, 'Interaction note 688')
# (689, 689, 70, datetime.date(2021, 11, 20), 2, 'Interaction note 689')
# (690, 690, 3, datetime.date(2021, 11, 21), 4, 'Interaction note 690')
# ...
# (772, 772, 29, datetime.date(2022, 2, 11), 4, 'Interaction note 772')
# (773, 773, 23, datetime.date(2022, 2, 12), 2, 'Interaction note 773')
# (774, 774, 49, datetime.date(2022, 2, 13), 1, 'Interaction note 774')
# (775, 775, 12, datetime.date(2022, 2, 14), 5, 'Interaction note 775')
# (776, 776, 92, datetime.date(2022, 2, 15), 1, 'Interaction note 776')
# (777, 777, 34, datetime.date(2022, 2, 16), 4, 'Interaction note 777')
# (778, 778, 64, datetime.date(2022, 2, 17), 5, 'Interaction note 778')
# (779, 779, 63, datetime.date(2022, 2, 18), 4, 'Interaction note 779')
# (780, 780, 5, datetime.date(2022, 2, 19), 1, 'Interaction note 780')
# (781, 781, 49, datetime.date(2022, 2, 20), 2, 'Interaction note 781')
# (782, 782, 1, datetime.date(2022, 2, 21), 1, 'Interaction note 782')
# (783, 783, 70, datetime.date(2022, 2, 22), 3, 'Interaction note 783')
# (784, 784, 66, datetime.date(2022, 2, 23), 2, 'Interaction note 784')
# (785, 785, 83, datetime.date(2022, 2, 24), 5, 'Interaction note 785')
# (786, 786, 6, datetime.date(2022, 2, 25), 2, 'Interaction note 786')
# (787, 787, 47, datetime.date(2022, 2, 26), 4, 'Interaction note 787')
# (788, 788, 91, datetime.date(2022, 2, 27), 4, 'Interaction note 788')
# (789, 789, 24, datetime.date(2022, 2, 28), 1, 'Interaction note 789')
# (790, 790, 80, datetime.date(2022, 3, 1), 2, 'Interaction note 790')
# (791, 791, 45, datetime.date(2022, 3, 2), 4, 'Interaction note 791')
# (792, 792, 9, datetime.date(2022, 3, 3), 3, 'Interaction note 792')
# (793, 793, 70, datetime.date(2022, 3, 4), 1, 'Interaction note 793')
# (794, 794, 22, datetime.date(2022, 3, 5), 5, 'Interaction note 794')
# (795, 795, 50, datetime.date(2022, 3, 6), 4, 'Interaction note 795')
# (796, 796, 30, datetime.date(2022, 3, 7), 2, 'Interaction note 796')
# (797, 797, 88, datetime.date(2022, 3, 8), 3, 'Interaction note 797')
# (798, 798, 14, datetime.date(2022, 3, 9), 1, 'Interaction note 798')
# (799, 799, 85, datetime.date(2022, 3, 10), 5, 'Interaction note 799')
# (800, 800, 29, datetime.date(2022, 3, 11), 1, 'Interaction note 800')
# (801, 801, 47, datetime.date(2022, 3, 12), 5, 'Interaction note 801')
# (802, 802, 38, datetime.date(2022, 3, 13), 3, 'Interaction note 802')
# (803, 803, 42, datetime.date(2022, 3, 14), 2, 'Interaction note 803')
# (804, 804, 30, datetime.date(2022, 3, 15), 1, 'Interaction note 804')
# (805, 805, 97, datetime.date(2022, 3, 16), 3, 'Interaction note 805')
# (806, 806, 94, datetime.date(2022, 3, 17), 5, 'Interaction note 806')
# (807, 807, 8, datetime.date(2022, 3, 18), 4, 'Interaction note 807')
# (808, 808, 9, datetime.date(2022, 3, 19), 1, 'Interaction note 808')
# (809, 809, 50, datetime.date(2022, 3, 20), 4, 'Interaction note 809')
# (810, 810, 42, datetime.date(2022, 3, 21), 2, 'Interaction note 810')
# (811, 811, 99, datetime.date(2022, 3, 22), 2, 'Interaction note 811')
# (812, 812, 50, datetime.date(2022, 3, 23), 3, 'Interaction note 812')
# (813, 813, 40, datetime.date(2022, 3, 24), 5, 'Interaction note 813')
# (814, 814, 97, datetime.date(2022, 3, 25), 4, 'Interaction note 814')
# (815, 815, 61, datetime.date(2022, 3, 26), 2, 'Interaction note 815')
# (816, 816, 63, datetime.date(2022, 3, 27), 2, 'Interaction note 816')
# (817, 817, 93, datetime.date(2022, 3, 28), 2, 'Interaction note 817')
# (818, 818, 25, datetime.date(2022, 3, 29), 2, 'Interaction note 818')
# (819, 819, 13, datetime.date(2022, 3, 30), 2, 'Interaction note 819')
# (820, 820, 68, datetime.date(2022, 3, 31), 4, 'Interaction note 820')
# (821, 821, 46, datetime.date(2022, 4, 1), 1, 'Interaction note 821')
# (822, 822, 24, datetime.date(2022, 4, 2), 4, 'Interaction note 822')
# (823, 823, 7, datetime.date(2022, 4, 3), 2, 'Interaction note 823')
# (824, 824, 72, datetime.date(2022, 4, 4), 5, 'Interaction note 824')
# (825, 825, 42, datetime.date(2022, 4, 5), 2, 'Interaction note 825')
# (826, 826, 7, datetime.date(2022, 4, 6), 3, 'Interaction note 826')
# (827, 827, 81, datetime.date(2022, 4, 7), 2, 'Interaction note 827')
# (828, 828, 45, datetime.date(2022, 4, 8), 1, 'Interaction note 828')
# (829, 829, 11, datetime.date(2022, 4, 9), 5, 'Interaction note 829')
# (830, 830, 44, datetime.date(2022, 4, 10), 1, 'Interaction note 830')
# (831, 831, 35, datetime.date(2022, 4, 11), 1, 'Interaction note 831')
# (832, 832, 18, datetime.date(2022, 4, 12), 4, 'Interaction note 832')
# (833, 833, 16, datetime.date(2022, 4, 13), 1, 'Interaction note 833')
# (834, 834, 68, datetime.date(2022, 4, 14), 2, 'Interaction note 834')
# (835, 835, 37, datetime.date(2022, 4, 15), 4, 'Interaction note 835')
# (836, 836, 9, datetime.date(2022, 4, 16), 2, 'Interaction note 836')
# (837, 837, 74, datetime.date(2022, 4, 17), 4, 'Interaction note 837')
# (838, 838, 44, datetime.date(2022, 4, 18), 2, 'Interaction note 838')
# (839, 839, 4, datetime.date(2022, 4, 19), 1, 'Interaction note 839')
# (840, 840, 1, datetime.date(2022, 4, 20), 4, 'Interaction note 840')
# (841, 841, 61, datetime.date(2022, 4, 21), 4, 'Interaction note 841')
# (842, 842, 85, datetime.date(2022, 4, 22), 3, 'Interaction note 842')
# (843, 843, 83, datetime.date(2022, 4, 23), 2, 'Interaction note 843')
# (844, 844, 69, datetime.date(2022, 4, 24), 1, 'Interaction note 844')
# (845, 845, 37, datetime.date(2022, 4, 25), 1, 'Interaction note 845')
# (846, 846, 35, datetime.date(2022, 4, 26), 2, 'Interaction note 846')
# (847, 847, 28, datetime.date(2022, 4, 27), 2, 'Interaction note 847')
# (848, 848, 52, datetime.date(2022, 4, 28), 5, 'Interaction note 848')
# (849, 849, 40, datetime.date(2022, 4, 29), 3, 'Interaction note 849')
# (850, 850, 4, datetime.date(2022, 4, 30), 5, 'Interaction note 850')
# (851, 851, 39, datetime.date(2022, 5, 1), 3, 'Interaction note 851')
# (852, 852, 50, datetime.date(2022, 5, 2), 1, 'Interaction note 852')
# (853, 853, 72, datetime.date(2022, 5, 3), 3, 'Interaction note 853')
# (854, 854, 62, datetime.date(2022, 5, 4), 4, 'Interaction note 854')
# (855, 855, 11, datetime.date(2022, 5, 5), 5, 'Interaction note 855')
# (856, 856, 99, datetime.date(2022, 5, 6), 5, 'Interaction note 856')
# (857, 857, 29, datetime.date(2022, 5, 7), 2, 'Interaction note 857')
# (858, 858, 62, datetime.date(2022, 5, 8), 5, 'Interaction note 858')
# (859, 859, 33, datetime.date(2022, 5, 9), 1, 'Interaction note 859')
# (860, 860, 15, datetime.date(2022, 5, 10), 5, 'Interaction note 860')
# (861, 861, 13, datetime.date(2022, 5, 11), 4, 'Interaction note 861')
# (862, 862, 69, datetime.date(2022, 5, 12), 1, 'Interaction note 862')
# (863, 863, 63, datetime.date(2022, 5, 13), 2, 'Interaction note 863')
# (864, 864, 43, datetime.date(2022, 5, 14), 3, 'Interaction note 864')
# (865, 865, 84, datetime.date(2022, 5, 15), 1, 'Interaction note 865')
# (866, 866, 18, datetime.date(2022, 5, 16), 5, 'Interaction note 866')
# (867, 867, 79, datetime.date(2022, 5, 17), 4, 'Interaction note 867')
# (868, 868, 69, datetime.date(2022, 5, 18), 2, 'Interaction note 868')
# (869, 869, 50, datetime.date(2022, 5, 19), 3, 'Interaction note 869')
# (870, 870, 44, datetime.date(2022, 5, 20), 2, 'Interaction note 870')
# (871, 871, 25, datetime.date(2022, 5, 21), 1, 'Interaction note 871')
# (872, 872, 97, datetime.date(2022, 5, 22), 2, 'Interaction note 872')
# (873, 873, 65, datetime.date(2022, 5, 23), 2, 'Interaction note 873')
# (874, 874, 11, datetime.date(2022, 5, 24), 4, 'Interaction note 874')
# (875, 875, 16, datetime.date(2022, 5, 25), 3, 'Interaction note 875')
# (876, 876, 45, datetime.date(2022, 5, 26), 4, 'Interaction note 876')
# (877, 877, 15, datetime.date(2022, 5, 27), 5, 'Interaction note 877')
# (878, 878, 4, datetime.date(2022, 5, 28), 1, 'Interaction note 878')
# (879, 879, 82, datetime.date(2022, 5, 29), 2, 'Interaction note 879')
# (880, 880, 24, datetime.date(2022, 5, 30), 5, 'Interaction note 880')
# (881, 881, 92, datetime.date(2022, 5, 31), 5, 'Interaction note 881')
# (882, 882, 14, datetime.date(2022, 6, 1), 4, 'Interaction note 882')
# (883, 883, 25, datetime.date(2022, 6, 2), 1, 'Interaction note 883')
# (884, 884, 43, datetime.date(2022, 6, 3), 4, 'Interaction note 884')
# (885, 885, 20, datetime.date(2022, 6, 4), 5, 'Interaction note 885')
# (886, 886, 73, datetime.date(2022, 6, 5), 2, 'Interaction note 886')
# (887, 887, 47, datetime.date(2022, 6, 6), 1, 'Interaction note 887')
# (888, 888, 77, datetime.date(2022, 6, 7), 3, 'Interaction note 888')
# (889, 889, 86, datetime.date(2022, 6, 8), 1, 'Interaction note 889')
# (890, 890, 8, datetime.date(2022, 6, 9), 2, 'Interaction note 890')
# (891, 891, 11, datetime.date(2022, 6, 10), 3, 'Interaction note 891')
# (892, 892, 52, datetime.date(2022, 6, 11), 3, 'Interaction note 892')
# (893, 893, 37, datetime.date(2022, 6, 12), 2, 'Interaction note 893')
# (894, 894, 76, datetime.date(2022, 6, 13), 2, 'Interaction note 894')
# (895, 895, 83, datetime.date(2022, 6, 14), 5, 'Interaction note 895')
# (896, 896, 50, datetime.date(2022, 6, 15), 2, 'Interaction note 896')
# (897, 897, 19, datetime.date(2022, 6, 16), 4, 'Interaction note 897')
# (898, 898, 87, datetime.date(2022, 6, 17), 3, 'Interaction note 898')
# (899, 899, 27, datetime.date(2022, 6, 18), 2, 'Interaction note 899')
# (900, 900, 11, datetime.date(2022, 6, 19), 2, 'Interaction note 900')
# (901, 901, 4, datetime.date(2022, 6, 20), 4, 'Interaction note 901')
# (902, 902, 27, datetime.date(2022, 6, 21), 1, 'Interaction note 902')
# (903, 903, 40, datetime.date(2022, 6, 22), 3, 'Interaction note 903')
# (904, 904, 82, datetime.date(2022, 6, 23), 4, 'Interaction note 904')
# (905, 905, 11, datetime.date(2022, 6, 24), 4, 'Interaction note 905')
# (906, 906, 49, datetime.date(2022, 6, 25), 1, 'Interaction note 906')
# (907, 907, 78, datetime.date(2022, 6, 26), 1, 'Interaction note 907')
# (908, 908, 65, datetime.date(2022, 6, 27), 5, 'Interaction note 908')
# (909, 909, 88, datetime.date(2022, 6, 28), 4, 'Interaction note 909')
# (910, 910, 9, datetime.date(2022, 6, 29), 2, 'Interaction note 910')
# (911, 911, 70, datetime.date(2022, 6, 30), 5, 'Interaction note 911')
# (912, 912, 23, datetime.date(2022, 7, 1), 1, 'Interaction note 912')
# (913, 913, 69, datetime.date(2022, 7, 2), 2, 'Interaction note 913')
# (914, 914, 23, datetime.date(2022, 7, 3), 2, 'Interaction note 914')
# (915, 915, 76, datetime.date(2022, 7, 4), 2, 'Interaction note 915')
# (916, 916, 22, datetime.date(2022, 7, 5), 2, 'Interaction note 916')
# (917, 917, 17, datetime.date(2022, 7, 6), 3, 'Interaction note 917')
# (918, 918, 100, datetime.date(2022, 7, 7), 1, 'Interaction note 918')
# (919, 919, 58, datetime.date(2022, 7, 8), 4, 'Interaction note 919')
# (920, 920, 45, datetime.date(2022, 7, 9), 3, 'Interaction note 920')
# (921, 921, 43, datetime.date(2022, 7, 10), 2, 'Interaction note 921')
# (922, 922, 24, datetime.date(2022, 7, 11), 5, 'Interaction note 922')
# (923, 923, 56, datetime.date(2022, 7, 12), 5, 'Interaction note 923')
# (924, 924, 31, datetime.date(2022, 7, 13), 1, 'Interaction note 924')
# (925, 925, 5, datetime.date(2022, 7, 14), 3, 'Interaction note 925')
# (926, 926, 78, datetime.date(2022, 7, 15), 4, 'Interaction note 926')
# (927, 927, 89, datetime.date(2022, 7, 16), 2, 'Interaction note 927')
# (928, 928, 40, datetime.date(2022, 7, 17), 2, 'Interaction note 928')
# (929, 929, 97, datetime.date(2022, 7, 18), 1, 'Interaction note 929')
# (930, 930, 26, datetime.date(2022, 7, 19), 1, 'Interaction note 930')
# (931, 931, 50, datetime.date(2022, 7, 20), 1, 'Interaction note 931')
# (932, 932, 15, datetime.date(2022, 7, 21), 1, 'Interaction note 932')
# (933, 933, 77, datetime.date(2022, 7, 22), 5, 'Interaction note 933')
# (934, 934, 42, datetime.date(2022, 7, 23), 1, 'Interaction note 934')
# (935, 935, 94, datetime.date(2022, 7, 24), 1, 'Interaction note 935')
# (936, 936, 88, datetime.date(2022, 7, 25), 4, 'Interaction note 936')
# (937, 937, 70, datetime.date(2022, 7, 26), 4, 'Interaction note 937')
# (938, 938, 61, datetime.date(2022, 7, 27), 3, 'Interaction note 938')
# (939, 939, 47, datetime.date(2022, 7, 28), 2, 'Interaction note 939')
# (940, 940, 86, datetime.date(2022, 7, 29), 5, 'Interaction note 940')
# (941, 941, 99, datetime.date(2022, 7, 30), 3, 'Interaction note 941')
# (942, 942, 6, datetime.date(2022, 7, 31), 5, 'Interaction note 942')
# (943, 943, 49, datetime.date(2022, 8, 1), 5, 'Interaction note 943')
# (944, 944, 3, datetime.date(2022, 8, 2), 3, 'Interaction note 944')
# (945, 945, 16, datetime.date(2022, 8, 3), 5, 'Interaction note 945')
# (946, 946, 73, datetime.date(2022, 8, 4), 3, 'Interaction note 946')
# (947, 947, 21, datetime.date(2022, 8, 5), 2, 'Interaction note 947')
# (948, 948, 98, datetime.date(2022, 8, 6), 2, 'Interaction note 948')
# (949, 949, 83, datetime.date(2022, 8, 7), 4, 'Interaction note 949')
# (950, 950, 24, datetime.date(2022, 8, 8), 4, 'Interaction note 950')
# (951, 951, 58, datetime.date(2022, 8, 9), 2, 'Interaction note 951')
# (952, 952, 45, datetime.date(2022, 8, 10), 2, 'Interaction note 952')
# (953, 953, 49, datetime.date(2022, 8, 11), 5, 'Interaction note 953')
# (954, 954, 49, datetime.date(2022, 8, 12), 3, 'Interaction note 954')
# (955, 955, 3, datetime.date(2022, 8, 13), 1, 'Interaction note 955')
# (956, 956, 5, datetime.date(2022, 8, 14), 1, 'Interaction note 956')
# (957, 957, 73, datetime.date(2022, 8, 15), 3, 'Interaction note 957')
# (958, 958, 5, datetime.date(2022, 8, 16), 2, 'Interaction note 958')
# (959, 959, 35, datetime.date(2022, 8, 17), 1, 'Interaction note 959')
# (960, 960, 14, datetime.date(2022, 8, 18), 1, 'Interaction note 960')
# (961, 961, 62, datetime.date(2022, 8, 19), 2, 'Interaction note 961')
# (962, 962, 25, datetime.date(2022, 8, 20), 5, 'Interaction note 962')
# (963, 963, 36, datetime.date(2022, 8, 21), 5, 'Interaction note 963')
# (964, 964, 73, datetime.date(2022, 8, 22), 4, 'Interaction note 964')
# (965, 965, 80, datetime.date(2022, 8, 23), 1, 'Interaction note 965')
# (966, 966, 89, datetime.date(2022, 8, 24), 1, 'Interaction note 966')
# (967, 967, 81, datetime.date(2022, 8, 25), 4, 'Interaction note 967')
# (968, 968, 77, datetime.date(2022, 8, 26), 1, 'Interaction note 968')
# (969, 969, 66, datetime.date(2022, 8, 27), 5, 'Interaction note 969')
# (970, 970, 18, datetime.date(2022, 8, 28), 3, 'Interaction note 970')
# (971, 971, 56, datetime.date(2022, 8, 29), 1, 'Interaction note 971')
# (972, 972, 46, datetime.date(2022, 8, 30), 5, 'Interaction note 972')
# (973, 973, 71, datetime.date(2022, 8, 31), 4, 'Interaction note 973')
# (974, 974, 95, datetime.date(2022, 9, 1), 3, 'Interaction note 974')
# (975, 975, 74, datetime.date(2022, 9, 2), 5, 'Interaction note 975')
# (976, 976, 46, datetime.date(2022, 9, 3), 2, 'Interaction note 976')
# (977, 977, 75, datetime.date(2022, 9, 4), 3, 'Interaction note 977')
# (978, 978, 38, datetime.date(2022, 9, 5), 2, 'Interaction note 978')
# (979, 979, 63, datetime.date(2022, 9, 6), 4, 'Interaction note 979')
# (980, 980, 59, datetime.date(2022, 9, 7), 3, 'Interaction note 980')
# (981, 981, 17, datetime.date(2022, 9, 8), 5, 'Interaction note 981')
# (982, 982, 25, datetime.date(2022, 9, 9), 5, 'Interaction note 982')
# (983, 983, 56, datetime.date(2022, 9, 10), 1, 'Interaction note 983')
# (984, 984, 90, datetime.date(2022, 9, 11), 4, 'Interaction note 984')
# (985, 985, 38, datetime.date(2022, 9, 12), 1, 'Interaction note 985')
# (986, 986, 52, datetime.date(2022, 9, 13), 5, 'Interaction note 986')
# (987, 987, 17, datetime.date(2022, 9, 14), 1, 'Interaction note 987')
# (988, 988, 73, datetime.date(2022, 9, 15), 4, 'Interaction note 988')
# (989, 989, 48, datetime.date(2022, 9, 16), 5, 'Interaction note 989')
# (990, 990, 68, datetime.date(2022, 9, 17), 1, 'Interaction note 990')
# (991, 991, 8, datetime.date(2022, 9, 18), 2, 'Interaction note 991')
# (992, 992, 38, datetime.date(2022, 9, 19), 3, 'Interaction note 992')
# (993, 993, 100, datetime.date(2022, 9, 20), 2, 'Interaction note 993')
# (994, 994, 41, datetime.date(2022, 9, 21), 5, 'Interaction note 994')
# (995, 995, 23, datetime.date(2022, 9, 22), 5, 'Interaction note 995')
# (996, 996, 6, datetime.date(2022, 9, 23), 1, 'Interaction note 996')
# (997, 997, 38, datetime.date(2022, 9, 24), 2, 'Interaction note 997')
# (998, 998, 60, datetime.date(2022, 9, 25), 3, 'Interaction note 998')
# (999, 999, 21, datetime.date(2022, 9, 26), 4, 'Interaction note 999')
# (1000, 1000, 65, datetime.date(2022, 9, 27), 1, 'Interaction note 1000')

# %%
import pyodbc

# الاتصال بقاعدة البيانات المصدر
database_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV\\SQLEXPRESS;'
    'DATABASE=CustomerDataManagement;'
    'Trusted_Connection=yes;'
)

# الاتصال بقاعدة البيانات الوجهة
dwh_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV;'
    'DATABASE=SalesDWH;'
    'Trusted_Connection=yes;'
)

def fetch_payment_method_data(connection):
    query = """
    SELECT PaymentMethodID, MethodName  -- العمود الصحيح هو MethodName
    FROM PaymentMethods
    """
    cursor = connection.cursor()
    cursor.execute(query)
    return cursor.fetchall()


def load_payment_method_data_to_dwh(connection, payment_method_data):
    cursor = connection.cursor()
    
    payment_method_insert_query = """
    INSERT INTO dim_payment_method (payment_method_id, method_name)  -- العمود الصحيح هو method_name
    VALUES (?, ?)
    """
    
    cursor.executemany(payment_method_insert_query, payment_method_data)
    connection.commit()
    print(f"{len(payment_method_data)} rows inserted successfully into dim_payment_method!")

# 3. تنفيذ الوظائف
payment_method_data = fetch_payment_method_data(database_conn)
load_payment_method_data_to_dwh(dwh_conn, payment_method_data)

# 4. إغلاق الاتصالات
database_conn.close()
dwh_conn.close()
# Out:
# 1000 rows inserted successfully into dim_payment_method!

# %%
import pyodbc

database_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV\\SQLEXPRESS;'
    'DATABASE=CustomerDataManagement;'
    'Trusted_Connection=yes;'
)

dwh_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV;'
    'DATABASE=SalesDWH;'
    'Trusted_Connection=yes;'
)


def fetch_sales_data(connection):
    query = """
    SELECT 
        TransactionID, 
        CustomerID, 
        TransactionDate, 
        Amount, 
        PaymentMethodID 
    FROM Transactions
    """
    cursor = connection.cursor()
    cursor.execute(query)
    return cursor.fetchall()


def map_keys_to_dwh(connection, sales_data):
    cursor = connection.cursor()
    mapped_data = []

    for row in sales_data:
        transaction_id = row[0]
        customer_id = row[1]
        transaction_date = row[2]
        amount = row[3]
        payment_method_id = row[4]

        
        cursor.execute("SELECT customer_key FROM dim_customer WHERE customer_id = ?", customer_id)
        customer_key = cursor.fetchone()[0]

        
        cursor.execute("SELECT payment_method_key FROM dim_payment_method WHERE payment_method_id = ?", payment_method_id)
        payment_method_key = cursor.fetchone()[0]

        
        cursor.execute("SELECT date_key FROM dim_date WHERE full_date = ?", transaction_date)
        transaction_date_key = cursor.fetchone()[0]

        
        mapped_data.append((
            transaction_id,
            customer_key,
            payment_method_key,
            transaction_date_key,
            amount
        ))

    return mapped_data


def load_sales_data_to_dwh(connection, sales_data):
    cursor = connection.cursor()

    sales_insert_query = """
    INSERT INTO fact_sales (transaction_id, customer_key, payment_method_key, transaction_date_key, amount)
    VALUES (?, ?, ?, ?, ?)
    """

    cursor.executemany(sales_insert_query, sales_data)
    connection.commit()
    print(f"{len(sales_data)} rows inserted successfully into fact_sales!")


sales_data = fetch_sales_data(database_conn)
mapped_sales_data = map_keys_to_dwh(dwh_conn, sales_data)
load_sales_data_to_dwh(dwh_conn, mapped_sales_data)

database_conn.close()
dwh_conn.close()
# Out:
# 1000 rows inserted successfully into fact_sales!

# %%
import pyodbc

# الاتصال بقاعدة البيانات
database_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV\\SQLEXPRESS;'
    'DATABASE=CustomerDataManagement;'
    'Trusted_Connection=yes;'
)

dwh_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV;'
    'DATABASE=SalesDWH;'
    'Trusted_Connection=yes;'
)

# 1. جلب بيانات Transactions من قاعدة البيانات
def fetch_sales_data(connection):
    query = """
    SELECT 
        TransactionID, 
        CustomerID, 
        TransactionDate, 
        Amount, 
        PaymentMethodID 
    FROM Transactions
    """
    cursor = connection.cursor()
    cursor.execute(query)
    return cursor.fetchall()

# 2. ربط المفاتيح من جداول الـ DWH
def map_keys_to_dwh(connection, sales_data):
    cursor = connection.cursor()
    mapped_data = []

    for row in sales_data:
        transaction_id = row[0]
        customer_id = row[1]
        transaction_date = row[2]
        amount = row[3]
        payment_method_id = row[4]

        # جلب customer_key من dim_customer
        cursor.execute("SELECT customer_key FROM dim_customer WHERE customer_id = ?", customer_id)
        customer_key = cursor.fetchone()[0]

        # جلب payment_method_key من dim_payment_method
        cursor.execute("SELECT payment_method_key FROM dim_payment_method WHERE payment_method_id = ?", payment_method_id)
        payment_method_key = cursor.fetchone()[0]

        # جلب transaction_date_key من dim_date
        cursor.execute("SELECT date_key FROM dim_date WHERE full_date = ?", transaction_date)
        transaction_date_key = cursor.fetchone()[0]

        # جلب address_key من dim_customer_address
        cursor.execute("SELECT address_key FROM dim_customer_address WHERE customer_id = ?", customer_id)
        address_key = cursor.fetchone()
        address_key = address_key[0] if address_key else None  # معالجة القيم الفارغة

        # جلب contact_key من dim_customer_contact
        cursor.execute("SELECT contact_key FROM dim_customer_contact WHERE customer_id = ?", customer_id)
        contact_key = cursor.fetchone()
        contact_key = contact_key[0] if contact_key else None  # معالجة القيم الفارغة

        # جلب interaction_key و interaction_type_key من dim_interaction
        cursor.execute("SELECT interaction_key, interaction_type_id FROM dim_interaction WHERE customer_id = ?", customer_id)
        interaction_row = cursor.fetchone()
        interaction_key = interaction_row[0] if interaction_row else None
        interaction_type_key = interaction_row[1] if interaction_row else None

        # التحقق من أن interaction_type_key موجودة في dim_interaction_type
        if interaction_type_key:
            cursor.execute("SELECT interaction_type_key FROM dim_interaction_type WHERE interaction_type_key = ?", interaction_type_key)
            interaction_type_exists = cursor.fetchone()
            if not interaction_type_exists:
                interaction_type_key = None  # التعامل مع المفاتيح غير الموجودة

        # إضافة البيانات المرتبطة إلى القائمة
        mapped_data.append((
            transaction_id,
            customer_key,
            address_key,
            contact_key,
            payment_method_key,
            interaction_key,
            interaction_type_key,
            transaction_date_key,
            amount
        ))

    return mapped_data

# 3. تحميل البيانات إلى fact_sales في الـ DWH
def load_sales_data_to_dwh(connection, sales_data):
    cursor = connection.cursor()

    sales_insert_query = """
    INSERT INTO fact_sales (transaction_id, customer_key, address_key, contact_key, payment_method_key, interaction_key, interaction_type_key, transaction_date_key, amount)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    """

    cursor.executemany(sales_insert_query, sales_data)
    connection.commit()
    print(f"{len(sales_data)} rows inserted successfully into fact_sales!")

# 4. تنفيذ الوظائف
sales_data = fetch_sales_data(database_conn)
mapped_sales_data = map_keys_to_dwh(dwh_conn, sales_data)
load_sales_data_to_dwh(dwh_conn, mapped_sales_data)

# 5. إغلاق الاتصالات
database_conn.close()
dwh_conn.close()
# Out:
# 1000 rows inserted successfully into fact_sales!

# %%
import pyodbc

# الاتصال بقاعدة البيانات الأصلية
database_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV\\SQLEXPRESS;'
    'DATABASE=CustomerDataManagement;'
    'Trusted_Connection=yes;'
)

# الاتصال بـ DWH
dwh_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV;'
    'DATABASE=SalesDWH;'
    'Trusted_Connection=yes;'
)

# 1. جلب بيانات Transactions من قاعدة البيانات الأصلية
def fetch_sales_data(connection):
    query = """
    SELECT 
        t.TransactionID, 
        t.CustomerID, 
        t.TransactionDate, 
        t.Amount, 
        t.PaymentMethodID 
    FROM Transactions t
    LEFT JOIN dim_customer_address dca ON t.CustomerID = dca.customer_id
    LEFT JOIN dim_interaction di ON t.CustomerID = di.customer_id
    """
    cursor = connection.cursor()
    cursor.execute(query)
    return cursor.fetchall()

# 2. ربط المفاتيح من جداول الـ DWH
def map_keys_to_dwh(connection, sales_data):
    cursor = connection.cursor()
    mapped_data = []

    for row in sales_data:
        transaction_id = row[0]
        customer_id = row[1]
        transaction_date = row[2]
        amount = row[3]
        payment_method_id = row[4]

        # جلب customer_key من dim_customer
        cursor.execute("SELECT customer_key FROM dim_customer WHERE customer_id = ?", customer_id)
        customer_key = cursor.fetchone()[0]

        # جلب payment_method_key من dim_payment_method
        cursor.execute("SELECT payment_method_key FROM dim_payment_method WHERE payment_method_id = ?", payment_method_id)
        payment_method_key = cursor.fetchone()[0]

        # جلب transaction_date_key من dim_date
        cursor.execute("SELECT date_key FROM dim_date WHERE full_date = ?", transaction_date)
        transaction_date_key = cursor.fetchone()[0]

        # جلب address_key من dim_customer_address
        cursor.execute("SELECT address_key FROM dim_customer_address WHERE customer_id = ?", customer_id)
        address_key = cursor.fetchone()
        address_key = address_key[0] if address_key else None  # معالجة القيم الفارغة

        # جلب contact_key من dim_customer_contact
        cursor.execute("SELECT contact_key FROM dim_customer_contact WHERE customer_id = ?", customer_id)
        contact_key = cursor.fetchone()
        contact_key = contact_key[0] if contact_key else None  # معالجة القيم الفارغة

        # جلب interaction_key و interaction_type_key من dim_interaction
        cursor.execute("SELECT interaction_key, interaction_type_id FROM dim_interaction WHERE customer_id = ?", customer_id)
        interaction_row = cursor.fetchone()
        interaction_key = interaction_row[0] if interaction_row else None
        interaction_type_key = interaction_row[1] if interaction_row else None

        # إضافة البيانات المرتبطة إلى القائمة
        mapped_data.append((
            transaction_id,
            customer_key,
            address_key,
            contact_key,
            payment_method_key,
            interaction_key,
            interaction_type_key,
            transaction_date_key,
            amount
        ))

    return mapped_data

# 3. تحميل البيانات إلى fact_sales في الـ DWH
def load_sales_data_to_dwh(connection, sales_data):
    cursor = connection.cursor()

    sales_insert_query = """
    INSERT INTO fact_sales (transaction_id, customer_key, address_key, contact_key, payment_method_key, interaction_key, interaction_type_key, transaction_date_key, amount)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    """

    cursor.executemany(sales_insert_query, sales_data)
    connection.commit()
    print(f"{len(sales_data)} rows inserted successfully into fact_sales!")

# 4. تنفيذ الوظائف
sales_data = fetch_sales_data(database_conn)
mapped_sales_data = map_keys_to_dwh(dwh_conn, sales_data)
load_sales_data_to_dwh(dwh_conn, mapped_sales_data)

# 5. إغلاق الاتصالات
database_conn.close()
dwh_conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[2], line 105
#     102     print(f"{len(sales_data)} rows inserted successfully into fact_sales!")
#     104 # 4. تنفيذ الوظائف
# --> 105 sales_data = fetch_sales_data(database_conn)
#     106 mapped_sales_data = map_keys_to_dwh(dwh_conn, sales_data)
#     107 load_sales_data_to_dwh(dwh_conn, mapped_sales_data)
#
# Cell In[2], line 33, in fetch_sales_data(connection)
#      21 query = """
#      22 SELECT
#      23     t.TransactionID,
#    (...)
#      30 LEFT JOIN dim_interaction di ON t.CustomerID = di.customer_id
#      31 """
#      32 cursor = connection.cursor()
# ---> 33 cursor.execute(query)
#      34 return cursor.fetchall()
#
# ProgrammingError: ('42S02', "[42S02] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Invalid object name 'dim_customer_address'. (208) (SQLExecDirectW)")

# %%
import pyodbc

# الاتصال بقاعدة البيانات الأصلية
database_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV\\SQLEXPRESS;'
    'DATABASE=CustomerDataManagement;'
    'Trusted_Connection=yes;'
)

# الاتصال بـ DWH
dwh_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV;'
    'DATABASE=SalesDWH;'
    'Trusted_Connection=yes;'
)

# 1. جلب بيانات Transactions من قاعدة البيانات الأصلية
def fetch_sales_data(connection):
    query = """
    SELECT 
        TransactionID, 
        CustomerID, 
        TransactionDate, 
        Amount, 
        PaymentMethodID 
    FROM Transactions
    """
    cursor = connection.cursor()
    cursor.execute(query)
    return cursor.fetchall()

# 2. ربط المفاتيح من جداول الـ DWH
def map_keys_to_dwh(connection, sales_data):
    cursor = connection.cursor()
    mapped_data = []

    for row in sales_data:
        transaction_id = row[0]
        customer_id = row[1]
        transaction_date = row[2]
        amount = row[3]
        payment_method_id = row[4]

        # جلب customer_key من dim_customer
        cursor.execute("SELECT customer_key FROM dim_customer WHERE customer_id = ?", customer_id)
        customer_key = cursor.fetchone()
        customer_key = customer_key[0] if customer_key else None

        # جلب payment_method_key من dim_payment_method
        cursor.execute("SELECT payment_method_key FROM dim_payment_method WHERE payment_method_id = ?", payment_method_id)
        payment_method_key = cursor.fetchone()
        payment_method_key = payment_method_key[0] if payment_method_key else None

        # جلب transaction_date_key من dim_date
        cursor.execute("SELECT date_key FROM dim_date WHERE full_date = ?", transaction_date)
        transaction_date_key = cursor.fetchone()
        transaction_date_key = transaction_date_key[0] if transaction_date_key else None

        # جلب address_key من dim_customer_address
        cursor.execute("SELECT address_key FROM dim_customer_address WHERE customer_id = ?", customer_id)
        address_key = cursor.fetchone()
        address_key = address_key[0] if address_key else None

        # جلب contact_key من dim_customer_contact
        cursor.execute("SELECT contact_key FROM dim_customer_contact WHERE customer_id = ?", customer_id)
        contact_key = cursor.fetchone()
        contact_key = contact_key[0] if contact_key else None

        # جلب interaction_key و interaction_type_key من dim_interaction
        cursor.execute("SELECT interaction_key, interaction_type_id FROM dim_interaction WHERE customer_id = ?", customer_id)
        interaction_row = cursor.fetchone()
        interaction_key = interaction_row[0] if interaction_row else None
        interaction_type_key = interaction_row[1] if interaction_row else None

        # إضافة البيانات المرتبطة إلى القائمة
        mapped_data.append((
            transaction_id,
            customer_key,
            address_key,
            contact_key,
            payment_method_key,
            interaction_key,
            interaction_type_key,
            transaction_date_key,
            amount
        ))

    return mapped_data

# 3. تحميل البيانات إلى fact_sales في الـ DWH
def load_sales_data_to_dwh(connection, sales_data):
    cursor = connection.cursor()

    sales_insert_query = """
    INSERT INTO fact_sales (transaction_id, customer_key, address_key, contact_key, payment_method_key, interaction_key, interaction_type_key, transaction_date_key, amount)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    """

    cursor.executemany(sales_insert_query, sales_data)
    connection.commit()
    print(f"{len(sales_data)} rows inserted successfully into fact_sales!")

# 4. تنفيذ الوظائف
sales_data = fetch_sales_data(database_conn)
mapped_sales_data = map_keys_to_dwh(dwh_conn, sales_data)
load_sales_data_to_dwh(dwh_conn, mapped_sales_data)

# 5. إغلاق الاتصالات
database_conn.close()
dwh_conn.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[3], line 108
#     106 sales_data = fetch_sales_data(database_conn)
#     107 mapped_sales_data = map_keys_to_dwh(dwh_conn, sales_data)
# --> 108 load_sales_data_to_dwh(dwh_conn, mapped_sales_data)
#     110 # 5. إغلاق الاتصالات
#     111 database_conn.close()
#
# Cell In[3], line 101, in load_sales_data_to_dwh(connection, sales_data)
#      94 cursor = connection.cursor()
#      96 sales_insert_query = """
#      97 INSERT INTO fact_sales (transaction_id, customer_key, address_key, contact_key, payment_method_key, interaction_key, interaction_type_key, transaction_date_key, amount)
#      98 VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
#      99 """
# --> 101 cursor.executemany(sales_insert_query, sales_data)
#     102 connection.commit()
#     103 print(f"{len(sales_data)} rows inserted successfully into fact_sales!")
#
# IntegrityError: ('23000', '[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The INSERT statement conflicted with the FOREIGN KEY constraint "fk_fact_sales_dim_interaction_type". The conflict occurred in database "SalesDWH", table "dbo.dim_interaction_type", column \'interaction_type_key\'. (547) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The statement has been terminated. (3621)')

# %%
import pyodbc

# الاتصال بقاعدة البيانات الأصلية (CustomerDataManagement)
database_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV\\SQLEXPRESS;'
    'DATABASE=CustomerDataManagement;'
    'Trusted_Connection=yes;'
)

# الاتصال بقاعدة بيانات الـ DWH (SalesDWH)
dwh_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV;'
    'DATABASE=SalesDWH;'
    'Trusted_Connection=yes;'
)

# 1. جلب بيانات `InteractionTypes` من قاعدة البيانات الأصلية
def fetch_interaction_type_data(connection):
    query = """
    SELECT InteractionTypeID, TypeName
    FROM InteractionTypes
    """
    cursor = connection.cursor()
    cursor.execute(query)
    return cursor.fetchall()

# 2. تحميل البيانات إلى `dim_interaction_type` في الـ DWH
def load_interaction_type_data_to_dwh(connection, interaction_type_data):
    cursor = connection.cursor()

    interaction_type_insert_query = """
    INSERT INTO dim_interaction_type (interaction_type_id, type_name)
    VALUES (?, ?)
    """

    cursor.executemany(interaction_type_insert_query, interaction_type_data)
    connection.commit()
    print(f"{len(interaction_type_data)} rows inserted successfully into dim_interaction_type!")

# 3. تنفيذ الوظائف
interaction_type_data = fetch_interaction_type_data(database_conn)
load_interaction_type_data_to_dwh(dwh_conn, interaction_type_data)

# 4. إغلاق الاتصالات
database_conn.close()
dwh_conn.close()
# Out:
# 1000 rows inserted successfully into dim_interaction_type!

# %%
import pyodbc

# الاتصال بقاعدة البيانات
database_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV\\SQLEXPRESS;'
    'DATABASE=CustomerDataManagement;'
    'Trusted_Connection=yes;'
)

dwh_conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-67E98DV;'
    'DATABASE=SalesDWH;'
    'Trusted_Connection=yes;'
)

# 1. جلب بيانات Transactions من قاعدة البيانات
def fetch_sales_data(connection):
    query = """
    SELECT 
        t.TransactionID, 
        t.CustomerID, 
        t.TransactionDate, 
        t.Amount, 
        t.PaymentMethodID
    FROM Transactions t
    """
    cursor = connection.cursor()
    cursor.execute(query)
    return cursor.fetchall()

# 2. ربط المفاتيح من جداول الـ DWH ومعالجة القيم المفقودة
def map_keys_to_dwh(connection, sales_data):
    cursor = connection.cursor()
    mapped_data = []

    for row in sales_data:
        transaction_id = row[0]
        customer_id = row[1]
        transaction_date = row[2]
        amount = row[3]
        payment_method_id = row[4]

        # جلب customer_key من dim_customer
        cursor.execute("SELECT customer_key FROM dim_customer WHERE customer_id = ?", customer_id)
        customer_key_row = cursor.fetchone()
        customer_key = customer_key_row[0] if customer_key_row else None

        # جلب payment_method_key من dim_payment_method
        cursor.execute("SELECT payment_method_key FROM dim_payment_method WHERE payment_method_id = ?", payment_method_id)
        payment_method_key_row = cursor.fetchone()
        payment_method_key = payment_method_key_row[0] if payment_method_key_row else None

        # جلب transaction_date_key من dim_date
        cursor.execute("SELECT date_key FROM dim_date WHERE full_date = ?", transaction_date)
        transaction_date_key_row = cursor.fetchone()
        transaction_date_key = transaction_date_key_row[0] if transaction_date_key_row else None

        # جلب address_key من dim_customer_address
        cursor.execute("SELECT address_key FROM dim_customer_address WHERE customer_id = ?", customer_id)
        address_key_row = cursor.fetchone()
        address_key = address_key_row[0] if address_key_row else None

        # جلب contact_key من dim_customer_contact
        cursor.execute("SELECT contact_key FROM dim_customer_contact WHERE customer_id = ?", customer_id)
        contact_key_row = cursor.fetchone()
        contact_key = contact_key_row[0] if contact_key_row else None

        # جلب interaction_key و interaction_type_key من dim_interaction
        cursor.execute("SELECT interaction_key, interaction_type_id FROM dim_interaction WHERE customer_id = ?", customer_id)
        interaction_row = cursor.fetchone()
        interaction_key = interaction_row[0] if interaction_row else None
        interaction_type_key = interaction_row[1] if interaction_row else None

        # التحقق من وجود interaction_type_key في dim_interaction_type
        if interaction_type_key:
            cursor.execute("SELECT interaction_type_key FROM dim_interaction_type WHERE interaction_type_key = ?", interaction_type_key)
            interaction_type_row = cursor.fetchone()
            if not interaction_type_row:
                interaction_type_key = None  # تعيين None إذا لم يتم العثور على نوع التفاعل

        # إضافة البيانات المرتبطة إلى القائمة
        mapped_data.append((
            transaction_id,
            customer_key,
            address_key,
            contact_key,
            payment_method_key,
            interaction_key,
            interaction_type_key,
            transaction_date_key,
            amount
        ))

    return mapped_data

# 3. تحميل البيانات إلى fact_sales في الـ DWH
def load_sales_data_to_dwh(connection, sales_data):
    cursor = connection.cursor()

    sales_insert_query = """
    INSERT INTO fact_sales (transaction_id, customer_key, address_key, contact_key, payment_method_key, interaction_key, interaction_type_key, transaction_date_key, amount)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    """

    cursor.executemany(sales_insert_query, sales_data)
    connection.commit()
    print(f"{len(sales_data)} rows inserted successfully into fact_sales!")

# 4. تنفيذ الوظائف
sales_data = fetch_sales_data(database_conn)
mapped_sales_data = map_keys_to_dwh(dwh_conn, sales_data)
load_sales_data_to_dwh(dwh_conn, mapped_sales_data)

# 5. إغلاق الاتصالات
database_conn.close()
dwh_conn.close()
# Out:
# 1000 rows inserted successfully into fact_sales!
